# %% [markdown]
# ## Data set for SEM1 and SEM2 1 hour and 2 hour lecture and room can be used

# %%
# dataset
courses1 = ['MATH08057',
  'MATH08057A',
  'MATH08063',
  'MATH08066',
  'MATH08066A',
  'MATH08071',
  'MATH08071A',
  'MATH08072',
  'MATH08072A',
  'MATH08074',
  'MATH08074A',
  'MATH08077',
  'MATH10007',
  'MATH10007A',
  'MATH10013',
  'MATH10013A',
  'MATH10017',
  'MATH10017A',
  'MATH10024',
  'MATH10024A',
  'MATH10028',
  'MATH10028A',
  'MATH10047',
  'MATH10047A',
  'MATH10053',
  'MATH10053A',
  'MATH10066',
  'MATH10066A',
  'MATH10068',
  'MATH10068A',
  'MATH10072',
  'MATH10072A',
  'MATH10074',
  'MATH10074A',
  'MATH10076',
  'MATH10076A',
  'MATH10079',
  'MATH10079A',
  'MATH10082',
  'MATH10082A',
  'MATH10095',
  'MATH10095A',
  'MATH10098',
  'MATH10098A',
  'MATH10099',
  'MATH10100',
  'MATH10100A',
  'MATH11053',
  'MATH11053A',
  'MATH11144',
  'MATH11144A',
  'MATH11199',
  'MATH11226',
  'MATH11226A',
  'MATH11231',
  'MATH11235',
  'MATH11235A',
  'MATH11236',
  'MATH11236A',
    'MATH08057',
    'MATH08057A',
    'MATH11220',
    'MATH10010 + MATH11088',
    'MATH08062',
    'MATH11177',
    'MATH11230',
    'MATH10065',
    'MATH11111',
    'MATH11187',
    'MATH11007',
    'MATH11197',
    'MATH10102',
    'MATH11176',
    'MATH11154',
    'MATH11179']

students_per_course1 = {'MATH08071A': 71,
  'MATH08071': 71,
  'MATH11226A': 38,
  'MATH11226': 38,
  'MATH10053A': 50,
  'MATH10053': 50,
  'MATH11236A': 22,
  'MATH11236': 22,
  'MATH10072A': 96,
  'MATH10072': 96,
  'MATH10017A': 30,
  'MATH10017': 30,
  'MATH11235A': 35,
  'MATH11235': 35,
  'MATH10047A': 25,
  'MATH10047': 25,
  'MATH10076A': 54,
  'MATH10076': 54,
  'MATH10074A': 97,
  'MATH10074': 97,
  'MATH10066A': 308,
  'MATH10066': 308,
  'MATH11053A': 13,
  'MATH11053': 13,
  'MATH08057A': 585,
  'MATH08057': 585,
  'MATH10100A': 33,
  'MATH10100': 33,
  'MATH10082A': 25,
  'MATH10082': 25,
  'MATH10013A': 60,
  'MATH10013': 60,
  'MATH08072A': 141,
  'MATH08072': 141,
  'MATH10095A': 262,
  'MATH10095': 262,
  'MATH10028A': 58,
  'MATH10028': 58,
  'MATH11144A': 5,
  'MATH11144': 5,
  'MATH08063': 452,
  'MATH10099': 43,
  'MATH11231': 32,
  'MATH08077': 180,
  'MATH11199': 228,
  'MATH08066A': 458,
  'MATH08074A': 427,
  'MATH08074': 427,
  'MATH08066': 458,
  'MATH10079': 50,
  'MATH10079A': 50,
  'MATH10068': 188,
  'MATH10068A': 188,
  'MATH10024': 7,
  'MATH10024A': 7,
  'MATH10007': 149,
  'MATH10007A': 149,
  'MATH10098': 145,
  'MATH10098A': 145,   
    'MATH08057': 585,
    'MATH08057A': 585,
    'MATH11220': 17,
    'MATH10010 + MATH11088': 67,
    'MATH08062': 57,
    'MATH11177': 161,
    'MATH11230': 47,
    'MATH10065': 216,
    'MATH11111': 174,
    'MATH11187': 138,
    'MATH11007': 78,
    'MATH11197': 24,
    'MATH10102': 44,
    'MATH11176': 140,
    'MATH11154': 79,
    'MATH11179': 29}

hours_per_course1 = {
    'MATH08071A': 1, 'MATH08071': 1,
    'MATH11226A': 1, 'MATH11226': 1,
    'MATH10053A': 1, 'MATH10053': 1,
    'MATH11236A': 1, 'MATH11236': 1,
    'MATH10072A': 1, 'MATH10072': 1,
    'MATH10017A': 1, 'MATH10017': 1,
    'MATH11235A': 1, 'MATH11235': 1,
    'MATH10047A': 1, 'MATH10047': 1,
    'MATH10076A': 1, 'MATH10076': 1,
    'MATH10074A': 1, 'MATH10074': 1,
    'MATH10066A': 1, 'MATH10066': 1,
    'MATH11053A': 1, 'MATH11053': 1,
    'MATH10100A': 1, 'MATH10100': 1,
    'MATH10082A': 1, 'MATH10082': 1,
    'MATH10013A': 1, 'MATH10013': 1,
    'MATH08072A': 1, 'MATH08072': 1,
    'MATH10095A': 1, 'MATH10095': 1,
    'MATH10028A': 1, 'MATH10028': 1,
    'MATH11144A': 1, 'MATH11144': 1,
    'MATH08063': 1, 'MATH10099': 1,
    'MATH11231': 1, 'MATH08077': 1,
    'MATH11199': 1, 'MATH11029': 1,
    'MATH08066A': 1, 'MATH08074A': 1,
    'MATH08074': 1, 'MATH08066': 1,
    'MATH10079': 1, 'MATH10079A': 1,
    'MATH10068': 1, 'MATH10068A': 1,
    'MATH10024': 1, 'MATH10024A': 1,
    'MATH10007': 1, 'MATH10007A': 1,
    'MATH10098': 1, 'MATH10098A': 1,
    # Courses with 2 hours duration
    'MATH08057': 2, 'MATH08057A': 2,
    'MATH11220': 2,
    'MATH10010 + MATH11088': 2,
    'MATH08062': 2,
    'MATH11177': 2,
    'MATH11230': 2,
    'MATH10065': 2,
    'MATH11111': 2,
    'MATH11187': 2,
    'MATH11007': 2,
    'MATH11197': 2,
    'MATH10102': 2,
    'MATH11176': 2,
    'MATH11154': 2,
    'MATH11179': 2,
}
courses2={

    'MATH10086', 'MATH11120', 'MATH10077', 'MATH11140', 'MATH08058_1','MATH08058', 'MATH08065', 

    'MATH11206', 'MATH10051', 'MATH08064', 'MATH11233', 'MATH10080', 'MATH11138', 

    'MATH10069', 'MATH10067', 'MATH11185', 'MATH11145', 'MATH10073', 'MATH10101', 

    'MATH10064', 'MATH10060', 'MATH11207', 'MATH11193', 'MATH10024', 'MATH08059', 

    'MATH11197', 'MATH10093', 'MATH11188', 'MATH08051', 'MATH10071', 'MATH08075',   'MATH10086D', 'MATH10086B', 'MATH10086C', 'MATH11120B', 'MATH11120A', 'MATH10077B', 

    'MATH10077A', 'MATH11140B', 'MATH11140A', 'MATH08058B','MATH08058B_1', 'MATH08058A','MATH08058A_1', 'MATH08065B', 

    'MATH11206B', 'MATH11206A', 'MATH10051A', 'MATH08064A', 'MATH08064B', 'MATH11233A', 

    'MATH10080A', 'MATH10080B', 'MATH11138A', 'MATH11138B', 'MATH10069A', 'MATH10069B', 

  'MATH10067A', 'MATH10067B', 'MATH11185B', 'MATH11185A', 'MATH11145B', 'MATH11145A',

    'MATH10073A', 'MATH10101B', 'MATH10101A', 'MATH10064A', 'MATH10064B', 'MATH10060A', 

    'MATH11207A', 'MATH11207B', 'MATH11193B', 'MATH11193A', 'MATH10024B', 'MATH10024A', 

    'MATH08059A', 'MATH08059B', 'MATH11197B', 'MATH11197A', 'MATH10093A', 'MATH11188A', 

    'MATH08051A', 'MATH08051B', 'MATH11148', 'MATH11174', 'MATH11132', 'MATH10010'}


 

students_per_course2={

    'MATH10086': 54, 'MATH11120': 37, 'MATH10077': 23, 'MATH11140': 43, 'MATH08058_1': 323, 'MATH08058':300,

    'MATH08065': 388, 'MATH11206': 11, 'MATH10051': 19, 'MATH08064': 461, 'MATH11233': 35, 

    'MATH10080': 28, 'MATH11138': 18, 'MATH10069': 199, 'MATH10067': 291, 'MATH11185': 185, 

  'MATH11145': 27, 'MATH10073': 88, 'MATH10101': 84, 'MATH10064': 129, 'MATH10060': 188,

    'MATH11207': 51, 'MATH11193': 19, 'MATH10024': 7, 'MATH08059': 392, 'MATH11197': 24, 

    'MATH10093': 172, 'MATH11188': 96, 'MATH08051': 395, 'MATH10071': 139, 'MATH08075': 429,    'MATH10086D': 54, 'MATH10086B': 54, 'MATH10086C': 54, 'MATH11120B': 37, 'MATH11120A': 37, 

    'MATH10077B': 23, 'MATH10077A': 23, 'MATH11140B': 43, 'MATH11140A': 43, 'MATH08058B': 323, 'MATH08058B_1':300,

    'MATH08058A': 323,'MATH08058A_1': 300, 'MATH08065B': 388, 'MATH11206B': 11, 'MATH11206A': 11, 'MATH10051A': 19, 

    'MATH08064A': 461, 'MATH08064B': 461, 'MATH11233A': 35, 'MATH10080A': 28, 'MATH10080B': 28, 

    'MATH11138A': 18, 'MATH11138B': 18, 'MATH10069A': 199, 'MATH10069B': 199, 'MATH10067A': 291, 

    'MATH10067B': 291, 'MATH11185B': 185, 'MATH11185A': 185, 'MATH11145B': 27, 'MATH11145A': 27, 

    'MATH10073A': 88, 'MATH10101B': 84, 'MATH10101A': 84, 'MATH10064A': 129, 'MATH10064B': 129, 

    'MATH10060A': 188, 'MATH11207A': 51, 'MATH11207B': 51, 'MATH11193B': 19, 'MATH11193A': 19, 

    'MATH10024B': 7, 'MATH10024A': 7, 'MATH08059A': 392, 'MATH08059B': 392, 'MATH11197B': 24, 

    'MATH11197A': 24, 'MATH10093A': 172, 'MATH11188A': 96, 'MATH08051A': 395, 'MATH08051B': 395, 

  'MATH11148': 149, 'MATH11174': 96, 'MATH11132': 53, 'MATH10010': 53

}


 

hours_per_course2 ={

    'MATH10086': 1, 'MATH11120': 1, 'MATH10077': 1, 'MATH11140': 1, 'MATH08058': 1, 'MATH08058_1':1,

    'MATH08065': 1, 'MATH11206': 1, 'MATH10051': 1, 'MATH08064': 1, 'MATH11233': 1, 

    'MATH10080': 1, 'MATH11138': 1, 'MATH10069': 1, 'MATH10067': 1, 'MATH11185': 1, 

    'MATH11145': 1, 'MATH10073': 1, 'MATH10101': 1, 'MATH10064': 1, 'MATH10060': 1, 

    'MATH11207': 1, 'MATH11193': 1, 'MATH10024': 1, 'MATH08059': 1, 'MATH11197': 1, 

    'MATH10093': 1, 'MATH11188': 1, 'MATH08051': 1, 'MATH10071': 1, 'MATH08075': 1, 'MATH10086D': 2, 'MATH10086B': 2, 'MATH10086C': 2, 'MATH11120B': 2, 'MATH11120A': 2, 

    'MATH10077B': 2, 'MATH10077A': 2, 'MATH11140B': 2, 'MATH11140A': 2, 'MATH08058B': 2, 'MATH08058B_1':2,

    'MATH08058A': 2, 'MATH08058A_1':2,'MATH08065B': 2, 'MATH11206B': 2, 'MATH11206A': 2, 'MATH10051A': 2, 

    'MATH08064A': 2, 'MATH08064B': 2, 'MATH11233A': 2, 'MATH10080A': 2, 'MATH10080B': 2, 

    'MATH11138A': 2, 'MATH11138B': 2, 'MATH10069A': 2, 'MATH10069B': 2, 'MATH10067A': 2, 

  'MATH10067B': 2, 'MATH11185B': 2, 'MATH11185A': 2, 'MATH11145B': 2, 'MATH11145A': 2,

    'MATH10073A': 2, 'MATH10101B': 2, 'MATH10101A': 2, 'MATH10064A': 2, 'MATH10064B': 2, 

    'MATH10060A': 2, 'MATH11207A': 2, 'MATH11207B': 2, 'MATH11193B': 2, 'MATH11193A': 2, 

    'MATH10024B': 2, 'MATH10024A': 2, 'MATH08059A': 2, 'MATH08059B': 2, 'MATH11197B': 2, 

    'MATH11197A': 2, 'MATH10093A': 2, 'MATH11188A': 2, 'MATH08051A': 2, 'MATH08051B': 2, 

    'MATH11148': 2, 'MATH11174': 2, 'MATH11132': 2, 'MATH10010': 2

}

rooms = [
    'GALT_Gordon Aikman Lecture Theatre', '40GS_Lecture Theatre B', '40GS_Lecture Theatre C',
    'AT_Lecture Theatre 2', '40GS_13.07', 'AT_2.05', 'CMB_Seminar Room 5',
    'OC_Usha Kasera Lecture Theatre', 'AT_Lecture Theatre 5', 'AT_Lecture Theatre 3',
    '7-8CS_1.01', 'ALR_Classroom 10', 'ASH_Honours Room 1', 'ASH_Honours Room 2',
    'ASH_Lecture Theatre 1', 'ASH_Lecture Theatre 3', 'DRB_G.27 Lecture Theatre 1',
    'ESB_Lecture Theatre No. 1', 'GRA_Lecture Theatre 201', 'GRA_Room 304B',
    'HBB_Classroom 4', 'HBB_Lecture Theatre 2', 'JBB_Theatre 100', 'JBB_Theatre 250',
    'JBB_Theatre 40', 'JCMB_1501', 'JCMB_4312', 'JCMB_4325A', 'JCMB_4325B',
    'JCMB_5326', 'JCMB_5327', 'JCMB_5328', 'JCMB_6201', 'JCMB_6206',
    'JCMB_Lecture Theatre A', 'JCMB_Lecture Theatre B', 'JCMB_Lecture Theatre C',
    'MH_Lecture Theatre G.26', 'NUC_1.14 - Oak Lecture Theatre', 'NUC_1.15 - Larch Lecture Theatre',
    'NUC_2.03 - Hawthorn Teaching Studio', 'NUC_2.07 - Yew Lecture Theatre',
    'NUC_B.01 - Alder Lecture Theatre', 'NUC_G.02 - Elm Lecture Theatre', 'SB_Main Lecture Theatre'
]

 

room_capacities = {
    'GALT_Gordon Aikman Lecture Theatre': 588, '40GS_Lecture Theatre B': 320, 
    '40GS_Lecture Theatre C': 315, 'AT_Lecture Theatre 2': 200, '40GS_13.07': 30,
    'AT_2.05': 24, 'CMB_Seminar Room 5': 35, 'OC_Usha Kasera Lecture Theatre': 350,
    'AT_Lecture Theatre 5': 300, 'AT_Lecture Theatre 3': 100, '7-8CS_1.01': 20,
    'ALR_Classroom 10': 86, 'ASH_Honours Room 1': 35, 'ASH_Honours Room 2': 33,
    'ASH_Lecture Theatre 1': 313, 'ASH_Lecture Theatre 3': 88, 'DRB_G.27 Lecture Theatre 1': 164,
    'ESB_Lecture Theatre No. 1': 200, 'GRA_Lecture Theatre 201': 135, 'GRA_Room 304B': 40,
    'HBB_Classroom 4': 54, 'HBB_Lecture Theatre 2': 195, 'JBB_Theatre 100': 94,
    'JBB_Theatre 250': 230, 'JBB_Theatre 40': 36, 'JCMB_1501': 62, 'JCMB_4312': 30,
    'JCMB_4325A': 50, 'JCMB_4325B': 39, 'JCMB_5326': 42, 'JCMB_5327': 50, 'JCMB_5328': 50,
    'JCMB_6201': 38, 'JCMB_6206': 52, 'JCMB_Lecture Theatre A': 197, 'JCMB_Lecture Theatre B': 150,
    'JCMB_Lecture Theatre C': 104, 'MH_Lecture Theatre G.26': 105, 'NUC_1.14 - Oak Lecture Theatre': 400,
    'NUC_1.15 - Larch Lecture Theatre': 300, 'NUC_2.03 - Hawthorn Teaching Studio': 132,
    'NUC_2.07 - Yew Lecture Theatre': 150, 'NUC_B.01 - Alder Lecture Theatre': 300,
    'NUC_G.02 - Elm Lecture Theatre': 112, 'SB_Main Lecture Theatre': 374
}
weekdays_num = 5
max_lecture_hours = 10

# %% [markdown]
# ## All useful function that can be used in the function that define below and print functions

# %%
def is_time_slot_available(timetable, room, day, start_hour, end_hour):
    """
    Check if a given time slot is available in a specified room. Assumes the end hour is inclusive.

    Args:
    - timetable: The current timetable containing all course schedules.
    - room: The room to check for availability.
    - day: The day to check for availability.
    - start_hour: The starting hour of the time slot (inclusive).
    - end_hour: The ending hour of the time slot (inclusive).

    Returns:
    - True if the given time slot and room are free of conflicts.
    - False if there is a conflict.
    """
    for entry in timetable:
        _, entry_room, entry_day, entry_start_hour, entry_end_hour = entry
        # Check if it's the same room and day
        if room == entry_room and day == entry_day:
            # Check for time overlap, adjusted condition to include end hour
            if not (start_hour > entry_end_hour or end_hour < entry_start_hour):
                return False  # Time overlap found
    return True  # No time overlap found


def calculate_conflict_count(timetable):
    """
    Calculate the number of conflicts in the timetable.

    A conflict occurs when two or more courses are scheduled in the same time slot.

    Args:
    - timetable: The timetable to check for conflicts.

    Returns:
    - The count of conflicts in the timetable.
    """
    time_slots = {}
    for course, room, day, start_hour, _ in timetable:
        key = (day, start_hour)
        if key not in time_slots:
            time_slots[key] = set()
        time_slots[key].add(course)

    conflict_count = sum(len(courses) - 1 for courses in time_slots.values() if len(courses) > 1)
    return conflict_count


def calculate_conflict_occurrences(timetable):
    """
    Calculate the number of time slots in the timetable that have scheduling conflicts.

    A conflict is defined as two or more courses being scheduled at the same time and day.

    Args:
    - timetable: The timetable containing course scheduling information.

    Returns:
    - The number of time slots with conflicts.
    """
    time_slots = {}
    for course, room, day, start_hour, _ in timetable:
        key = (day, start_hour)
        if key not in time_slots:
            time_slots[key] = set()
        time_slots[key].add(course)

    conflict_occurrences = sum(len(courses) > 1 for courses in time_slots.values())
    return conflict_occurrences

def find_conflicting_courses(timetable):
    """
    Find and return a list of courses that have scheduling conflicts in the timetable.
    
    A conflict is defined as two or more courses being scheduled at the same time and day but in different rooms.

    Args:
    - timetable (list of tuples): The timetable containing course scheduling information. Each tuple consists of (course, room, day, start_hour, end_hour).

    Returns:
    - set: A set of conflicting courses.
    """
    conflicts = set()
    for index, (course, room, day, start_hour, end_hour) in enumerate(timetable):
        for other_course, other_room, other_day, other_start_hour, other_end_hour in timetable[index + 1:]:
            # Check if there is a time overlap but in different rooms
            if day == other_day and not (end_hour <= other_start_hour or start_hour >= other_end_hour) and room != other_room:
                conflicts.add(course)
                conflicts.add(other_course)

    return conflicts


def print_timetable_by_room(initial_timetable, hours_per_course):
    hour_conversion = {
        1: "9 AM", 2: "10 AM", 3: "11 AM", 4: "12 PM", 5: "1 PM",
        6: "2 PM", 7: "3 PM", 8: "4 PM", 9: "5 PM", 10: "6 PM"
    }
    day_conversion = {
        1: "Monday", 2: "Tuesday", 3: "Wednesday",
        4: "Thursday", 5: "Friday"
    }

    # Sort the timetable by room, day, and start hour
    sorted_timetable = sorted(initial_timetable, key=lambda x: (x[1], x[2], x[3]))

    current_room = ""

    for entry in sorted_timetable:
        course_code, room_name, day, start_hour, end_hour = entry

        if room_name != current_room:
            print(f"\n{room_name}:")
            current_room = room_name

        day_str = day_conversion.get(day, "Invalid Day")
        start_hour_str = hour_conversion.get(start_hour, "Invalid Hour")
        end_hour_str = hour_conversion.get(end_hour, "Invalid Hour")

        # Print the course details
        print(f"  - Course Code: {course_code}, {day_str}, {start_hour_str}-{end_hour_str}")


def check_unassigned_courses(courses, optimized_timetable):
    assigned_courses = set(entry[0] for entry in optimized_timetable)
    unassigned_courses = set(courses) - assigned_courses
    return unassigned_courses


def find_unused_time_slots1(timetable, weekdays_num, max_lecture_hours):
   
    all_time_slots = {(day, hour): False for day in range(1, weekdays_num + 1) for hour in range(1, max_lecture_hours + 1)}

    for _, _, day, start_hour, end_hour in timetable:
        for hour in range(start_hour, end_hour):
            all_time_slots[(day, hour)] = True

   
    unused_slots_list = [key for key, used in all_time_slots.items() if not used]

    hour_to_time = {1: "9am", 2: "10am", 3: "11am", 4: "12pm", 5: "1pm", 6: "2pm", 7: "3pm", 8: "4pm", 9: "5pm", 10: "6pm"}
    day_names = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]

  
    formatted_unused_slots = []
    for day, hour in sorted(unused_slots_list):
        day_name = day_names[day - 1]
        time_range = f"{hour_to_time[hour]} - {hour_to_time.get(hour+1, 'End of Day')}"
        formatted_unused_slots.append(f"{day_name}, {time_range}")

    return formatted_unused_slots

# %% [markdown]
# ## A function that random allocate courses to classroom. Only follow the basic constraints that two courses can't allocate in same room at same and a courses can't allocated in different room at same time

# %%
import random

def generate_random_sample(courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    timetable = []
    for course in courses:
        course_scheduled = False
        hours_needed = hours_per_course[course]
        while not course_scheduled:
            day = random.randint(1, weekdays_num)
            room = random.choice(rooms)
            if room_capacities[room] >= students_per_course[course]:
               
                if hours_needed == 1: 
                    start_hour_range = max_lecture_hours  
                else:
                    start_hour_range = max_lecture_hours - hours_needed + 1
               
                start_hour = random.randint(1, start_hour_range)
                end_hour = start_hour + hours_needed
                if end_hour+1 <= max_lecture_hours:  
                    if is_time_slot_available(timetable, room, day, start_hour, end_hour):
                        timetable.append((course, room, day, start_hour, end_hour))
                        course_scheduled = True
    return timetable

# %% [markdown]
# ## Algorithm that named simulated annealing algorithm that help us to opt the timetable that ramdon allocated at previous code block

# %%
import random
import math
import matplotlib.pyplot as plt
import copy






def fitness(timetable, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    """
    Calculate the fitness of a timetable, focusing on reducing the number of conflict occurrences and conflict count.
    """
    # Set a penalty for each conflict occurrence and each conflict count
    
    # Calculate conflict occurrences and conflict counts
    conflict_occurrences = calculate_conflict_occurrences(timetable)
    conflict_count = calculate_conflict_count(timetable)
    
    # Apply penalties for conflicts
    total_penalty = (conflict_occurrences + conflict_count) 

    # The fitness is inversely proportional to the total penalty
    fitness_score = -total_penalty

    return fitness_score



def generate_sample(courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    timetable = []
    for course in courses:
        hours_needed = hours_per_course[course]
        successfully_scheduled = False
        
        for day in range(1, weekdays_num + 1):
            if successfully_scheduled:
                break
            for room in rooms:
                if room_capacities[room] < students_per_course[course]:
                    continue
                for start_hour in range(1, max_lecture_hours - hours_needed + 1):
                    end_hour = start_hour + hours_needed
                    
                    if end_hour  <= max_lecture_hours: 
                        if is_time_slot_available(timetable, room, day, start_hour, end_hour):
                            timetable.append((course, room, day, start_hour, end_hour))  
                            successfully_scheduled = True
                            break
    return timetable



def find_unused_time_slots(timetable, weekdays_num, max_lecture_hours):
    
    all_time_slots = {(day, hour): False for day in range(1, weekdays_num + 1) for hour in range(1, max_lecture_hours + 1)}

    
    for _, _, day, start_hour, end_hour in timetable:
        for hour in range(start_hour, end_hour):
            all_time_slots[(day, hour)] = True

    
    unused_time_slots = []
    for day in range(1, weekdays_num + 1):
        start = None
        for hour in range(1, max_lecture_hours + 1):
            if all_time_slots[(day, hour)] == False:
                if start is None:
                    start = hour
            else:
                if start is not None:
                    unused_time_slots.append((day, start, hour))
                    start = None
        
        if start is not None:
            unused_time_slots.append((day, start, max_lecture_hours + 1))

    return unused_time_slots







def mutate(timetable, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    mutated_timetable = copy.deepcopy(timetable)
    unused_time_slots = find_unused_time_slots(mutated_timetable, weekdays_num, max_lecture_hours)
    
    courses_to_mutate = random.sample(courses, k=random.randint(1, len(courses) // 2))
    
    for course in courses_to_mutate:
        mutated_timetable = [entry for entry in mutated_timetable if entry[0] != course]
        hours_needed = hours_per_course[course]

        shuffled_time_slots = unused_time_slots[:]  
        random.shuffle(shuffled_time_slots)  

        for _ in range(100):  
            day = random.randint(1, weekdays_num)
            room = random.choice(rooms)

            if room_capacities[room] >= students_per_course[course]:
                if shuffled_time_slots:  
                    slot = shuffled_time_slots.pop(0)  
                    day, start, _ = slot  
                else:
                    start = random.randint(1, max_lecture_hours - hours_needed + 1)  
                
                end = start + hours_needed
                if end  <= max_lecture_hours and is_time_slot_available(mutated_timetable, room, day, start, end):
                    mutated_timetable.append((course, room, day, start, end))
                    break  

    return mutated_timetable








    
def simulated_annealing(timetable, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours, max_iterations=100000):
    """Simulated annealing process to optimize the timetable."""
    initial_temp = 100000000
    final_temp = 0.0000001
    alpha = 0.99
    current_temp = initial_temp

    conflicts_history = []  # For distinct conflict counts
    conflict_occurrences_history = []  # For total number of conflict occurrences

    current_solution = timetable
    current_fitness = fitness(current_solution, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)
    best_solution = current_solution
    best_fitness = current_fitness

    iteration = 0
    while current_temp > final_temp and iteration < max_iterations:
        new_solution = mutate(current_solution, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)

        new_fitness = fitness(new_solution, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)

        if new_fitness > current_fitness or random.random() < math.exp((new_fitness - current_fitness) / current_temp):
            current_solution = new_solution
            current_fitness = new_fitness
            if current_fitness > best_fitness:
                best_solution = current_solution
                best_fitness = current_fitness

        current_temp *= alpha
        iteration += 1

        # Update both conflict counts and occurrences
        conflicts_times = calculate_conflict_count(best_solution)
        total_conflicts = calculate_conflict_occurrences(best_solution) 

        conflicts_history.append(conflicts_times)
        conflict_occurrences_history.append(total_conflicts)

    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(conflicts_history, label='Distinct Conflicts')
    plt.plot(conflict_occurrences_history, label='Total Conflict Occurrences')
    plt.xlabel('Iteration')
    plt.ylabel('Count')
    plt.title('Optimization Process Visualization')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return best_solution

# %% [markdown]
# ## Use random allcate method to form a timetable and print it use the function define below

# %%
t = generate_random_sample(courses1, hours_per_course1, students_per_course1, room_capacities, rooms, weekdays_num, max_lecture_hours)
print_timetable_by_room(t, hours_per_course1)
# Out:
# 40GS_13.07:
#   - Course Code: MATH10024A, Tuesday, 2 PM-3 PM
#
# 40GS_Lecture Theatre B:
#   - Course Code: MATH10007, Wednesday, 11 AM-12 PM
#   - Course Code: MATH11177, Friday, 11 AM-1 PM
#   - Course Code: MATH10076, Friday, 3 PM-4 PM
#
# 40GS_Lecture Theatre C:
#   - Course Code: MATH11007, Monday, 11 AM-1 PM
#   - Course Code: MATH10017A, Tuesday, 2 PM-3 PM
#   - Course Code: MATH11235A, Wednesday, 12 PM-1 PM
#   - Course Code: MATH10100A, Wednesday, 2 PM-3 PM
#   - Course Code: MATH10068A, Friday, 11 AM-12 PM
#
# ALR_Classroom 10:
#   - Course Code: MATH11226, Monday, 9 AM-10 AM
#   - Course Code: MATH10010 + MATH11088, Friday, 12 PM-2 PM
#
# ASH_Lecture Theatre 1:
#   - Course Code: MATH10066, Monday, 3 PM-4 PM
#   - Course Code: MATH10065, Friday, 11 AM-1 PM
#   - Course Code: MATH11111, Friday, 3 PM-5 PM
#
# AT_Lecture Theatre 2:
#   - Course Code: MATH10017, Wednesday, 9 AM-10 AM
#   - Course Code: MATH11154, Wednesday, 2 PM-4 PM
# ...

# %% [markdown]
#  ## Use the simulated annealing algorithm to opt the orignal timetable.And print out the timetable after opt and how mant conflict occurrences and the number of conflicting courses. Our goal is to reduce both conflict occurrences and conflicing courses. Also print out unused time slot to check if we have already consider all time slot to reduce conflict occurrences.

# %%
optimized_timetable = simulated_annealing(t,courses1, hours_per_course1, students_per_course1, room_capacities, rooms, weekdays_num=5, max_lecture_hours=10, max_iterations=100000)
print("Optimized class schedule and the number of conflicts：")
print_timetable_by_room(optimized_timetable, hours_per_course1)
conflicts = calculate_conflict_occurrences(optimized_timetable)  # Calculates conflicts based on room and start hour
conflict_occurrences = calculate_conflict_count(optimized_timetable) 
print("conflict occurrences:", conflicts,"number of courses that conflict",conflict_occurrences)
conflicting_courses = find_conflicting_courses(optimized_timetable)
print("Conflicting courses:", conflicting_courses)
unused_slots = find_unused_time_slots1(optimized_timetable, weekdays_num=5, max_lecture_hours=9)
print("Unused Time Slots:")
for slot in unused_slots:
    print(slot)
# Out:
# Optimized class schedule and the number of conflicts：
#
# 40GS_13.07:
#   - Course Code: MATH11220, Tuesday, 10 AM-12 PM
#   - Course Code: MATH11197, Thursday, 4 PM-6 PM
#
# 40GS_Lecture Theatre B:
#   - Course Code: MATH10068A, Monday, 2 PM-3 PM
#   - Course Code: MATH10066, Monday, 5 PM-6 PM
#   - Course Code: MATH10072A, Thursday, 4 PM-5 PM
#
# 40GS_Lecture Theatre C:
#   - Course Code: MATH10095, Wednesday, 1 PM-2 PM
#
# ALR_Classroom 10:
#   - Course Code: MATH10076, Tuesday, 4 PM-5 PM
#   - Course Code: MATH10017A, Thursday, 4 PM-5 PM
#
# ASH_Honours Room 1:
#   - Course Code: MATH10017, Thursday, 10 AM-11 AM
#
# ASH_Honours Room 2:
#   - Course Code: MATH10047, Thursday, 3 PM-4 PM
#
# ASH_Lecture Theatre 1:
#   - Course Code: MATH11199, Monday, 9 AM-10 AM
#   - Course Code: MATH10095A, Thursday, 1 PM-2 PM
#   - Course Code: MATH10098A, Friday, 2 PM-3 PM
#
# AT_Lecture Theatre 2:
#   - Course Code: MATH08072A, Friday, 10 AM-11 AM
#
# AT_Lecture Theatre 5:
# ...

# %% [markdown]
# ## Algorithm of Particle swarm optimization to optimaize the timetable that produce from simulated annealing

# %%
import numpy as np
from concurrent.futures import ThreadPoolExecutor
import copy
import random
import matplotlib.pyplot as plt
import math

def fitness(timetable, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    """
    Calculate the fitness of a timetable, focusing on reducing the number of conflict occurrences and conflict count.
    """
    # Set a penalty for each conflict occurrence and each conflict count
#     conflict_penalty = 1000

    # Calculate conflict occurrences and conflict counts
    conflict_occurrences = calculate_conflict_occurrences(timetable)
    conflict_count = calculate_conflict_count(timetable)
    
    # Apply penalties for conflicts
    total_penalty = (conflict_occurrences + conflict_count) 

    # The fitness is inversely proportional to the total penalty
    fitness_score = -total_penalty

    return fitness_score



class Particle:
    def __init__(self, timetable, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
        self.position = copy.deepcopy(timetable)  # Deep copy to ensure independence
        self.velocity = [0 for _ in timetable]  # Initialize velocity
        self.best_position = copy.deepcopy(timetable)
        self.best_fitness = fitness(timetable, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)




def update_velocity(particle, global_best_position, w, c1, c2, max_velocity=5):
    for i in range(len(particle.velocity)):
        
        cognitive_component = c1 * (0.5 + random.random()) * (particle.best_position[i][3] - particle.position[i][3])
        social_component = c2 * (0.5 + random.random()) * (global_best_position[i][3] - particle.position[i][3])
        velocity_change = w * particle.velocity[i] + cognitive_component + social_component
        particle.velocity[i] = max(-max_velocity, min(max_velocity, velocity_change))
def reinitialize_particle(particle, rooms, weekdays_num, max_lecture_hours, hours_per_course):
    if random.random() < 0.35: 
        new_timetable = generate_sample(courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)
        particle.position = copy.deepcopy(new_timetable)
        particle.velocity = [0 for _ in new_timetable]



def update_position(particle, weekdays_num, max_lecture_hours, hours_per_course, rooms, unused_time_slots):
    for i in range(len(particle.position)):
        course_code, room, day, start_hour, _ = particle.position[i]
        hours_needed = hours_per_course[course_code]

       
        if unused_time_slots:
            chosen_slot = random.choice(unused_time_slots)
            slot_day, start, end = chosen_slot
            
          
            if end - start >= hours_needed:
                new_start_hour = start
                new_end_hour = new_start_hour + hours_needed
              
                if new_end_hour <= max_lecture_hours:
                    particle.position[i] = (course_code, room, slot_day, new_start_hour, new_end_hour)
                    unused_time_slots.remove(chosen_slot)  
                    continue  

      
        new_start_hour = int(round(start_hour + particle.velocity[i]))
     
        new_start_hour = max(1, min(new_start_hour, max_lecture_hours - hours_needed + 1))
        new_end_hour = new_start_hour + hours_needed
       
        if new_end_hour > max_lecture_hours:
            new_end_hour = max_lecture_hours
            new_start_hour = max(1, new_end_hour - hours_needed)

        
        if random.random() < 0.9:
            room = random.choice(rooms)

        
        particle.position[i] = (course_code, room, day, new_start_hour, new_end_hour)






def find_unused_time_slots(timetable, weekdays_num, max_lecture_hours):

    all_time_slots = {(day, hour): False for day in range(1, weekdays_num + 1) for hour in range(1, max_lecture_hours + 1)}

 
    for _, _, day, start_hour, end_hour in timetable:
        for hour in range(start_hour, end_hour):
            all_time_slots[(day, hour)] = True

  
    unused_time_slots = []
    for day in range(1, weekdays_num + 1):
        start = None
        for hour in range(1, max_lecture_hours + 1):
            if all_time_slots[(day, hour)] == False:
                if start is None:
                    start = hour
            else:
                if start is not None:
                    unused_time_slots.append((day, start, hour))
                    start = None
     
        if start is not None:
            unused_time_slots.append((day, start, max_lecture_hours + 1))

    return unused_time_slots


def local_search(particle, hours_per_course, weekdays_num, max_lecture_hours):

    for i in range(len(particle.position)):
        course_code, room, day, start_hour, end_hour = particle.position[i]
        hours_needed = hours_per_course[course_code]

      
        if random.random() < 0.5:  
            new_start_hour = start_hour + random.choice([-1, 1])
            new_start_hour = max(1, min(new_start_hour, max_lecture_hours - hours_needed + 1))
            new_end_hour = new_start_hour + hours_needed

           
            if 1 <= new_start_hour <= max_lecture_hours and new_end_hour <= max_lecture_hours:
                particle.position[i] = (course_code, room, day, new_start_hour, new_end_hour)

def update_particle(particle, global_best_position, w, c1, c2, max_velocity, weekdays_num, max_lecture_hours, hours_per_course, rooms, unused_time_slots):
    update_velocity(particle, global_best_position, w, c1, c2, max_velocity)
    update_position(particle, weekdays_num, max_lecture_hours, hours_per_course, rooms, unused_time_slots)
    local_search(particle, hours_per_course, weekdays_num, max_lecture_hours)

def pso_optimize(initial_timetable, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours, num_particles=30, max_iterations=10000, print_frequency=100):
    w_max = 0.9
    w_min = 0.4
    c1 = 2
    c2 = 1
    max_velocity = 5

    particles = [Particle(initial_timetable, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours) for _ in range(num_particles)]
    global_best_position = copy.deepcopy(initial_timetable)
    global_best_fitness = fitness(initial_timetable, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)

    conflicts_history = []
    conflict_occurrences_history = []

    with ThreadPoolExecutor() as executor:
        for iteration in range(max_iterations):
            w = w_max - (w_max - w_min) * (iteration / max_iterations)

            
            futures = [executor.submit(update_particle, particle, global_best_position, w, c1, c2, max_velocity, weekdays_num, max_lecture_hours, hours_per_course, rooms, find_unused_time_slots(particle.position, weekdays_num, max_lecture_hours)) for particle in particles]
            
            
            for future in futures:
                future.result()

           
            for particle in particles:
                current_fitness = fitness(particle.position, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)
                if current_fitness > particle.best_fitness:
                    particle.best_position = copy.deepcopy(particle.position)
                    particle.best_fitness = current_fitness

                if current_fitness > global_best_fitness:
                    global_best_position = copy.deepcopy(particle.position)
                    global_best_fitness = current_fitness

            conflicts = calculate_conflict_count(global_best_position)
            conflict_occurrences = calculate_conflict_occurrences(global_best_position)
            conflicts_history.append(conflicts)
            conflict_occurrences_history.append(conflict_occurrences)


    plt.figure(figsize=(10, 5))
    plt.plot(conflicts_history, label='Distinct Conflicts')
    plt.plot(conflict_occurrences_history, label='Total Conflict Occurrences')
    plt.xlabel('times')
    plt.ylabel('number')
    plt.title('PSO Optimization Process Visualization')
    plt.legend()
    plt.grid(True)
    plt.show()

    return global_best_position

# %% [markdown]
# ## print the result

# %%
final_timetable = pso_optimize(optimized_timetable,hours_per_course1, students_per_course1, room_capacities, rooms, weekdays_num, max_lecture_hours, num_particles=30, max_iterations=10000, print_frequency=100)
print("Optimized class schedule and the number of conflicts：")
print_timetable_by_room(final_timetable, hours_per_course1)
conflicts = calculate_conflict_occurrences(final_timetable)  # Calculates conflicts based on room and start hour
conflict_occurrences = calculate_conflict_count(final_timetable) 
print("conflict occurrences:", conflicts,"number of courses that conflict",conflict_occurrences)
conflicting_courses = find_conflicting_courses(final_timetable)
print("Conflicting courses:", conflicting_courses)
unused_slots = find_unused_time_slots1(final_timetable, weekdays_num=5, max_lecture_hours=9)
print("Unused Time Slots:")
for slot in unused_slots:
    print(slot)
# Out:
# Optimized class schedule and the number of conflicts：
#
# 40GS_13.07:
#   - Course Code: MATH08071A, Monday, 9 AM-10 AM
#   - Course Code: MATH10095A, Friday, 11 AM-12 PM
#
# 40GS_Lecture Theatre C:
#   - Course Code: MATH11187, Monday, 3 PM-5 PM
#   - Course Code: MATH11007, Tuesday, 11 AM-1 PM
#   - Course Code: MATH10100A, Friday, 1 PM-2 PM
#
# 7-8CS_1.01:
#   - Course Code: MATH10082, Friday, 9 AM-10 AM
#   - Course Code: MATH11111, Friday, 4 PM-6 PM
#
# ASH_Honours Room 1:
#   - Course Code: MATH11230, Wednesday, 9 AM-11 AM
#
# ASH_Honours Room 2:
#   - Course Code: MATH10068, Tuesday, 5 PM-6 PM
#
# ASH_Lecture Theatre 1:
#   - Course Code: MATH10098, Monday, 9 AM-10 AM
#   - Course Code: MATH11176, Monday, 9 AM-11 AM
#   - Course Code: MATH10024A, Thursday, 3 PM-4 PM
#
# ASH_Lecture Theatre 3:
#   - Course Code: MATH11053, Wednesday, 9 AM-10 AM
#
# AT_2.05:
#   - Course Code: MATH11226, Monday, 9 AM-10 AM
#   - Course Code: MATH10100, Tuesday, 1 PM-2 PM
#
# ...

# %% [markdown]
# ## Transpose the positions of the two algorithms

# %% [markdown]
# ## First use PSO algorithms

# %%
PSO = pso_optimize(t,hours_per_course1, students_per_course1, room_capacities, rooms, weekdays_num, max_lecture_hours, num_particles=30, max_iterations=10000, print_frequency=100)
print("Optimized class schedule and the number of conflicts：")
print_timetable_by_room(PSO, hours_per_course1)
conflicts = calculate_conflict_occurrences(PSO)  # Calculates conflicts based on room and start hour
conflict_occurrences = calculate_conflict_count(PSO) 
print("conflict occurrences:", conflicts,"number of courses that conflict",conflict_occurrences)
conflicting_courses = find_conflicting_courses(PSO)
print("Conflicting courses:", conflicting_courses)
unused_slots = find_unused_time_slots1(PSO, weekdays_num=5, max_lecture_hours=9)
print("Unused Time Slots:")
for slot in unused_slots:
    print(slot)
# Out:
# Optimized class schedule and the number of conflicts：
#
# 40GS_13.07:
#   - Course Code: MATH08066, Thursday, 12 PM-1 PM
#   - Course Code: MATH08071, Thursday, 4 PM-5 PM
#   - Course Code: MATH10095A, Thursday, 4 PM-5 PM
#   - Course Code: MATH10007A, Friday, 12 PM-1 PM
#
# 40GS_Lecture Theatre B:
#   - Course Code: MATH10066, Monday, 4 PM-5 PM
#   - Course Code: MATH10047A, Friday, 9 AM-10 AM
#   - Course Code: MATH10072, Friday, 9 AM-10 AM
#   - Course Code: MATH08077, Friday, 5 PM-6 PM
#
# 7-8CS_1.01:
#   - Course Code: MATH11236, Monday, 9 AM-10 AM
#   - Course Code: MATH11053, Monday, 2 PM-3 PM
#   - Course Code: MATH11226A, Tuesday, 5 PM-6 PM
#
# ALR_Classroom 10:
#   - Course Code: MATH10047, Friday, 9 AM-10 AM
#
# ASH_Honours Room 2:
#   - Course Code: MATH11230, Tuesday, 9 AM-11 AM
#   - Course Code: MATH08066A, Wednesday, 2 PM-3 PM
#
# ASH_Lecture Theatre 1:
#   - Course Code: MATH08074, Wednesday, 11 AM-12 PM
#   - Course Code: MATH10017A, Thursday, 11 AM-12 PM
#
# ...

# %% [markdown]
# ## Then use simulated annealing algorithms

# %%
SA= simulated_annealing(t,courses1, hours_per_course1, students_per_course1, room_capacities, rooms, weekdays_num=5, max_lecture_hours=10, max_iterations=100000)
print("Optimized class schedule and the number of conflicts：")
print_timetable_by_room(SA, hours_per_course1)
conflicts = calculate_conflict_occurrences(SA)  # Calculates conflicts based on room and start hour
conflict_occurrences = calculate_conflict_count(SA) 
print("conflict occurrences:", conflicts,"number of courses that conflict",conflict_occurrences)
conflicting_courses = find_conflicting_courses(SA)
print("Conflicting courses:", conflicting_courses)
unused_slots = find_unused_time_slots1(SA, weekdays_num=5, max_lecture_hours=9)
print("Unused Time Slots:")
for slot in unused_slots:
    print(slot)
# Out:
# Optimized class schedule and the number of conflicts：
#
# 40GS_Lecture Theatre B:
#   - Course Code: MATH10028A, Tuesday, 3 PM-4 PM
#   - Course Code: MATH10082A, Friday, 1 PM-2 PM
#
# 40GS_Lecture Theatre C:
#   - Course Code: MATH10066A, Monday, 2 PM-3 PM
#   - Course Code: MATH11179, Tuesday, 12 PM-2 PM
#   - Course Code: MATH10066, Tuesday, 5 PM-6 PM
#   - Course Code: MATH10074, Friday, 12 PM-1 PM
#
# ALR_Classroom 10:
#   - Course Code: MATH11154, Tuesday, 4 PM-6 PM
#   - Course Code: MATH11007, Friday, 9 AM-11 AM
#
# ASH_Honours Room 1:
#   - Course Code: MATH10047A, Friday, 12 PM-1 PM
#
# ASH_Lecture Theatre 1:
#   - Course Code: MATH11144A, Monday, 4 PM-5 PM
#   - Course Code: MATH10010 + MATH11088, Tuesday, 12 PM-2 PM
#   - Course Code: MATH10065, Thursday, 4 PM-6 PM
#
# ASH_Lecture Theatre 3:
#   - Course Code: MATH10076A, Thursday, 12 PM-1 PM
#
# AT_Lecture Theatre 2:
#   - Course Code: MATH11236, Monday, 10 AM-11 AM
#   - Course Code: MATH08071, Tuesday, 10 AM-11 AM
# ...

# %% [markdown]
# ## If we can't allcate courses at Wednesday afternoon we need use a new function called Wednesday to add constraints that can't allcate courses at wednesday afternoon and check what will happened.

# %%
import random
import math
import matplotlib.pyplot as plt
import copy
import numpy as np


def fitness(timetable, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    """
    Calculate the fitness of a timetable, focusing on reducing the number of conflict occurrences and conflict count.
    """
    # Set a penalty for each conflict occurrence and each conflict count
    conflict_penalty = 1000

    # Calculate conflict occurrences and conflict counts
    conflict_occurrences = calculate_conflict_occurrences(timetable)
    conflict_count = calculate_conflict_count(timetable)
    
    # Apply penalties for conflicts
    total_penalty = (conflict_occurrences + conflict_count) * conflict_penalty

    # The fitness is inversely proportional to the total penalty
    fitness_score = -total_penalty

    return fitness_score



def generate_sample(courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    timetable = []
    for course in courses:
        hours_needed = hours_per_course[course]
        successfully_scheduled = False
        
        for day in range(1, weekdays_num + 1):
            if successfully_scheduled:
                break
            for room in rooms:
                if room_capacities[room] < students_per_course[course]:
                    continue
                for start_hour in range(1, max_lecture_hours - hours_needed + 1):
                    end_hour = start_hour + hours_needed
                    
                    if day == 3 and (end_hour > 4 and start_hour < 10):
                        continue  
                    if end_hour <= max_lecture_hours and is_time_slot_available(timetable, room, day, start_hour, end_hour):
                        timetable.append((course, room, day, start_hour, end_hour))
                        successfully_scheduled = True
                        break
    return timetable



def find_unused_time_slots(timetable, weekdays_num, max_lecture_hours):
    
    all_time_slots = {(day, hour): False for day in range(1, weekdays_num + 1) for hour in range(1, max_lecture_hours + 1)}

   
    for _, _, day, start_hour, end_hour in timetable:
        for hour in range(start_hour, end_hour):
            all_time_slots[(day, hour)] = True

    # 查找连续的未使用小时，并创建时间段
    unused_time_slots = []
    for day in range(1, weekdays_num + 1):
        start = None
        for hour in range(1, max_lecture_hours + 1):
            if all_time_slots[(day, hour)] == False:
                if start is None:
                    start = hour
            else:
                if start is not None:
                    unused_time_slots.append((day, start, hour))
                    start = None
        # 检查是否有跨越整天的未使用时间段
        if start is not None:
            unused_time_slots.append((day, start, max_lecture_hours + 1))

    return unused_time_slots







def mutate(timetable, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    mutated_timetable = copy.deepcopy(timetable)
    unused_time_slots = find_unused_time_slots(mutated_timetable, weekdays_num, max_lecture_hours)
    
    courses_to_mutate = random.sample(courses, k=random.randint(1, len(courses) // 2))
    
    for course in courses_to_mutate:
        mutated_timetable = [entry for entry in mutated_timetable if entry[0] != course]
        hours_needed = hours_per_course[course]

        shuffled_time_slots = unused_time_slots[:] 
        random.shuffle(shuffled_time_slots) 

        for _ in range(100):  
            day = random.randint(1, weekdays_num)
            room = random.choice(rooms)

            if room_capacities[room] >= students_per_course[course]:
                start = random.randint(1, max_lecture_hours - hours_needed + 1)
                end = start + hours_needed
              
                if day == 3 and (end > 4 and start < 10):
                    continue  
                if end <= max_lecture_hours and is_time_slot_available(mutated_timetable, room, day, start, end):
                    mutated_timetable.append((course, room, day, start, end))
                    break  

    return mutated_timetable








    
def simulated_annealing_Wednesday(timetable, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours, max_iterations=100000):
    """Simulated annealing process to optimize the timetable."""
    initial_temp = 1000000
    final_temp = 0.000001
    alpha = 0.99
    current_temp = initial_temp

    conflicts_history = []  # For distinct conflict counts
    conflict_occurrences_history = []  # For total number of conflict occurrences

    current_solution = timetable
    current_fitness = fitness(current_solution, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)
    best_solution = current_solution
    best_fitness = current_fitness

    iteration = 0
    while current_temp > final_temp and iteration < max_iterations:
        new_solution = mutate(current_solution, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)

        new_fitness = fitness(new_solution, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)

        if new_fitness > current_fitness or random.random() < math.exp((new_fitness - current_fitness) / current_temp):
            current_solution = new_solution
            current_fitness = new_fitness
            if current_fitness > best_fitness:
                best_solution = current_solution
                best_fitness = current_fitness

        current_temp *= alpha
        iteration += 1

        # Update both conflict counts and occurrences
        conflicts_times = calculate_conflict_count(best_solution)
        total_conflicts = calculate_conflict_occurrences(best_solution) 

        conflicts_history.append(conflicts_times)
        conflict_occurrences_history.append(total_conflicts)

    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(conflicts_history, label='Distinct Conflicts')
    plt.plot(conflict_occurrences_history, label='Total Conflict Occurrences')
    plt.xlabel('Iteration')
    plt.ylabel('Count')
    plt.title('Optimization Process Visualization')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return best_solution

# %%
W= simulated_annealing_Wednesday(t,courses1, hours_per_course1, students_per_course1, room_capacities, rooms, weekdays_num=5, max_lecture_hours=10, max_iterations=100000)
print("Optimized class schedule and the number of conflicts：")
print_timetable_by_room(W, hours_per_course1)
conflicts = calculate_conflict_occurrences(W)  # Calculates conflicts based on room and start hour
conflict_occurrences = calculate_conflict_count(W) 
print("conflict occurrences:", conflicts,"number of courses that conflict",conflict_occurrences)
conflicting_courses = find_conflicting_courses(W)
print("Conflicting courses:", conflicting_courses)
unused_slots = find_unused_time_slots1(W, weekdays_num=5, max_lecture_hours=9)
print("Unused Time Slots:")
for slot in unused_slots:
    print(slot)
# Out:
# Optimized class schedule and the number of conflicts：
#
# 40GS_Lecture Theatre B:
#   - Course Code: MATH10072A, Monday, 2 PM-3 PM
#   - Course Code: MATH11236, Tuesday, 11 AM-12 PM
#   - Course Code: MATH10007A, Thursday, 9 AM-10 AM
#
# ASH_Lecture Theatre 1:
#   - Course Code: MATH10017A, Monday, 2 PM-3 PM
#   - Course Code: MATH10066A, Thursday, 2 PM-3 PM
#
# ASH_Lecture Theatre 3:
#   - Course Code: MATH11230, Monday, 9 AM-11 AM
#   - Course Code: MATH10053A, Monday, 12 PM-1 PM
#   - Course Code: MATH10082, Thursday, 12 PM-1 PM
#   - Course Code: MATH10099, Friday, 11 AM-12 PM
#   - Course Code: MATH10100A, Friday, 5 PM-6 PM
#
# AT_Lecture Theatre 2:
#   - Course Code: MATH10028A, Thursday, 12 PM-1 PM
#   - Course Code: MATH11007, Thursday, 3 PM-5 PM
#   - Course Code: MATH10082A, Friday, 1 PM-2 PM
#
# AT_Lecture Theatre 3:
#   - Course Code: MATH10013, Monday, 5 PM-6 PM
#   - Course Code: MATH08062, Thursday, 12 PM-2 PM
#   - Course Code: MATH08071, Friday, 2 PM-3 PM
#
# ...

# %% [markdown]
# ## Next apply this to SEM2 lectures

# %% [markdown]
# ## First random allocate courses

# %%
t2 = generate_random_sample(courses2, hours_per_course2, students_per_course2, room_capacities, rooms, weekdays_num, max_lecture_hours)
print_timetable_by_room(t2, hours_per_course2)
# Out:
# 40GS_13.07:
#   - Course Code: MATH11193, Friday, 9 AM-10 AM
#
# 40GS_Lecture Theatre B:
#   - Course Code: MATH08058, Tuesday, 9 AM-10 AM
#   - Course Code: MATH11185B, Thursday, 9 AM-11 AM
#
# 40GS_Lecture Theatre C:
#   - Course Code: MATH10086, Monday, 2 PM-3 PM
#   - Course Code: MATH10093A, Tuesday, 9 AM-11 AM
#   - Course Code: MATH10067, Thursday, 2 PM-3 PM
#
# 7-8CS_1.01:
#   - Course Code: MATH10024A, Friday, 1 PM-3 PM
#
# ALR_Classroom 10:
#   - Course Code: MATH11193B, Thursday, 12 PM-2 PM
#
# ASH_Honours Room 1:
#   - Course Code: MATH11206A, Tuesday, 11 AM-1 PM
#
# ASH_Honours Room 2:
#   - Course Code: MATH11145, Tuesday, 10 AM-11 AM
#   - Course Code: MATH10051A, Friday, 9 AM-11 AM
#
# ASH_Lecture Theatre 1:
#   - Course Code: MATH11188A, Monday, 3 PM-5 PM
#   - Course Code: MATH11197A, Tuesday, 9 AM-11 AM
#   - Course Code: MATH11140, Tuesday, 1 PM-2 PM
#   - Course Code: MATH11140B, Wednesday, 9 AM-11 AM
#   - Course Code: MATH11138A, Thursday, 11 AM-1 PM
#
# ...

# %% [markdown]
# ## use the rest algorithm

# %%
import random
import math
import matplotlib.pyplot as plt
import copy






def fitness(timetable, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    """
    Calculate the fitness of a timetable, focusing on reducing the number of conflict occurrences and conflict count.
    """
    # Set a penalty for each conflict occurrence and each conflict count
    
    # Calculate conflict occurrences and conflict counts
    conflict_occurrences = calculate_conflict_occurrences(timetable)
    conflict_count = calculate_conflict_count(timetable)
    
    # Apply penalties for conflicts
    total_penalty = (conflict_occurrences + conflict_count) 

    # The fitness is inversely proportional to the total penalty
    fitness_score = -total_penalty

    return fitness_score



def generate_sample(courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    timetable = []
    for course in courses:
        hours_needed = hours_per_course[course]
        successfully_scheduled = False
        
        for day in range(1, weekdays_num + 1):
            if successfully_scheduled:
                break
            for room in rooms:
                if room_capacities[room] < students_per_course[course]:
                    continue
                for start_hour in range(1, max_lecture_hours - hours_needed + 1):
                    end_hour = start_hour + hours_needed
                    
                    if end_hour  <= max_lecture_hours: 
                        if is_time_slot_available(timetable, room, day, start_hour, end_hour):
                            timetable.append((course, room, day, start_hour, end_hour))  
                            successfully_scheduled = True
                            break
    return timetable



def find_unused_time_slots(timetable, weekdays_num, max_lecture_hours):
    
    all_time_slots = {(day, hour): False for day in range(1, weekdays_num + 1) for hour in range(1, max_lecture_hours + 1)}

    
    for _, _, day, start_hour, end_hour in timetable:
        for hour in range(start_hour, end_hour):
            all_time_slots[(day, hour)] = True

    
    unused_time_slots = []
    for day in range(1, weekdays_num + 1):
        start = None
        for hour in range(1, max_lecture_hours + 1):
            if all_time_slots[(day, hour)] == False:
                if start is None:
                    start = hour
            else:
                if start is not None:
                    unused_time_slots.append((day, start, hour))
                    start = None
        
        if start is not None:
            unused_time_slots.append((day, start, max_lecture_hours + 1))

    return unused_time_slots







def mutate(timetable, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    mutated_timetable = copy.deepcopy(timetable)
    unused_time_slots = find_unused_time_slots(mutated_timetable, weekdays_num, max_lecture_hours)
    
    courses_to_mutate = random.sample(courses, k=random.randint(1, len(courses) // 2))
    
    for course in courses_to_mutate:
        mutated_timetable = [entry for entry in mutated_timetable if entry[0] != course]
        hours_needed = hours_per_course[course]

        shuffled_time_slots = unused_time_slots[:]  
        random.shuffle(shuffled_time_slots)  

        for _ in range(100):  
            day = random.randint(1, weekdays_num)
            room = random.choice(rooms)

            if room_capacities[room] >= students_per_course[course]:
                if shuffled_time_slots:  
                    slot = shuffled_time_slots.pop(0)  
                    day, start, _ = slot  
                else:
                    start = random.randint(1, max_lecture_hours - hours_needed + 1)  
                
                end = start + hours_needed
                if end  <= max_lecture_hours and is_time_slot_available(mutated_timetable, room, day, start, end):
                    mutated_timetable.append((course, room, day, start, end))
                    break  

    return mutated_timetable








    
def simulated_annealing(timetable, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours, max_iterations=100000):
    """Simulated annealing process to optimize the timetable."""
    initial_temp = 100000000
    final_temp = 0.0000001
    alpha = 0.99
    current_temp = initial_temp

    conflicts_history = []  # For distinct conflict counts
    conflict_occurrences_history = []  # For total number of conflict occurrences

    current_solution = timetable
    current_fitness = fitness(current_solution, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)
    best_solution = current_solution
    best_fitness = current_fitness

    iteration = 0
    while current_temp > final_temp and iteration < max_iterations:
        new_solution = mutate(current_solution, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)

        new_fitness = fitness(new_solution, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)

        if new_fitness > current_fitness or random.random() < math.exp((new_fitness - current_fitness) / current_temp):
            current_solution = new_solution
            current_fitness = new_fitness
            if current_fitness > best_fitness:
                best_solution = current_solution
                best_fitness = current_fitness

        current_temp *= alpha
        iteration += 1

        # Update both conflict counts and occurrences
        conflicts_times = calculate_conflict_count(best_solution)
        total_conflicts = calculate_conflict_occurrences(best_solution) 

        conflicts_history.append(conflicts_times)
        conflict_occurrences_history.append(total_conflicts)

    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(conflicts_history, label='Distinct Conflicts')
    plt.plot(conflict_occurrences_history, label='Total Conflict Occurrences')
    plt.xlabel('Iteration')
    plt.ylabel('Count')
    plt.title('Optimization Process Visualization')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return best_solution

# %%
optimized_timetable2 = simulated_annealing(t2,courses2, hours_per_course2, students_per_course2, room_capacities, rooms, weekdays_num=5, max_lecture_hours=10, max_iterations=100000)
print("Optimized class schedule and the number of conflicts：")
print_timetable_by_room(optimized_timetable2, hours_per_course2)
conflicts = calculate_conflict_occurrences(optimized_timetable2)  # Calculates conflicts based on room and start hour
conflict_occurrences = calculate_conflict_count(optimized_timetable2) 
print("conflict occurrences:", conflicts,"number of courses that conflict",conflict_occurrences)
conflicting_courses = find_conflicting_courses(optimized_timetable2)
print("Conflicting courses:", conflicting_courses)
unused_slots = find_unused_time_slots1(optimized_timetable2, weekdays_num=5, max_lecture_hours=9)
print("Unused Time Slots:")
for slot in unused_slots:
    print(slot)
# Out:
# /tmp/ipykernel_140/3863067793.py:92: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   courses_to_mutate = random.sample(courses, k=random.randint(1, len(courses) // 2))
# Optimized class schedule and the number of conflicts：
#
# 40GS_Lecture Theatre B:
#   - Course Code: MATH08058B_1, Wednesday, 11 AM-1 PM
#   - Course Code: MATH10093, Wednesday, 3 PM-4 PM
#   - Course Code: MATH10064B, Thursday, 12 PM-2 PM
#   - Course Code: MATH10067, Friday, 10 AM-11 AM
#   - Course Code: MATH08058, Friday, 1 PM-2 PM
#
# 40GS_Lecture Theatre C:
#   - Course Code: MATH11140, Monday, 9 AM-10 AM
#   - Course Code: MATH10071, Monday, 5 PM-6 PM
#   - Course Code: MATH10086C, Tuesday, 11 AM-1 PM
#   - Course Code: MATH10060, Wednesday, 9 AM-10 AM
#   - Course Code: MATH10086D, Wednesday, 3 PM-5 PM
#   - Course Code: MATH08058A_1, Friday, 11 AM-1 PM
#
# ALR_Classroom 10:
#   - Course Code: MATH10080, Wednesday, 4 PM-5 PM
# ...

# %%
final_timetable2 = pso_optimize(optimized_timetable2,hours_per_course2, students_per_course2, room_capacities, rooms, weekdays_num, max_lecture_hours, num_particles=30, max_iterations=10000, print_frequency=100)
print("Optimized class schedule and the number of conflicts：")
print_timetable_by_room(final_timetable2, hours_per_course2)
conflicts = calculate_conflict_occurrences(final_timetable2)  # Calculates conflicts based on room and start hour
conflict_occurrences = calculate_conflict_count(final_timetable2) 
print("conflict occurrences:", conflicts,"number of courses that conflict",conflict_occurrences)
conflicting_courses = find_conflicting_courses(final_timetable2)
print("Conflicting courses:", conflicting_courses)
unused_slots = find_unused_time_slots1(final_timetable2, weekdays_num=5, max_lecture_hours=9)
print("Unused Time Slots:")
for slot in unused_slots:
    print(slot)
# Out:
# Optimized class schedule and the number of conflicts：
#
# 40GS_Lecture Theatre B:
#   - Course Code: MATH08058B_1, Wednesday, 11 AM-1 PM
#   - Course Code: MATH10093, Wednesday, 3 PM-4 PM
#   - Course Code: MATH10064B, Thursday, 12 PM-2 PM
#   - Course Code: MATH10067, Friday, 10 AM-11 AM
#   - Course Code: MATH08058, Friday, 1 PM-2 PM
#
# 40GS_Lecture Theatre C:
#   - Course Code: MATH11140, Monday, 9 AM-10 AM
#   - Course Code: MATH10071, Monday, 5 PM-6 PM
#   - Course Code: MATH10086C, Tuesday, 11 AM-1 PM
#   - Course Code: MATH10060, Wednesday, 9 AM-10 AM
#   - Course Code: MATH10086D, Wednesday, 3 PM-5 PM
#   - Course Code: MATH08058A_1, Friday, 11 AM-1 PM
#
# ALR_Classroom 10:
#   - Course Code: MATH10080, Wednesday, 4 PM-5 PM
#   - Course Code: MATH11197A, Thursday, 12 PM-2 PM
#
# ASH_Honours Room 2:
#   - Course Code: MATH11145B, Wednesday, 10 AM-12 PM
#
# ASH_Lecture Theatre 1:
#   - Course Code: MATH10060A, Tuesday, 9 AM-11 AM
# ...

# %% [markdown]
# ## then check what will happened if we can't allocated courses in wednesday afternoon

# %%
import random
import math
import matplotlib.pyplot as plt
import copy
import numpy as np


def fitness(timetable, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    """
    Calculate the fitness of a timetable, focusing on reducing the number of conflict occurrences and conflict count.
    """
    # Set a penalty for each conflict occurrence and each conflict count
    conflict_penalty = 1000

    # Calculate conflict occurrences and conflict counts
    conflict_occurrences = calculate_conflict_occurrences(timetable)
    conflict_count = calculate_conflict_count(timetable)
    
    # Apply penalties for conflicts
    total_penalty = (conflict_occurrences + conflict_count) * conflict_penalty

    # The fitness is inversely proportional to the total penalty
    fitness_score = -total_penalty

    return fitness_score



def generate_sample(courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    timetable = []
    for course in courses:
        hours_needed = hours_per_course[course]
        successfully_scheduled = False
        
        for day in range(1, weekdays_num + 1):
            if successfully_scheduled:
                break
            for room in rooms:
                if room_capacities[room] < students_per_course[course]:
                    continue
                for start_hour in range(1, max_lecture_hours - hours_needed + 1):
                    end_hour = start_hour + hours_needed
                    
                    if day == 3 and (end_hour > 4 and start_hour < 10):
                        continue  
                    if end_hour <= max_lecture_hours and is_time_slot_available(timetable, room, day, start_hour, end_hour):
                        timetable.append((course, room, day, start_hour, end_hour))
                        successfully_scheduled = True
                        break
    return timetable



def find_unused_time_slots(timetable, weekdays_num, max_lecture_hours):
    
    all_time_slots = {(day, hour): False for day in range(1, weekdays_num + 1) for hour in range(1, max_lecture_hours + 1)}

   
    for _, _, day, start_hour, end_hour in timetable:
        for hour in range(start_hour, end_hour):
            all_time_slots[(day, hour)] = True

    # 查找连续的未使用小时，并创建时间段
    unused_time_slots = []
    for day in range(1, weekdays_num + 1):
        start = None
        for hour in range(1, max_lecture_hours + 1):
            if all_time_slots[(day, hour)] == False:
                if start is None:
                    start = hour
            else:
                if start is not None:
                    unused_time_slots.append((day, start, hour))
                    start = None
        # 检查是否有跨越整天的未使用时间段
        if start is not None:
            unused_time_slots.append((day, start, max_lecture_hours + 1))

    return unused_time_slots







def mutate(timetable, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours):
    mutated_timetable = copy.deepcopy(timetable)
    unused_time_slots = find_unused_time_slots(mutated_timetable, weekdays_num, max_lecture_hours)
    
    courses_to_mutate = random.sample(courses, k=random.randint(1, len(courses) // 2))
    
    for course in courses_to_mutate:
        mutated_timetable = [entry for entry in mutated_timetable if entry[0] != course]
        hours_needed = hours_per_course[course]

        shuffled_time_slots = unused_time_slots[:] 
        random.shuffle(shuffled_time_slots) 

        for _ in range(100):  
            day = random.randint(1, weekdays_num)
            room = random.choice(rooms)

            if room_capacities[room] >= students_per_course[course]:
                start = random.randint(1, max_lecture_hours - hours_needed + 1)
                end = start + hours_needed
              
                if day == 3 and (end > 4 and start < 10):
                    continue  
                if end <= max_lecture_hours and is_time_slot_available(mutated_timetable, room, day, start, end):
                    mutated_timetable.append((course, room, day, start, end))
                    break  

    return mutated_timetable








    
def simulated_annealing_Wednesday(timetable, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours, max_iterations=100000):
    """Simulated annealing process to optimize the timetable."""
    initial_temp = 1000000
    final_temp = 0.000001
    alpha = 0.99
    current_temp = initial_temp

    conflicts_history = []  # For distinct conflict counts
    conflict_occurrences_history = []  # For total number of conflict occurrences

    current_solution = timetable
    current_fitness = fitness(current_solution, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)
    best_solution = current_solution
    best_fitness = current_fitness

    iteration = 0
    while current_temp > final_temp and iteration < max_iterations:
        new_solution = mutate(current_solution, courses, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)

        new_fitness = fitness(new_solution, hours_per_course, students_per_course, room_capacities, rooms, weekdays_num, max_lecture_hours)

        if new_fitness > current_fitness or random.random() < math.exp((new_fitness - current_fitness) / current_temp):
            current_solution = new_solution
            current_fitness = new_fitness
            if current_fitness > best_fitness:
                best_solution = current_solution
                best_fitness = current_fitness

        current_temp *= alpha
        iteration += 1

        # Update both conflict counts and occurrences
        conflicts_times = calculate_conflict_count(best_solution)
        total_conflicts = calculate_conflict_occurrences(best_solution) 

        conflicts_history.append(conflicts_times)
        conflict_occurrences_history.append(total_conflicts)

    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(conflicts_history, label='Distinct Conflicts')
    plt.plot(conflict_occurrences_history, label='Total Conflict Occurrences')
    plt.xlabel('Iteration')
    plt.ylabel('Count')
    plt.title('Optimization Process Visualization')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return best_solution

# %%
W2= simulated_annealing_Wednesday(t2,courses2, hours_per_course2, students_per_course2, room_capacities, rooms, weekdays_num=5, max_lecture_hours=10, max_iterations=100000)
print("Optimized class schedule and the number of conflicts：")
print_timetable_by_room(W2, hours_per_course2)
conflicts = calculate_conflict_occurrences(W2)  # Calculates conflicts based on room and start hour
conflict_occurrences = calculate_conflict_count(W2) 
print("conflict occurrences:", conflicts,"number of courses that conflict",conflict_occurrences)
conflicting_courses = find_conflicting_courses(W2)
print("Conflicting courses:", conflicting_courses)
unused_slots = find_unused_time_slots1(W2, weekdays_num=5, max_lecture_hours=9)
print("Unused Time Slots:")
for slot in unused_slots:
    print(slot)
# Out:
# /tmp/ipykernel_140/1023123342.py:91: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   courses_to_mutate = random.sample(courses, k=random.randint(1, len(courses) // 2))
# Optimized class schedule and the number of conflicts：
#
# 40GS_13.07:
#   - Course Code: MATH10024B, Monday, 3 PM-5 PM
#
# 40GS_Lecture Theatre B:
#   - Course Code: MATH11138A, Wednesday, 9 AM-11 AM
#   - Course Code: MATH10093A, Thursday, 9 AM-11 AM
#
# 40GS_Lecture Theatre C:
#   - Course Code: MATH08058B_1, Thursday, 10 AM-12 PM
#
# 7-8CS_1.01:
#   - Course Code: MATH11206, Monday, 4 PM-5 PM
#
# ALR_Classroom 10:
#   - Course Code: MATH11138, Friday, 10 AM-11 AM
#
# ASH_Honours Room 1:
#   - Course Code: MATH10080B, Monday, 10 AM-12 PM
#
# ASH_Honours Room 2:
#   - Course Code: MATH11193, Thursday, 4 PM-5 PM
#
# ASH_Lecture Theatre 1:
#   - Course Code: MATH10060, Tuesday, 2 PM-3 PM
#   - Course Code: MATH10101A, Tuesday, 4 PM-6 PM
# ...
