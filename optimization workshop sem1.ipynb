# %%
import math
import numpy as np
import random
from collections import Counter
import pandas as pd

def generate_sample(courses,hours_per_course,max_lecture_times, rooms_num, weekdays_num, max_lecture_hours): 
    #generate (room, weekday) combination for 9 times
    population = [(room, weekday) for room in range(rooms_num) for weekday in range(weekdays_num) for _ in range(int(max_lecture_hours))]
    
    #initialization timetable
    #course:[(room,weekday)]
    timetable={key:None for key in courses}
    num=0  # Variable to count the total number of scheduled hours
    for i in range(len(courses)):
        pick_hour=hours_per_course[courses[i]] #duration of course
        s_list=[] #sampling list for a course
        for k in range(max_lecture_times[courses[i]]): #worst assignment, greatest number of class for all erolled students
            count_dict = dict(Counter(population)) #(room,weekday):left hours, only available
            count_dict={key: value for key, value in count_dict.items() if value >= pick_hour}# Filter slots that can still accommodate the hours needed for the current course.
            temp_population=[key for key, value in count_dict.items() for _ in range(value)]   # Weight each time slot by its remaining capacity, increasing the chance of being chosen.
            s = random.sample(temp_population, 1)[0] # Randomly select a time slot.
            
            s_list.append(s)# Append the selected slot to the course's list of slots.
            for j in range(pick_hour):# Remove the allocated slot from the population.
                num+=1
                population.remove(s)
        timetable[courses[i]]=s_list# Update the course's list of allocated time slots.
    print("num:",num)
    return timetable,population

def mutation(timetable, courses, variation, unoccupied_time, hours_per_course):
    # Start mutation process by selecting a specific course based on a variation index.
    course = courses[variation]
    # Retrieve the number of hours needed for the course.
    hours = hours_per_course[course]
    # Randomly select a current time slot index for this course to mutate.
    index = random.randint(0, len(timetable[course]) - 1)
    # Count available slots in unoccupied_time that can accommodate the course duration.
    count_dict = dict(Counter(unoccupied_time))
    count_dict = {key: value for key, value in count_dict.items() if value >= hours}
    temp_population = [key for key, value in count_dict.items() for _ in range(value)]
    index_unoccupied = random.randint(0, len(temp_population) - 1)
    
    # Perform the swap of the selected slot with an unoccupied slot.
    temp = timetable[course][index]
    before = len(temp)
    timetable[course][index] = unoccupied_time[index_unoccupied]
    unoccupied_time[index_unoccupied] = temp
    # If the course duration is more than 1 hour, additional slots need to be managed.
    if hours > 1:
        for i in range(hours - 1):
            unoccupied_time.remove(temp)
    after = len(temp)
    # Debugging output to verify the process
    return timetable, unoccupied_time
    
def exchange(timetable, courses, variation_1, variation_2, hours_per_course, unoccupied_time):
    # Select two courses based on variation indices for exchange.
    course_1 = courses[variation_1]
    course_2 = courses[variation_2]
    hour_1 = hours_per_course[course_1]
    hour_2 = hours_per_course[course_2]
    # If both courses have the same duration, a simple swap is possible.
    if hour_1 == hour_2:
        index_1 = random.randint(0, len(timetable[course_1]) - 1)
        index_2 = random.randint(0, len(timetable[course_2]) - 1)
        temp = timetable[course_1][index_1]
        timetable[course_1][index_1] = timetable[course_2][index_2]
        timetable[course_2][index_2] = temp
    else:
        # More complex exchange logic when courses have different durations.
        index_2 = random.randint(0, len(timetable[course_2]) - 1)
        index_1 = random.randint(0, len(timetable[course_1]) - 1)
        rw_1 = timetable[course_1][index_1]
        rw_2 = timetable[course_2][index_2]
        if rw_1 in unoccupied_time:
            index_unoccupied_1 = unoccupied_time.index(rw_1)
        else:
            index_unoccupied_1 = -1
        if rw_2 in unoccupied_time:
            index_unoccupied_2 = unoccupied_time.index(rw_2)
        else:
            index_unoccupied_2 = -1

        # Exchange slots if appropriate conditions are met.
        if hour_1 > hour_2 and index_unoccupied_2 > -1:
            temp = timetable[course_1][index_1]
            timetable[course_1][index_1] = timetable[course_2][index_2]
            timetable[course_2][index_2] = temp
            unoccupied_time.append(temp)
            unoccupied_time.remove(rw_2)
        if hour_1 < hour_2 and index_unoccupied_1 > -1:
            temp = timetable[course_2][index_2]
            timetable[course_2][index_2] = timetable[course_1][index_1]
            timetable[course_1][index_1] = temp
            unoccupied_time.append(temp)
            unoccupied_time.remove(rw_1)
    return timetable, unoccupied_time


def count_lecture_num(lecture_arrangement, students_per_course, course_str, rooms, room_capacities):
    # Start with the total number of students enrolled in the specified course.
    student_left = students_per_course[course_str]
    # Initialize the count of lectures needed to accommodate all students.
    lecture_num = 0
    
    # Iterate through each lecture in the arrangement for the course.
    for lecture in lecture_arrangement:
        # If there are no students left to accommodate, stop the loop.
        if student_left <= 0:
            break
        # Get the room number from the lecture tuple.
        room_num = lecture[0]
        # Find the capacity of the room using the room number.
        room_cap = room_capacities[rooms[room_num]]
        
        # If the remaining students exceed the room's capacity, subtract the capacity from the remaining students.
        if student_left >= room_cap:
            student_left -= room_cap
            lecture_num += 1
            # Output the room and its capacity.
            print(rooms[room_num], ":", room_cap)
        else:
            # If fewer students remain than the room capacity, just account for them.
            if student_left > 0:
                lecture_num += 1
                # Output the room and the number of remaining students.
                print(rooms[room_num], ":", student_left)
                student_left = 0
    # Print the total number of lectures required for the course.
    print(course_str, "number_of_class:", lecture_num)
    return lecture_num

def total_classes_num(courses, timetable, students_per_course, rooms, room_capacities):
    # Initialize the total number of classes across all courses.
    total_num = 0
    
    # Iterate through each course in the list.
    for i in range(len(courses)):
        course_str = courses[i]
        # Retrieve the specific timetable arrangement for the course.
        lecture_arrangement = timetable[course_str]
        # Count the number of classes needed for the course.
        lec_num = count_lecture_num(lecture_arrangement=lecture_arrangement,
                                    students_per_course=students_per_course,
                                    course_str=course_str,
                                    rooms=rooms,
                                    room_capacities=room_capacities)
        # Add the number of classes for this course to the total.
        total_num += lec_num
    # Return the total number of classes for all courses.
    return total_num

# %%
courses = [
    'MATH08062', 'MATH10066', 'MATH11231', 'MATH08077',
    'MATH08057', 'MATH10098', 'MATH11199', 'MATH11029',
    'MATH10099', 'MATH11029+MATH11197', 'MATH10098+MATH10066',
    'MATH10068+MATH08068+MATH10079',
    
    'MATH08071', 'MATH11226', 'MATH11236', 'MATH11177', 'MATH10072', 'MATH10017',
    'MATH11235', 'MATH11153', 'MATH08074', 'MATH10047', 'MATH10065', 'MATH11111',
    'MATH10076', 'MATH11187', 'MATH10074',
    'MATH11053', 'MATH10100', 'MATH10082', 'MATH10013', 'MATH08072',
    'MATH11007', 'MATH08066', 'MATH10024', 'MATH08063',
    'MATH10095', 'MATH11176', 'MATH11154', 'MATH10007', 'MATH10028',
    'MATH11144', 'MATH11179', 'MATH10066A', 
    'MATH11236 + MATH11177', 'MATH11230 + MATH11153', 'MATH10072 + MATH10047',
    'MATH10017 + MATH10065', 'MATH11235 + MATH10076', 'MATH11111 + MATH11187',
    'MATH11226 + MATH10053', 'MATH10082 + MATH11053', 'MATH08066 + MATH10100',
    'MATH10013 + MATH10074', 'MATH08074 + MATH10095', 'MATH08068 + MATH08074',
    'MATH11144 + MATH11179', 'MATH07003 + MATH11154', 'MATH10010 + MATH10053',
    'MATH10098 + MATH10028', 'MATH10024 + MATH10079','MATH10066', 'MATH11231A', 
    'MATH08077A', 'MATH08057A', 'MATH10098A',
    'MATH11199A', 'MATH11029A'
]
students_per_course = {
    'MATH08071': 71, 'MATH11226': 38, 'MATH11236': 22, 'MATH11177': 161, 'MATH10072': 96,
    'MATH10017': 30, 'MATH11235': 35, 'MATH11153': 88, 'MATH08074': 427, 'MATH10047': 25,
    'MATH10065': 216, 'MATH11111': 174, 'MATH10076': 54, 'MATH11187': 138, 'MATH10074': 97,
    'MATH10066A': 308, 'MATH11231A': 32, 'MATH08077A': 180, 'MATH11053': 13, 'MATH08057A': 585,
    'MATH10100': 33, 'MATH10082': 25, 'MATH10013': 60, 'MATH08072': 141, 'MATH11007': 78,
    'MATH10098A': 145, 'MATH08066': 458, 'MATH10024': 7, 'MATH11199A': 228, 'MATH08063': 452,
    'MATH10095': 262, 'MATH11176': 140, 'MATH11154': 79, 'MATH11029A': 59, 'MATH10007': 149,
    'MATH10028': 58, 'MATH11144': 5, 'MATH11179': 29, 'MATH11236 + MATH11177':161,'MATH11230 + MATH11153': 88, 
    'MATH10072 + MATH10047': 96, 'MATH10017 + MATH10065': 216, 'MATH11235 + MATH10076': 54, 
    'MATH11111 + MATH11187': 174, 'MATH11226 + MATH10053': 50, 'MATH10082 + MATH11053': 25, 
    'MATH08066 + MATH10100': 458, 'MATH10013 + MATH10074': 97, 'MATH08074 + MATH10095': 427, 
    'MATH08068 + MATH08074': 427, 'MATH11144 + MATH11179': 29, 'MATH07003 + MATH11154': 248, 
    'MATH10010 + MATH10053': 53, 'MATH10098 + MATH10028': 145, 'MATH10024 + MATH10079': 50,'MATH08062': 57, 'MATH10066': 308, 'MATH11231': 32, 'MATH08077': 180, 'MATH08057': 585,
    'MATH10098': 145, 'MATH11199': 228, 'MATH11029': 59, 'MATH10099': 43,
    'MATH11029+MATH11197': 59, 'MATH10098+MATH10066': 300, 'MATH10068+MATH08068+MATH10079': 274
}
hours_per_course = {
    'MATH08071': 1, 'MATH11226': 1, 'MATH11236': 1, 'MATH11177': 1, 'MATH10072': 1,
    'MATH10017': 1, 'MATH11235': 1, 'MATH11153': 1, 'MATH08074': 1, 'MATH10047': 1,
    'MATH10065': 1, 'MATH11111': 1, 'MATH10076': 1, 'MATH11187': 1, 'MATH10074': 1,
    'MATH10066A': 1, 'MATH11231A': 1, 'MATH08077A': 1, 'MATH11053': 1, 'MATH08057A': 1,
    'MATH10100': 1, 'MATH10082': 1, 'MATH10013': 1, 'MATH08072': 1, 'MATH11007': 1,
    'MATH10098A': 1, 'MATH08066': 1, 'MATH10024': 1, 'MATH11199A': 1, 'MATH08063': 1,
    'MATH10095': 1, 'MATH11176': 1, 'MATH11154': 1, 'MATH11029A': 1, 'MATH10007': 1,
    'MATH10028': 1, 'MATH11144': 1, 'MATH11179': 1, 'MATH11236 + MATH11177':1 ,'MATH11230 + MATH11153': 1,
    'MATH10072 + MATH10047': 1, 'MATH10017 + MATH10065': 1, 'MATH11235 + MATH10076': 1,
    'MATH11111 + MATH11187': 1, 'MATH11226 + MATH10053': 1, 'MATH10082 + MATH11053': 1,
    'MATH08066 + MATH10100': 1, 'MATH10013 + MATH10074': 1, 'MATH08074 + MATH10095': 1,
    'MATH08068 + MATH08074': 1, 'MATH11144 + MATH11179': 1, 'MATH07003 + MATH11154': 1,
    'MATH10010 + MATH10053': 1, 'MATH10098 + MATH10028': 1, 'MATH10024 + MATH10079': 1,
    'MATH08062': 2, 'MATH10066': 2, 'MATH11231': 2, 'MATH08077': 2,
    'MATH08057': 2, 'MATH10098': 2, 'MATH11199': 2, 'MATH11029': 2,
    'MATH10099': 2, 'MATH11029+MATH11197': 2, 'MATH10098+MATH10066': 2,
    'MATH10068+MATH08068+MATH10079': 2
}
 

rooms = [
    'JBB_G.69', 'JCMB_2901', 'JCMB_3211 - Teaching Studio', 'JCMB_3212 - Teaching Studio',
    'JCMB_3217 - Teaching Studio', 'MH_1.19', 'MH_G.04', 'MH_G.05', 'MH_G.10', 'MH_G.12',
    'MH_G.13', 'MH_G.30', 'MH_G.31', 'MH_G.32', 'MH_G.33', 'MH_G.34', 'NUC_2.06 - Rowan',
    'SB_7.15', 'SB_7.20', 'AT_M2 - Teaching Studio', '40GS_LG.07 - Teaching Studio',
    '40GS_LG.09', '40GS_LG.11', 'AT_2.12', 'LLTC_2.14 - Teaching Studio',
    'ROB_Hugh Robson Building Computer Lab - 129 cap', '40GS_7.18', '40GS_7.01'
]  
 

room_capacities = {
    'JBB_G.69': 25, 'JCMB_2901': 14, 'JCMB_3211 - Teaching Studio': 24,
    'JCMB_3212 - Teaching Studio': 24, 'JCMB_3217 - Teaching Studio': 84,
    'MH_1.19': 68, 'MH_G.04': 20, 'MH_G.05': 24, 'MH_G.10': 20,
    'MH_G.12': 20, 'MH_G.13': 19, 'MH_G.30': 20, 'MH_G.31': 46,
    'MH_G.32': 28, 'MH_G.33': 20, 'MH_G.34': 24, 'NUC_2.06 - Rowan': 60,
    'SB_7.15': 50, 'SB_7.20': 58, 'AT_M2 - Teaching Studio': 25,
    '40GS_LG.07 - Teaching Studio': 20, '40GS_LG.09': 90, '40GS_LG.11': 60,
    'AT_2.12': 20, 'LLTC_2.14 - Teaching Studio': 36,
    'ROB_Hugh Robson Building Computer Lab - 129 cap': 12, '40GS_7.18': 18, '40GS_7.01': 12
}

# %%
max_lecture_hours=9# Maximum number of lecture hours that can be scheduled in a single day

weekdays_num = 5# Total number of weekdays for scheduling (Monday to Friday)

mutation_time=10#number of new timetable

total_mutation=500#mutation and exchange
date={0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4:'Friday'}

# %%
# Determine the total number of rooms available based on the length of the 'rooms' list or array.
rooms_num = len(rooms)

# Determine the total number of courses based on the length of the 'courses' list or array.
courses_num = len(courses)

# Calculate the minimum capacity among all rooms. This is the smallest number of students that any room can accommodate.
min_cap_room = min(room_capacities.values())

# Calculate the maximum number of lecture times for each course. This is determined by dividing the total number of students per course
# by the minimum capacity room and rounding up. This gives the minimum number of sessions needed for each course if only the smallest room were used.
max_lecture_times = {key: math.ceil(value / min_cap_room) for key, value in students_per_course.items()}

# Generate a sample timetable and a list of unoccupied time slots. This involves creating a (room, weekday) combination for each available room
# and weekday for the maximum number of lecture hours specified.
timetable, unoccupied_time = generate_sample(courses=courses, hours_per_course=hours_per_course,
                                             max_lecture_times=max_lecture_times, rooms_num=rooms_num, 
                                             weekdays_num=weekdays_num, max_lecture_hours=max_lecture_hours)
# Out:
# num: 1128

# %%
pre_timetable=timetable
pre_timetable
# Out:
# {'MATH08062': [(22, 3), (4, 2), (19, 0), (8, 0), (15, 1)],
#  'MATH10066': [(17, 4),
#   (1, 4),
#   (11, 1),
#   (12, 3),
#   (2, 0),
#   (26, 2),
#   (22, 0),
#   (3, 1),
#   (20, 1),
#   (26, 0),
#   (8, 4),
#   (2, 3),
#   (6, 0),
#   (2, 2),
#   (3, 3),
#   (15, 2),
#   (4, 1),
#   (0, 0),
#   (15, 0),
#   (5, 1),
#   (1, 1),
#   (6, 1),
#   (2, 0),
#   (16, 1),
#   (21, 2),
#   (10, 1)],
#  'MATH11231': [(11, 3), (26, 3), (2, 2)],
#  'MATH08077': [(5, 0),
#   (10, 0),
#   (11, 4),
#   (25, 3),
#   (7, 1),
#   (27, 0),
#   (2, 4),
#   (6, 4),
#   (10, 4),
#   (9, 4),
#   (25, 3),
#   (15, 1),
#   (4, 3),
#   (2, 3),
#   (1, 3)],
#  'MATH08057': [(15, 1),
#   (22, 1),
#   (9, 4),
#   (19, 1),
#   (22, 3),
#   (17, 3),
#   (11, 4),
#   (11, 0),
#   (3, 3),
#   (0, 1),
#   (12, 0),
#   (17, 1),
#   (20, 4),
#   (23, 1),
#   (11, 1),
#   (24, 2),
#   (8, 0),
#   (19, 2),
#   (17, 4),
#   (24, 1),
#   (22, 4),
#   (13, 4),
#   (16, 2),
#   (27, 2),
#   (13, 4),
#   (7, 2),
#   (6, 2),
#   (13, 3),
#   (1, 3),
#   (1, 3),
#   (7, 4),
#   (26, 4),
#   (9, 3),
#   (16, 4),
#   (5, 1),
#   (12, 2),
#   (15, 2),
#   (27, 1),
#   (18, 0),
#   (4, 1),
#   (16, 4),
#   (22, 2),
#   (16, 0),
#   (17, 3),
#   (14, 2),
#   (24, 4),
#   (26, 4),
#   (6, 3),
#   (17, 2)],
#  'MATH10098': [(2, 1),
#   (11, 4),
#   (3, 4),
#   (16, 4),
#   (20, 0),
#   (10, 4),
#   (11, 0),
#   (13, 4),
#   (3, 0),
#   (1, 0),
#   (10, 3),
#   (1, 0),
#   (13, 1)],
#  'MATH11199': [(8, 1),
#   (0, 3),
#   (19, 4),
#   (21, 4),
#   (9, 1),
#   (20, 1),
#   (3, 2),
#   (9, 4),
#   (21, 1),
#   (2, 2),
#   (9, 1),
#   (22, 2),
#   (12, 3),
#   (12, 2),
#   (16, 0),
#   (10, 0),
#   (9, 1),
#   (11, 3),
#   (5, 0)],
#  'MATH11029': [(9, 4), (12, 1), (14, 4), (10, 4), (14, 1)],
#  'MATH10099': [(24, 2), (18, 4), (11, 3), (17, 0)],
#  'MATH11029+MATH11197': [(12, 0), (12, 1), (16, 1), (2, 4), (20, 2)],
#  'MATH10098+MATH10066': [(14, 3),
#   (7, 0),
#   (24, 1),
#   (13, 1),
#   (18, 1),
#   (26, 3),
#   (25, 1),
#   (4, 2),
#   (6, 2),
#   (24, 0),
#   (15, 4),
#   (21, 3),
#   (16, 4),
#   (10, 2),
#   (16, 3),
#   (26, 1),
#   (13, 2),
#   (17, 2),
#   (6, 2),
#   (15, 0),
#   (18, 1),
#   (20, 3),
#   (24, 2),
#   (15, 3),
#   (20, 1)],
#  'MATH10068+MATH08068+MATH10079': [(15, 4),
#   (1, 2),
#   (23, 0),
#   (4, 4),
#   (23, 4),
#   (26, 0),
#   (0, 2),
#   (10, 2),
#   (20, 3),
#   (8, 4),
#   (27, 3),
#   (21, 4),
#   (26, 1),
#   (25, 4),
#   (27, 2),
#   (17, 2),
#   (19, 0),
#   (5, 1),
#   (13, 3),
#   (16, 1),
#   (7, 3),
#   (21, 4),
#   (10, 3)],
#  'MATH08071': [(20, 3), (23, 2), (15, 0), (7, 3), (3, 1), (8, 2)],
#  'MATH11226': [(12, 3), (24, 2), (13, 1), (24, 1)],
#  'MATH11236': [(20, 0), (14, 2)],
#  'MATH11177': [(13, 2),
#   (9, 3),
#   (18, 2),
#   (12, 2),
#   (20, 1),
#   (3, 3),
#   (26, 3),
#   (20, 3),
#   (27, 2),
#   (22, 0),
#   (10, 1),
#   (18, 4),
#   (9, 2),
#   (13, 3)],
#  'MATH10072': [(8, 3),
#   (25, 4),
#   (18, 3),
#   (21, 0),
#   (23, 3),
#   (20, 1),
#   (5, 1),
#   (7, 0)],
#  'MATH10017': [(12, 1), (11, 1), (25, 3)],
#  'MATH11235': [(14, 0), (20, 4), (5, 4)],
#  'MATH11153': [(18, 3),
#   (19, 4),
#   (26, 1),
#   (9, 3),
#   (18, 2),
#   (8, 1),
#   (16, 0),
#   (1, 2)],
#  'MATH08074': [(0, 0),
#   (3, 3),
#   (5, 3),
#   (3, 4),
#   (14, 0),
#   (10, 2),
#   (23, 4),
#   (3, 1),
#   (16, 0),
#   (5, 3),
#   (21, 0),
#   (12, 2),
#   (24, 3),
#   (4, 0),
#   (12, 4),
#   (26, 0),
#   (0, 1),
#   (10, 3),
#   (17, 4),
#   (9, 2),
#   (10, 3),
#   (14, 3),
#   (14, 0),
#   (15, 2),
#   (8, 4),
#   (6, 1),
#   (19, 4),
#   (16, 0),
#   (24, 0),
#   (23, 3),
#   (6, 3),
#   (5, 3),
#   (6, 1),
#   (19, 4),
#   (4, 1),
#   (3, 0)],
#  'MATH10047': [(27, 4), (11, 3), (5, 3)],
#  'MATH10065': [(6, 3),
#   (22, 4),
#   (12, 0),
#   (9, 0),
#   (22, 1),
#   (8, 2),
#   (20, 4),
#   (18, 1),
#   (27, 1),
#   (17, 2),
#   (19, 0),
#   (23, 3),
#   (13, 1),
#   (17, 2),
#   (24, 3),
#   (1, 2),
#   (16, 2),
#   (18, 0)],
#  'MATH11111': [(23, 2),
#   (26, 2),
#   (3, 2),
#   (22, 3),
#   (26, 1),
#   (2, 1),
#   (14, 1),
#   (27, 3),
#   (21, 1),
#   (20, 2),
#   (13, 2),
#   (26, 4),
#   (5, 1),
#   (10, 0),
#   (7, 3)],
#  'MATH10076': [(22, 2), (5, 2), (0, 1), (7, 0), (21, 0)],
#  'MATH11187': [(6, 0),
#   (27, 3),
#   (9, 2),
#   (0, 1),
#   (14, 2),
#   (17, 3),
#   (2, 2),
#   (23, 3),
#   (27, 1),
#   (24, 0),
#   (25, 4),
#   (23, 2)],
#  'MATH10074': [(20, 2),
#   (7, 1),
#   (15, 0),
#   (14, 4),
#   (19, 1),
#   (26, 4),
#   (10, 0),
#   (15, 3),
#   (21, 3)],
#  'MATH11053': [(9, 0), (27, 1)],
#  'MATH10100': [(21, 3), (14, 4), (24, 4)],
#  'MATH10082': [(19, 1), (1, 1), (10, 2)],
#  'MATH10013': [(6, 1), (25, 2), (22, 2), (11, 1), (0, 4)],
#  'MATH08072': [(6, 3),
#   (14, 1),
#   (21, 3),
#   (1, 0),
#   (1, 4),
#   (13, 0),
#   (2, 3),
#   (2, 1),
#   (9, 0),
#   (24, 4),
#   (19, 3),
#   (7, 3)],
#  'MATH11007': [(0, 0), (4, 1), (19, 2), (25, 4), (20, 0), (15, 2), (4, 4)],
#  'MATH08066': [(20, 1),
#   (23, 2),
#   (22, 0),
#   (5, 0),
#   (6, 3),
#   (0, 2),
#   (7, 2),
#   (27, 2),
#   (11, 2),
#   (23, 2),
#   (7, 1),
#   (26, 0),
#   (18, 3),
#   (24, 3),
#   (25, 1),
#   (25, 4),
#   (9, 3),
#   (3, 3),
#   (24, 4),
#   (1, 3),
#   (6, 4),
#   (10, 4),
#   (1, 4),
#   (17, 4),
#   (9, 1),
#   (14, 4),
#   (26, 4),
#   (27, 0),
#   (25, 2),
#   (8, 4),
#   (17, 1),
#   (16, 0),
#   (0, 0),
#   (4, 4),
#   (1, 1),
#   (9, 2),
#   (15, 4),
#   (6, 4),
#   (4, 3)],
#  'MATH10024': [(25, 3)],
#  'MATH08063': [(25, 4),
#   (8, 0),
#   (19, 3),
#   (9, 0),
#   (11, 0),
#   (4, 3),
#   (4, 3),
#   (8, 1),
#   (6, 1),
#   (2, 0),
#   (14, 0),
#   (13, 3),
#   (23, 0),
#   (25, 0),
#   (5, 2),
#   (22, 0),
#   (26, 0),
#   (25, 0),
#   (5, 0),
#   (27, 3),
#   (27, 3),
#   (12, 4),
#   (8, 4),
#   (10, 2),
#   (2, 1),
#   (6, 2),
#   (12, 0),
#   (14, 3),
#   (23, 4),
#   (5, 2),
#   (27, 4),
#   (19, 0),
#   (5, 3),
#   (1, 4),
#   (25, 2),
#   (7, 0),
#   (26, 2),
#   (0, 4)],
#  'MATH10095': [(3, 4),
#   (2, 0),
#   (24, 0),
#   (19, 4),
#   (7, 2),
#   (19, 2),
#   (15, 3),
#   (26, 1),
#   (8, 4),
#   (13, 1),
#   (5, 4),
#   (11, 1),
#   (19, 4),
#   (0, 4),
#   (9, 1),
#   (6, 0),
#   (10, 1),
#   (0, 2),
#   (19, 0),
#   (24, 0),
#   (25, 1),
#   (4, 0)],
#  'MATH11176': [(26, 3),
#   (14, 4),
#   (7, 1),
#   (21, 2),
#   (3, 0),
#   (5, 0),
#   (2, 1),
#   (4, 3),
#   (2, 0),
#   (20, 2),
#   (9, 1),
#   (21, 1)],
#  'MATH11154': [(6, 2), (17, 1), (22, 3), (26, 0), (8, 1), (4, 2), (4, 1)],
#  'MATH10007': [(20, 3),
#   (17, 3),
#   (21, 2),
#   (4, 0),
#   (22, 0),
#   (6, 4),
#   (21, 2),
#   (13, 3),
#   (12, 0),
#   (12, 1),
#   (25, 0),
#   (3, 1),
#   (14, 3)],
#  'MATH10028': [(17, 3), (2, 3), (25, 1), (2, 4), (16, 2)],
#  'MATH11144': [(11, 4)],
#  'MATH11179': [(7, 1), (16, 3), (9, 2)],
#  'MATH10066A': [(8, 2),
#   (13, 0),
#   (16, 2),
#   (17, 0),
#   (20, 0),
#   (22, 0),
#   (6, 0),
#   (23, 4),
#   (22, 4),
#   (19, 3),
#   (20, 3),
#   (1, 0),
#   (27, 4),
#   (14, 0),
#   (20, 4),
#   (6, 3),
#   (1, 3),
#   (12, 4),
#   (21, 4),
#   (3, 0),
#   (23, 4),
#   (5, 2),
#   (1, 1),
#   (2, 1),
#   (14, 1),
#   (9, 0)],
#  'MATH11236 + MATH11177': [(12, 3),
#   (12, 4),
#   (0, 4),
#   (27, 4),
#   (16, 0),
#   (24, 1),
#   (24, 4),
#   (0, 4),
#   (26, 0),
#   (15, 2),
#   (19, 0),
#   (27, 1),
#   (18, 3),
#   (6, 4)],
#  'MATH11230 + MATH11153': [(18, 0),
#   (13, 0),
#   (0, 3),
#   (19, 4),
#   (17, 0),
#   (14, 0),
#   (14, 0),
#   (7, 0)],
#  'MATH10072 + MATH10047': [(5, 4),
#   (18, 1),
#   (15, 4),
#   (6, 0),
#   (23, 1),
#   (17, 0),
#   (17, 1),
#   (19, 1)],
#  'MATH10017 + MATH10065': [(23, 3),
#   (19, 1),
#   (21, 0),
#   (13, 3),
#   (0, 1),
#   (18, 4),
#   (6, 1),
#   (14, 1),
#   (11, 3),
#   (24, 2),
#   (8, 1),
#   (3, 1),
#   (16, 2),
#   (0, 0),
#   (4, 4),
#   (0, 4),
#   (3, 4),
#   (5, 3)],
#  'MATH11235 + MATH10076': [(23, 4), (7, 4), (5, 2), (1, 4), (7, 3)],
#  'MATH11111 + MATH11187': [(15, 2),
#   (8, 1),
#   (20, 0),
#   (10, 0),
#   (2, 3),
#   (12, 4),
#   (6, 4),
#   (26, 4),
#   (16, 2),
#   (8, 2),
#   (12, 0),
#   (18, 2),
#   (4, 1),
#   (22, 4),
#   (15, 0)],
#  'MATH11226 + MATH10053': [(11, 1), (27, 3), (16, 3), (25, 0), (23, 1)],
#  'MATH10082 + MATH11053': [(21, 0), (5, 3), (27, 3)],
#  'MATH08066 + MATH10100': [(6, 1),
#   (15, 2),
#   (17, 1),
#   (24, 1),
#   (4, 2),
#   (17, 3),
#   (12, 4),
#   (25, 0),
#   (8, 0),
#   (14, 2),
#   (14, 3),
#   (17, 4),
#   (7, 0),
#   (2, 1),
#   (23, 3),
#   (13, 1),
#   (11, 2),
#   (10, 0),
#   (2, 2),
#   (10, 2),
#   (12, 0),
#   (24, 1),
#   (12, 3),
#   (5, 0),
#   (25, 1),
#   (5, 1),
#   (5, 0),
#   (12, 2),
#   (0, 3),
#   (10, 2),
#   (12, 2),
#   (26, 2),
#   (25, 0),
#   (11, 1),
#   (19, 2),
#   (27, 3),
#   (18, 0),
#   (4, 3),
#   (19, 1)],
#  'MATH10013 + MATH10074': [(7, 4),
#   (3, 2),
#   (9, 4),
#   (22, 3),
#   (13, 0),
#   (1, 2),
#   (27, 4),
#   (17, 0),
#   (3, 2)],
#  'MATH08074 + MATH10095': [(16, 3),
#   (11, 2),
#   (2, 3),
#   (0, 3),
#   (23, 2),
#   (0, 1),
#   (27, 0),
#   (27, 2),
#   (8, 0),
#   (11, 3),
#   (5, 4),
#   (6, 4),
#   (3, 3),
#   (10, 1),
#   (11, 0),
#   (0, 2),
#   (23, 4),
#   (19, 2),
#   (13, 3),
#   (22, 4),
#   (3, 2),
#   (23, 2),
#   (5, 3),
#   (3, 2),
#   (7, 3),
#   (2, 2),
#   (9, 0),
#   (25, 0),
#   (5, 4),
#   (8, 3),
#   (24, 3),
#   (16, 2),
#   (19, 0),
#   (14, 3),
#   (25, 2),
#   (20, 2)],
#  'MATH08068 + MATH08074': [(27, 0),
#   (4, 0),
#   (7, 0),
#   (0, 0),
#   (14, 2),
#   (1, 1),
#   (26, 2),
#   (16, 3),
#   (10, 1),
#   (15, 1),
#   (4, 4),
#   (4, 0),
#   (19, 3),
#   (17, 0),
#   (3, 0),
#   (21, 4),
#   (13, 4),
#   (4, 0),
#   (11, 2),
#   (16, 1),
#   (18, 0),
#   (22, 4),
#   (6, 1),
#   (18, 3),
#   (25, 2),
#   (14, 4),
#   (8, 4),
#   (23, 4),
#   (10, 3),
#   (26, 1),
#   (18, 0),
#   (2, 0),
#   (3, 2),
#   (1, 0),
#   (7, 4),
#   (10, 1)],
#  'MATH11144 + MATH11179': [(6, 0), (11, 0), (1, 1)],
#  'MATH07003 + MATH11154': [(23, 3),
#   (18, 3),
#   (25, 1),
#   (6, 3),
#   (19, 3),
#   (15, 0),
#   (0, 4),
#   (7, 4),
#   (22, 4),
#   (6, 4),
#   (24, 4),
#   (13, 2),
#   (27, 1),
#   (15, 1),
#   (7, 0),
#   (2, 0),
#   (27, 2),
#   (11, 2),
#   (8, 2),
#   (0, 0),
#   (1, 4)],
#  'MATH10010 + MATH10053': [(4, 2), (14, 1), (13, 0), (23, 1), (11, 4)],
#  'MATH10098 + MATH10028': [(10, 3),
#   (1, 0),
#   (15, 1),
#   (9, 2),
#   (19, 2),
#   (3, 1),
#   (23, 1),
#   (9, 0),
#   (17, 3),
#   (8, 3),
#   (20, 3),
#   (20, 4),
#   (23, 2)],
#  'MATH10024 + MATH10079': [(8, 3), (20, 2), (9, 3), (14, 1), (2, 1)],
#  'MATH11231A': [(3, 4), (27, 1), (14, 0)],
#  'MATH08077A': [(10, 1),
#   (27, 1),
#   (25, 2),
#   (18, 3),
#   (4, 2),
#   (20, 0),
#   (21, 3),
#   (13, 2),
#   (7, 2),
#   (16, 2),
#   (23, 3),
#   (22, 3),
#   (13, 2),
#   (21, 1),
#   (21, 1)],
#  'MATH08057A': [(3, 4),
#   (26, 2),
#   (14, 4),
#   (9, 0),
#   (14, 3),
#   (3, 2),
#   (21, 1),
#   (27, 2),
#   (25, 3),
#   (5, 2),
#   (17, 1),
#   (3, 4),
#   (0, 3),
#   (17, 0),
#   (16, 3),
#   (7, 4),
#   (18, 2),
#   (27, 4),
#   (16, 3),
#   (8, 3),
#   (9, 2),
#   (4, 3),
#   (23, 0),
#   (4, 0),
#   (11, 2),
#   (23, 3),
#   (25, 0),
#   (4, 0),
#   (22, 4),
#   (13, 4),
#   (7, 1),
#   (27, 0),
#   (8, 2),
#   (21, 1),
#   (21, 2),
#   (6, 0),
#   (16, 3),
#   (10, 3),
#   (3, 4),
#   (21, 2),
#   (22, 3),
#   (0, 2),
#   (8, 1),
#   (12, 1),
#   (14, 2),
#   (5, 3),
#   (21, 0),
#   (19, 3),
#   (24, 1)],
#  'MATH10098A': [(27, 0),
#   (7, 2),
#   (14, 2),
#   (18, 3),
#   (4, 0),
#   (26, 4),
#   (6, 0),
#   (7, 3),
#   (27, 0),
#   (22, 1),
#   (8, 1),
#   (22, 2),
#   (18, 3)],
#  'MATH11199A': [(20, 2),
#   (9, 2),
#   (22, 2),
#   (14, 4),
#   (20, 4),
#   (21, 2),
#   (11, 2),
#   (4, 2),
#   (18, 2),
#   (0, 2),
#   (13, 0),
#   (0, 2),
#   (1, 1),
#   (5, 2),
#   (23, 1),
#   (15, 3),
#   (8, 0),
#   (8, 0),
#   (13, 1)],
#  'MATH11029A': [(20, 0), (18, 1), (14, 0), (27, 0), (23, 0)]}

# %%
# Generate a list of all possible room and weekday combinations.
room_timetable = [(room, weekday) for room in range(rooms_num) for weekday in range(weekdays_num)]

# Create a dictionary to map each room-weekday pair to a list that will contain course data.
room_timetable_dict = {key: [] for key in room_timetable}

# Populate the room_timetable_dict with course and hour information from a predefined timetable.
for course in pre_timetable:
    arrangement_list = pre_timetable[course]
    for room_date in arrangement_list:
        # Each entry in the room's timetable includes the course and the number of hours it takes.
        course_time = (course, hours_per_course[course])
        room_timetable_dict[room_date].append(course_time)

# Iterate through each room-weekday combination to display the scheduled courses.
for rt in room_timetable:
    # Print the room number and the day it's being used.
    print(rooms[rt[0]], ":")
    # Initialize 'k' to calculate the starting time for the first class of the day at 9 AM.
    k = 0
    # Process each class scheduled in this room on this day.
    for one_class in room_timetable_dict[rt]:
        # Prepare the display string with course code and the specific day.
        first_part = "  - Course Code: " + one_class[0] + ", " + "Day " + str(rt[1] + 1) + ", "
        # Calculate starting and ending times for the class based on its duration.
        second_part = [9 + k, 9 + k + one_class[1]]
        # Convert times to a 12-hour format with AM/PM notation.
        for j in range(2):
            if second_part[j] < 12:
                second_part[j] = str(second_part[j]) + "AM"
            elif second_part[j] == 12:
                second_part[j] = "12PM"
            else:
                second_part[j] = str(second_part[j] % 12) + "PM"
        # Append the duration of the class to the display string.
        third_part = "(" + str(one_class[1]) + "h)"
        # Update 'k' with the ending time of the current class to start the next class at the correct time.
        k += one_class[1]
        # Print the formatted information for this class.
        print(first_part + second_part[0] + "-" + second_part[1] + third_part)
# Out:
# JBB_G.69 :
#   - Course Code: MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH11007, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08066, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 1, 4PM-5PM(1h)
# JBB_G.69 :
#   - Course Code: MATH08057, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10076, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH11187, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 3PM-4PM(1h)
# JBB_G.69 :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH11199A, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 3, 4PM-5PM(1h)
# JBB_G.69 :
#   - Course Code: MATH11199, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11230 + MATH11153, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 4, 2PM-3PM(1h)
# JBB_G.69 :
#   - Course Code: MATH10013, Day 5, 9AM-10AM(1h)
#   - Course Code: MATH08063, Day 5, 10AM-11AM(1h)
#   - Course Code: MATH10095, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 5, 3PM-4PM(1h)
# JCMB_2901 :
#   - Course Code: MATH10098, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10098, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08072, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10066A, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 1, 4PM-5PM(1h)
# JCMB_2901 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10082, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11144 + MATH11179, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 2, 4PM-5PM(1h)
# JCMB_2901 :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11153, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10065, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 3, 1PM-2PM(1h)
# JCMB_2901 :
#   - Course Code: MATH08077, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH08057, Day 4, 1PM-3PM(2h)
#   - Course Code: MATH08066, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10066A, Day 4, 4PM-5PM(1h)
# JCMB_2901 :
#   - Course Code: MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08072, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11235 + MATH10076, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 5, 3PM-4PM(1h)
# JCMB_3211 - Teaching Studio :
#   - Course Code: MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10066, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08063, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10095, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH11176, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 1, 5PM-6PM(1h)
# JCMB_3211 - Teaching Studio :
#   - Course Code: MATH10098, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11111, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH08072, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH11176, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10066A, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH10024 + MATH10079, Day 2, 5PM-6PM(1h)
# JCMB_3211 - Teaching Studio :
#   - Course Code: MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11231, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH11199, Day 3, 1PM-3PM(2h)
#   - Course Code: MATH11187, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 5PM-6PM(1h)
# JCMB_3211 - Teaching Studio :
#   - Course Code: MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08077, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH08072, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10028, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 4PM-5PM(1h)
# JCMB_3211 - Teaching Studio :
#   - Course Code: MATH08077, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH11029+MATH11197, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH10028, Day 5, 1PM-2PM(1h)
# JCMB_3212 - Teaching Studio :
#   - Course Code: MATH10098, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH11176, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 2PM-3PM(1h)
# JCMB_3212 - Teaching Studio :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08071, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH08074, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10007, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 2, 3PM-4PM(1h)
# JCMB_3212 - Teaching Studio :
#   - Course Code: MATH11199, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11111, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 3, 5PM-6PM(1h)
# JCMB_3212 - Teaching Studio :
#   - Course Code: MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH11177, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08074, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08066, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 4PM-5PM(1h)
# JCMB_3212 - Teaching Studio :
#   - Course Code: MATH10098, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11231A, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 5, 5PM-6PM(1h)
# JCMB_3217 - Teaching Studio :
#   - Course Code: MATH08074, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH10095, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH10007, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 1, 5PM-6PM(1h)
# JCMB_3217 - Teaching Studio :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH11007, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11154, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 2, 4PM-5PM(1h)
# JCMB_3217 - Teaching Studio :
#   - Course Code: MATH08062, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH11154, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH10010 + MATH10053, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH08077A, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH11199A, Day 3, 5PM-6PM(1h)
# JCMB_3217 - Teaching Studio :
#   - Course Code: MATH08077, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11176, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 4, 4PM-5PM(1h)
# JCMB_3217 - Teaching Studio :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH11007, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 2PM-3PM(1h)
# MH_1.19 :
#   - Course Code: MATH08077, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08066, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH11176, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 5PM-6PM(1h)
# MH_1.19 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH10072, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH11111, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 5PM-6PM(1h)
# MH_1.19 :
#   - Course Code: MATH10076, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH08063, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH08063, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10066A, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH11235 + MATH10076, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH11199A, Day 3, 3PM-4PM(1h)
# MH_1.19 :
#   - Course Code: MATH08074, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH08074, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH08074, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH10047, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10082 + MATH11053, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 4, 5PM-6PM(1h)
# MH_1.19 :
#   - Course Code: MATH11235, Day 5, 9AM-10AM(1h)
#   - Course Code: MATH10095, Day 5, 10AM-11AM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 1PM-2PM(1h)
# MH_G.04 :
#   - Course Code: MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11187, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH11144 + MATH11179, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 1, 5PM-6PM(1h)
# MH_G.04 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH08074, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10013, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 5PM-6PM(1h)
# MH_G.04 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH10098+MATH10066, Day 3, 1PM-3PM(2h)
#   - Course Code: MATH08063, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11154, Day 3, 4PM-5PM(1h)
# MH_G.04 :
#   - Course Code: MATH08057, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH10065, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08072, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08066, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10066A, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 4, 4PM-5PM(1h)
# MH_G.04 :
#   - Course Code: MATH08077, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH10007, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 5, 5PM-6PM(1h)
# MH_G.05 :
#   - Course Code: MATH10098+MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10072, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH10076, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 1, 5PM-6PM(1h)
# MH_G.05 :
#   - Course Code: MATH08077, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10074, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH11176, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH11179, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 2, 3PM-4PM(1h)
# MH_G.05 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08077A, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10098A, Day 3, 2PM-3PM(1h)
# MH_G.05 :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08071, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH11111, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08072, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11235 + MATH10076, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10098A, Day 4, 4PM-5PM(1h)
# MH_G.05 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH11235 + MATH10076, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 5, 3PM-4PM(1h)
# MH_G.10 :
#   - Course Code: MATH08062, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08063, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH11199A, Day 1, 5PM-6PM(1h)
# MH_G.10 :
#   - Course Code: MATH11199, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11153, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH11154, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 2, 5PM-6PM(1h)
# MH_G.10 :
#   - Course Code: MATH08071, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH10065, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH10066A, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 3, 2PM-3PM(1h)
# MH_G.10 :
#   - Course Code: MATH10072, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH10024 + MATH10079, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08057A, Day 4, 1PM-2PM(1h)
# MH_G.10 :
#   - Course Code: MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08066, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08063, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH10095, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 5PM-6PM(1h)
# MH_G.12 :
#   - Course Code: MATH10065, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH11053, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH08072, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 1, 4PM-5PM(1h)
# MH_G.12 :
#   - Course Code: MATH11199, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH11199, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH08066, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH10095, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH11176, Day 2, 5PM-6PM(1h)
# MH_G.12 :
#   - Course Code: MATH11177, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH08074, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH11187, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH11179, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 3, 4PM-5PM(1h)
# MH_G.12 :
#   - Course Code: MATH08057, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH11153, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08066, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10024 + MATH10079, Day 4, 2PM-3PM(1h)
# MH_G.12 :
#   - Course Code: MATH08077, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH11199, Day 5, 1PM-3PM(2h)
#   - Course Code: MATH11029, Day 5, 3PM-5PM(2h)
#   - Course Code: MATH10013 + MATH10074, Day 5, 5PM-6PM(1h)
# MH_G.13 :
#   - Course Code: MATH08077, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH11111, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10074, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 4PM-5PM(1h)
# MH_G.13 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08077A, Day 2, 4PM-5PM(1h)
# MH_G.13 :
#   - Course Code: MATH10098+MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10082, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08063, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 5PM-6PM(1h)
# MH_G.13 :
#   - Course Code: MATH10098, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08074, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 4, 5PM-6PM(1h)
# MH_G.13 :
#   - Course Code: MATH08077, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10098, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH11029, Day 5, 1PM-3PM(2h)
#   - Course Code: MATH08066, Day 5, 3PM-4PM(1h)
# MH_G.30 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10098, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08063, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH11144 + MATH11179, Day 1, 3PM-4PM(1h)
# MH_G.30 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10017, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10013, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10095, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH11226 + MATH10053, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 5PM-6PM(1h)
# MH_G.30 :
#   - Course Code: MATH08066, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH11199A, Day 3, 3PM-4PM(1h)
# MH_G.30 :
#   - Course Code: MATH11231, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH10099, Day 4, 1PM-3PM(2h)
#   - Course Code: MATH10047, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 5PM-6PM(1h)
# MH_G.30 :
#   - Course Code: MATH08077, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH10098, Day 5, 1PM-3PM(2h)
#   - Course Code: MATH11144, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH10010 + MATH10053, Day 5, 4PM-5PM(1h)
# MH_G.31 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11029+MATH11197, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH10065, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10007, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 5PM-6PM(1h)
# MH_G.31 :
#   - Course Code: MATH11029, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11029+MATH11197, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10017, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10007, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 2, 3PM-4PM(1h)
# MH_G.31 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH11177, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08074, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 4PM-5PM(1h)
# MH_G.31 :
#   - Course Code: MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH11226, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 3PM-4PM(1h)
# MH_G.31 :
#   - Course Code: MATH08074, Day 5, 9AM-10AM(1h)
#   - Course Code: MATH08063, Day 5, 10AM-11AM(1h)
#   - Course Code: MATH10066A, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 5, 2PM-3PM(1h)
# MH_G.32 :
#   - Course Code: MATH08072, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH10066A, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10010 + MATH10053, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH11199A, Day 1, 2PM-3PM(1h)
# MH_G.32 :
#   - Course Code: MATH10098, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH11226, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10065, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10095, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH11199A, Day 2, 5PM-6PM(1h)
# MH_G.32 :
#   - Course Code: MATH10098+MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH11111, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08077A, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08077A, Day 3, 3PM-4PM(1h)
# MH_G.32 :
#   - Course Code: MATH08057, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH11177, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10007, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 5PM-6PM(1h)
# MH_G.32 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH10098, Day 5, 1PM-3PM(2h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 5, 4PM-5PM(1h)
# MH_G.33 :
#   - Course Code: MATH11235, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH08074, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH08074, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH11231A, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH11029A, Day 1, 5PM-6PM(1h)
# MH_G.33 :
#   - Course Code: MATH11029, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11111, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH08072, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10010 + MATH10053, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH10024 + MATH10079, Day 2, 4PM-5PM(1h)
# MH_G.33 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11236, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH11187, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH10098A, Day 3, 4PM-5PM(1h)
# MH_G.33 :
#   - Course Code: MATH10098+MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH10007, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 4, 4PM-5PM(1h)
# MH_G.33 :
#   - Course Code: MATH11029, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10074, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10100, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08066, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11176, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH11199A, Day 5, 5PM-6PM(1h)
# MH_G.34 :
#   - Course Code: MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08071, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10074, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 1, 4PM-5PM(1h)
# MH_G.34 :
#   - Course Code: MATH08062, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08077, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH08057, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 2, 5PM-6PM(1h)
# MH_G.34 :
#   - Course Code: MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH11007, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 5PM-6PM(1h)
# MH_G.34 :
#   - Course Code: MATH10098+MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10074, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH11199A, Day 4, 1PM-2PM(1h)
# MH_G.34 :
#   - Course Code: MATH10098+MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH08066, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 5, 2PM-3PM(1h)
# NUC_2.06 - Rowan :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH11153, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08074, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08066, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 1, 5PM-6PM(1h)
# NUC_2.06 - Rowan :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11029+MATH11197, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 3PM-4PM(1h)
# NUC_2.06 - Rowan :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10065, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10028, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH08077A, Day 3, 5PM-6PM(1h)
# NUC_2.06 - Rowan :
#   - Course Code: MATH10098+MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11179, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH11226 + MATH10053, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 4, 5PM-6PM(1h)
# NUC_2.06 - Rowan :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH10098, Day 5, 1PM-3PM(2h)
#   - Course Code: MATH10098+MATH10066, Day 5, 3PM-5PM(2h)
# SB_7.15 :
#   - Course Code: MATH10099, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10066A, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 1, 4PM-5PM(1h)
# SB_7.15 :
#   - Course Code: MATH08057, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH11154, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 2, 3PM-4PM(1h)
# SB_7.15 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 1PM-3PM(2h)
#   - Course Code: MATH10065, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH10065, Day 3, 4PM-5PM(1h)
# SB_7.15 :
#   - Course Code: MATH08057, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH11187, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10007, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10028, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 4, 5PM-6PM(1h)
# SB_7.15 :
#   - Course Code: MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08066, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 5, 3PM-4PM(1h)
# SB_7.20 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10065, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 3PM-4PM(1h)
# SB_7.20 :
#   - Course Code: MATH10098+MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10065, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11029A, Day 2, 3PM-4PM(1h)
# SB_7.20 :
#   - Course Code: MATH11177, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH11153, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08057A, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH11199A, Day 3, 1PM-2PM(1h)
# SB_7.20 :
#   - Course Code: MATH10072, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH11153, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH08066, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08077A, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10098A, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 4, 5PM-6PM(1h)
# SB_7.20 :
#   - Course Code: MATH10099, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 5, 12PM-1PM(1h)
# AT_M2 - Teaching Studio :
#   - Course Code: MATH08062, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH10065, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10095, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 5PM-6PM(1h)
# AT_M2 - Teaching Studio :
#   - Course Code: MATH08057, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10074, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10082, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 3PM-4PM(1h)
# AT_M2 - Teaching Studio :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11007, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 3, 3PM-4PM(1h)
# AT_M2 - Teaching Studio :
#   - Course Code: MATH08072, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH08063, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH10066A, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 4, 2PM-3PM(1h)
# AT_M2 - Teaching Studio :
#   - Course Code: MATH11199, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH11153, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08074, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08074, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10095, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH10095, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 5, 4PM-5PM(1h)
# 40GS_LG.07 - Teaching Studio :
#   - Course Code: MATH10098, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11236, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH11007, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08077A, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH11029A, Day 1, 4PM-5PM(1h)
# 40GS_LG.07 - Teaching Studio :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10098+MATH10066, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH11177, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH10072, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08066, Day 2, 5PM-6PM(1h)
# 40GS_LG.07 - Teaching Studio :
#   - Course Code: MATH11029+MATH11197, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11111, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10074, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH11176, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH10024 + MATH10079, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 3, 4PM-5PM(1h)
# 40GS_LG.07 - Teaching Studio :
#   - Course Code: MATH10098+MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH08071, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11177, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10007, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10066A, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 4, 5PM-6PM(1h)
# 40GS_LG.07 - Teaching Studio :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH11235, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10065, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH11199A, Day 5, 3PM-4PM(1h)
# 40GS_LG.09 :
#   - Course Code: MATH10072, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH08074, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH10076, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10082 + MATH11053, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 1, 2PM-3PM(1h)
# 40GS_LG.09 :
#   - Course Code: MATH11199, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11111, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH11176, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08077A, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08077A, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 2, 4PM-5PM(1h)
# 40GS_LG.09 :
#   - Course Code: MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11176, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10007, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH10007, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 3, 4PM-5PM(1h)
# 40GS_LG.09 :
#   - Course Code: MATH10098+MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10074, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH10100, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08072, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08077A, Day 4, 2PM-3PM(1h)
# 40GS_LG.09 :
#   - Course Code: MATH11199, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 5, 1PM-3PM(2h)
#   - Course Code: MATH10066A, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 4PM-5PM(1h)
# 40GS_LG.11 :
#   - Course Code: MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10007, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10066A, Day 1, 3PM-4PM(1h)
# 40GS_LG.11 :
#   - Course Code: MATH08057, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10065, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10098A, Day 2, 12PM-1PM(1h)
# 40GS_LG.11 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH10076, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10013, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH10098A, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 3, 4PM-5PM(1h)
# 40GS_LG.11 :
#   - Course Code: MATH08062, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH11111, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11154, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08077A, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 4, 5PM-6PM(1h)
# 40GS_LG.11 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10065, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10066A, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 5, 5PM-6PM(1h)
# AT_2.12 :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH08063, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08057A, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH11029A, Day 1, 1PM-2PM(1h)
# AT_2.12 :
#   - Course Code: MATH08057, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10072 + MATH10047, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH11226 + MATH10053, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10010 + MATH10053, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11199A, Day 2, 3PM-4PM(1h)
# AT_2.12 :
#   - Course Code: MATH08071, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH11111, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH11187, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08066, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 3, 4PM-5PM(1h)
# AT_2.12 :
#   - Course Code: MATH10072, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH08074, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH10065, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH11187, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08077A, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 4, 5PM-6PM(1h)
# AT_2.12 :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10066A, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH11235 + MATH10076, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 5PM-6PM(1h)
# LLTC_2.14 - Teaching Studio :
#   - Course Code: MATH10098+MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH11187, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10095, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10095, Day 1, 2PM-3PM(1h)
# LLTC_2.14 - Teaching Studio :
#   - Course Code: MATH08057, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH11226, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 2, 5PM-6PM(1h)
# LLTC_2.14 - Teaching Studio :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10099, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH10098+MATH10066, Day 3, 1PM-3PM(2h)
#   - Course Code: MATH11226, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 3, 4PM-5PM(1h)
# LLTC_2.14 - Teaching Studio :
#   - Course Code: MATH08074, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH10065, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH08066, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 12PM-1PM(1h)
# LLTC_2.14 - Teaching Studio :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10100, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08072, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08066, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 5, 3PM-4PM(1h)
# ROB_Hugh Robson Building Computer Lab - 129 cap :
#   - Course Code: MATH08063, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH08063, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH10007, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH11226 + MATH10053, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 1, 4PM-5PM(1h)
# ROB_Hugh Robson Building Computer Lab - 129 cap :
#   - Course Code: MATH10098+MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10028, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 2, 3PM-4PM(1h)
# ROB_Hugh Robson Building Computer Lab - 129 cap :
#   - Course Code: MATH10013, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH08066, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH08063, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08077A, Day 3, 2PM-3PM(1h)
# ROB_Hugh Robson Building Computer Lab - 129 cap :
#   - Course Code: MATH08077, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08077, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH10017, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10024, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 4, 3PM-4PM(1h)
# ROB_Hugh Robson Building Computer Lab - 129 cap :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10072, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH11187, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH11007, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08066, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08063, Day 5, 3PM-4PM(1h)
# 40GS_7.18 :
#   - Course Code: MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08066, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08063, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH11154, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 1, 5PM-6PM(1h)
# 40GS_7.18 :
#   - Course Code: MATH10098+MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH11153, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH11111, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10095, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 4PM-5PM(1h)
# 40GS_7.18 :
#   - Course Code: MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11111, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 3, 3PM-4PM(1h)
# 40GS_7.18 :
#   - Course Code: MATH11231, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH11177, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11176, Day 4, 2PM-3PM(1h)
# 40GS_7.18 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH11111, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10074, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08066, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 5, 5PM-6PM(1h)
# 40GS_7.01 :
#   - Course Code: MATH08077, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10098A, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH10098A, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH11029A, Day 1, 5PM-6PM(1h)
# 40GS_7.01 :
#   - Course Code: MATH08057, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10065, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH11187, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH11053, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH11231A, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08077A, Day 2, 5PM-6PM(1h)
# 40GS_7.01 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH11177, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08066, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 3, 5PM-6PM(1h)
# 40GS_7.01 :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11111, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH11187, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH11226 + MATH10053, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10082 + MATH11053, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 5PM-6PM(1h)
# 40GS_7.01 :
#   - Course Code: MATH10047, Day 5, 9AM-10AM(1h)
#   - Course Code: MATH08063, Day 5, 10AM-11AM(1h)
#   - Course Code: MATH10066A, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 5, 2PM-3PM(1h)

# %%
# Initialize a list to store the number of classes for each course.
total_classes = []
# Iterate over each course based on the total number of courses.
for i in range(courses_num):
    # Calculate the number of classes needed for each course using the count_lecture_num function.
    class_n = count_lecture_num(
        lecture_arrangement=timetable[courses[i]],
        students_per_course=students_per_course,
        course_str=courses[i],
        rooms=rooms,
        room_capacities=room_capacities
    )
    # Append the result to the list of total classes.
    total_classes.append(class_n)

# Print the total number of classes for each course.
print("total_class:", total_classes)

# Calculate the sum of all classes required for all courses and print it.
sum_total_classes = sum(total_classes)
print("Sum of all classes:", sum_total_classes)
# Out:
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# SB_7.15 : 50
# JCMB_2901 : 14
# MH_G.30 : 20
# MH_G.31 : 46
# JCMB_3211 - Teaching Studio : 24
# 40GS_7.18 : 18
# 40GS_LG.11 : 60
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_7.18 : 18
# MH_G.10 : 14
# MATH10066 number_of_class: 11
# MH_G.30 : 20
# 40GS_7.18 : 12
# MATH11231 number_of_class: 2
# MH_1.19 : 68
# MH_G.13 : 19
# MH_G.30 : 20
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# 40GS_7.01 : 12
# JCMB_3211 - Teaching Studio : 24
# MH_G.04 : 1
# MATH08077 number_of_class: 8
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# SB_7.15 : 20
# MATH08057 number_of_class: 19
# JCMB_3211 - Teaching Studio : 24
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# NUC_2.06 - Rowan : 60
# 40GS_LG.07 - Teaching Studio : 17
# MATH10098 number_of_class: 5
# MH_G.10 : 20
# JBB_G.69 : 25
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 90
# MH_G.12 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 4
# MATH11199 number_of_class: 8
# MH_G.12 : 20
# MH_G.31 : 39
# MATH11029 number_of_class: 2
# LLTC_2.14 - Teaching Studio : 36
# SB_7.20 : 7
# MATH10099 number_of_class: 2
# MH_G.31 : 46
# MH_G.31 : 13
# MATH11029+MATH11197 number_of_class: 2
# MH_G.33 : 20
# MH_G.05 : 24
# LLTC_2.14 - Teaching Studio : 36
# MH_G.32 : 28
# SB_7.20 : 58
# 40GS_7.18 : 18
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# JCMB_3217 - Teaching Studio : 84
# MH_G.04 : 20
# MATH10098+MATH10066 number_of_class: 9
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# JBB_G.69 : 25
# MH_G.13 : 19
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.10 : 20
# 40GS_7.01 : 10
# MATH10068+MATH08068+MATH10079 number_of_class: 11
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.34 : 24
# MH_G.05 : 7
# MATH08071 number_of_class: 4
# MH_G.31 : 38
# MATH11226 number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 2
# MATH11236 number_of_class: 2
# MH_G.32 : 28
# MH_G.12 : 20
# SB_7.20 : 58
# MH_G.31 : 46
# 40GS_LG.07 - Teaching Studio : 9
# MATH11177 number_of_class: 5
# MH_G.10 : 20
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# SB_7.20 : 58
# 40GS_LG.09 : 6
# MATH10072 number_of_class: 4
# MH_G.31 : 30
# MATH10017 number_of_class: 1
# MH_G.33 : 20
# 40GS_LG.07 - Teaching Studio : 15
# MATH11235 number_of_class: 2
# SB_7.20 : 58
# AT_M2 - Teaching Studio : 25
# 40GS_7.18 : 5
# MATH11153 number_of_class: 3
# JBB_G.69 : 25
# JCMB_3212 - Teaching Studio : 24
# MH_1.19 : 68
# JCMB_3212 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.13 : 19
# AT_2.12 : 20
# JCMB_3212 - Teaching Studio : 24
# NUC_2.06 - Rowan : 60
# MH_1.19 : 68
# 40GS_LG.09 : 75
# MATH08074 number_of_class: 11
# 40GS_7.01 : 12
# MH_G.30 : 13
# MATH10047 number_of_class: 2
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# 40GS_LG.11 : 60
# MH_G.10 : 10
# MATH10065 number_of_class: 6
# AT_2.12 : 20
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 60
# 40GS_7.18 : 18
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 10
# MATH11111 number_of_class: 7
# 40GS_LG.11 : 54
# MATH10076 number_of_class: 1
# MH_G.04 : 20
# 40GS_7.01 : 12
# MH_G.12 : 20
# JBB_G.69 : 25
# MH_G.33 : 20
# SB_7.15 : 41
# MATH11187 number_of_class: 6
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.05 : 24
# MH_G.34 : 24
# MH_G.33 : 20
# AT_M2 - Teaching Studio : 9
# MATH10074 number_of_class: 5
# MH_G.12 : 13
# MATH11053 number_of_class: 1
# 40GS_LG.09 : 33
# MATH10100 number_of_class: 1
# AT_M2 - Teaching Studio : 25
# MATH10082 number_of_class: 1
# MH_G.04 : 20
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_LG.11 : 28
# MATH10013 number_of_class: 3
# MH_G.04 : 20
# MH_G.33 : 20
# 40GS_LG.09 : 90
# JCMB_2901 : 11
# MATH08072 number_of_class: 4
# JBB_G.69 : 25
# JCMB_3217 - Teaching Studio : 53
# MATH11007 number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_1.19 : 68
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# 40GS_7.01 : 12
# MH_G.30 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.12 : 9
# MATH08066 number_of_class: 17
# ROB_Hugh Robson Building Computer Lab - 129 cap : 7
# MATH10024 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# AT_2.12 : 20
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_1.19 : 43
# MATH08063 number_of_class: 15
# JCMB_3212 - Teaching Studio : 24
# JCMB_3211 - Teaching Studio : 24
# LLTC_2.14 - Teaching Studio : 36
# AT_M2 - Teaching Studio : 25
# MH_G.05 : 24
# AT_M2 - Teaching Studio : 25
# MH_G.34 : 24
# 40GS_7.18 : 18
# MH_G.10 : 20
# MH_G.32 : 28
# MH_1.19 : 14
# MATH10095 number_of_class: 11
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_G.05 : 24
# 40GS_LG.09 : 78
# MATH11176 number_of_class: 4
# MH_G.04 : 20
# SB_7.15 : 50
# 40GS_LG.11 : 9
# MATH11154 number_of_class: 3
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.09 : 79
# MATH10007 number_of_class: 3
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# MH_G.30 : 5
# MATH11144 number_of_class: 1
# MH_G.05 : 24
# NUC_2.06 - Rowan : 5
# MATH11179 number_of_class: 2
# MH_G.10 : 20
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 30
# MATH10066A number_of_class: 9
# MH_G.31 : 46
# MH_G.31 : 46
# JBB_G.69 : 25
# 40GS_7.01 : 12
# NUC_2.06 - Rowan : 32
# MATH11236 + MATH11177 number_of_class: 5
# SB_7.20 : 58
# MH_G.32 : 28
# JBB_G.69 : 2
# MATH11230 + MATH11153 number_of_class: 3
# MH_1.19 : 68
# SB_7.20 : 28
# MATH10072 + MATH10047 number_of_class: 2
# AT_2.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 90
# MH_G.32 : 28
# JBB_G.69 : 25
# SB_7.20 : 28
# MATH10017 + MATH10065 number_of_class: 6
# AT_2.12 : 20
# MH_G.05 : 24
# MH_1.19 : 10
# MATH11235 + MATH10076 number_of_class: 3
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.13 : 19
# JCMB_3211 - Teaching Studio : 24
# MH_G.31 : 46
# MH_G.04 : 20
# 40GS_7.18 : 1
# MATH11111 + MATH11187 number_of_class: 8
# MH_G.30 : 20
# 40GS_7.01 : 12
# NUC_2.06 - Rowan : 18
# MATH11226 + MATH10053 number_of_class: 3
# 40GS_LG.09 : 25
# MATH10082 + MATH11053 number_of_class: 1
# MH_G.04 : 20
# MH_G.34 : 24
# SB_7.15 : 50
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# JCMB_3211 - Teaching Studio : 2
# MATH08066 + MATH10100 number_of_class: 14
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# 40GS_LG.11 : 29
# MATH10013 + MATH10074 number_of_class: 4
# NUC_2.06 - Rowan : 60
# MH_G.30 : 20
# JCMB_3211 - Teaching Studio : 24
# JBB_G.69 : 25
# AT_2.12 : 20
# JBB_G.69 : 25
# 40GS_7.01 : 12
# 40GS_7.01 : 12
# MH_G.10 : 20
# MH_G.30 : 20
# MH_1.19 : 68
# MH_G.04 : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.13 : 19
# MH_G.30 : 20
# JBB_G.69 : 25
# AT_2.12 : 13
# MATH08074 + MATH10095 number_of_class: 17
# 40GS_7.01 : 12
# JCMB_3217 - Teaching Studio : 84
# MH_G.05 : 24
# JBB_G.69 : 25
# MH_G.33 : 20
# JCMB_2901 : 14
# 40GS_7.18 : 18
# NUC_2.06 - Rowan : 60
# MH_G.13 : 19
# MH_G.34 : 24
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 43
# MATH08068 + MATH08074 number_of_class: 12
# MH_G.04 : 20
# MH_G.30 : 9
# MATH11144 + MATH11179 number_of_class: 2
# AT_2.12 : 20
# SB_7.20 : 58
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.04 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.34 : 24
# JBB_G.69 : 25
# MH_G.05 : 24
# 40GS_LG.11 : 40
# MATH07003 + MATH11154 number_of_class: 9
# JCMB_3217 - Teaching Studio : 53
# MATH10010 + MATH10053 number_of_class: 1
# MH_G.13 : 19
# JCMB_2901 : 14
# MH_G.34 : 24
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# JCMB_3212 - Teaching Studio : 24
# AT_2.12 : 19
# MATH10098 + MATH10028 number_of_class: 7
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.12 : 10
# MATH10024 + MATH10079 number_of_class: 3
# SB_7.15 : 50
# JCMB_2901 : 14
# MH_G.30 : 20
# MH_G.31 : 46
# JCMB_3211 - Teaching Studio : 24
# 40GS_7.18 : 18
# 40GS_LG.11 : 60
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_7.18 : 18
# MH_G.10 : 14
# MATH10066 number_of_class: 11
# JCMB_3212 - Teaching Studio : 24
# 40GS_7.01 : 8
# MATH11231A number_of_class: 2
# MH_G.13 : 19
# 40GS_7.01 : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 79
# MATH08077A number_of_class: 5
# JCMB_3212 - Teaching Studio : 24
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_G.12 : 20
# MH_G.33 : 20
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.09 : 90
# 40GS_7.01 : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_1.19 : 68
# SB_7.15 : 50
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# SB_7.15 : 50
# NUC_2.06 - Rowan : 60
# MH_G.05 : 24
# SB_7.20 : 44
# MATH08057A number_of_class: 17
# 40GS_7.01 : 12
# MH_G.05 : 24
# MH_G.33 : 20
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 31
# MATH10098A number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.12 : 20
# 40GS_LG.11 : 60
# MH_G.33 : 20
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.09 : 88
# MATH11199A number_of_class: 6
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.20 : 39
# MATH11029A number_of_class: 2
# total_class: [1, 11, 2, 8, 19, 5, 8, 2, 2, 2, 9, 11, 4, 1, 2, 5, 4, 1, 2, 3, 11, 2, 6, 7, 1, 6, 5, 1, 1, 1, 3, 4, 2, 17, 1, 15, 11, 4, 3, 3, 2, 1, 2, 9, 5, 3, 2, 6, 3, 8, 3, 1, 14, 4, 17, 12, 2, 9, 1, 7, 3, 11, 2, 5, 17, 5, 6, 2]
# Sum of all classes: 368

# %%
# Initialize the total decrease in the number of class sessions.
total_decrease = 0

# Iterate over the total number of mutations specified.
for i in range(total_mutation):
    # Randomly select two courses for potential mutation or exchange.
    variation_1 = random.randint(0, len(courses) - 1)
    variation_2 = random.randint(0, len(courses) - 1)

    if variation_1 == variation_2:
        # If the same course is selected twice, perform a self-mutation.
        print("mutation")
        mutation_list = []
        class_num = []

        # Perform the mutation multiple times (as per mutation_time) and store the results.
        for i in range(mutation_time):
            course_str = courses[variation_1]
            timetable_temp, unoccupied_time_temp = mutation(timetable=timetable,
                                                            courses=courses,
                                                            variation=variation_1,
                                                            unoccupied_time=unoccupied_time,
                                                            hours_per_course=hours_per_course)
            # Count the number of classes for the mutated timetable.
            class_num.append(count_lecture_num(lecture_arrangement=timetable_temp[course_str],
                                               students_per_course=students_per_course,
                                               course_str=course_str,
                                               rooms=rooms,
                                               room_capacities=room_capacities))
            mutation_list.append((timetable_temp, unoccupied_time_temp))

        print("class_num:", class_num)
        # Find the mutation with the minimum number of classes.
        index_ = class_num.index(min(class_num))
        if total_classes[variation_1] > min(class_num):
            # If the mutation reduces the number of classes, update the timetable.
            timetable.update(mutation_list[index_][0])
            unoccupied_time = mutation_list[index_][1]
            print(total_classes[variation_1], "v.s.", min(class_num))
            total_classes[variation_1] = min(class_num)
            print("new self mutation")
            total_decrease += 1
        print("done")

    else:
        # If different courses are selected, perform a gene exchange.
        print("exchange:")
        mutation_list = []
        class_num = []

        # Perform the exchange multiple times and store the results.
        for i in range(mutation_time):
            timetable_temp, unoccupied_time_temp = exchange(timetable=timetable, courses=courses,
                                                            variation_1=variation_1, variation_2=variation_2,
                                                            hours_per_course=hours_per_course, unoccupied_time=unoccupied_time)
            course_str_1 = courses[variation_1]
            course_str_2 = courses[variation_2]
            num_1 = count_lecture_num(lecture_arrangement=timetable_temp[course_str_1],
                                      students_per_course=students_per_course,
                                      course_str=course_str_1,
                                      rooms=rooms,
                                      room_capacities=room_capacities)
            num_2 = count_lecture_num(lecture_arrangement=timetable_temp[course_str_2],
                                      students_per_course=students_per_course,
                                      course_str=course_str_2,
                                      rooms=rooms,
                                      room_capacities=room_capacities)
            class_num.append((num_1, num_2))
            mutation_list.append((timetable_temp, unoccupied_time_temp))

        # Calculate the sum of class sessions for each mutation.
        sum_len = [i + j for (i, j) in class_num]
        index_ = sum_len.index(min(sum_len))
        # If the total class sessions decrease, update the timetable.
        if total_classes[variation_1] + total_classes[variation_2] > min(sum_len):
            timetable.update(mutation_list[index_][0])
            unoccupied_time = mutation_list[index_][1]
            before_times = total_classes[variation_1] + total_classes[variation_2]
            after_times = min(sum_len)
            print(before_times, "v.s.", after_times)
            print("new exchange")
            total_classes[variation_1] = class_num[index_][0]
            total_classes[variation_2] = class_num[index_][1]
            total_decrease += before_times - after_times
        print("done")

# Output the total reduction in class sessions achieved by the mutations.
print("Total decrease in class sessions:", total_decrease)
# Out:
# exchange:
# 40GS_LG.09 : 25
# MATH10082 number_of_class: 1
# AT_M2 - Teaching Studio : 25
# MH_G.33 : 8
# MATH10100 number_of_class: 2
# MH_G.33 : 20
# JCMB_2901 : 5
# MATH10082 number_of_class: 2
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 8
# MATH10100 number_of_class: 2
# MH_G.33 : 20
# JCMB_2901 : 5
# MATH10082 number_of_class: 2
# MH_G.13 : 19
# 40GS_LG.09 : 14
# MATH10100 number_of_class: 2
# MH_G.33 : 20
# JCMB_2901 : 5
# MATH10082 number_of_class: 2
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 8
# MATH10100 number_of_class: 2
# MH_G.33 : 20
# JCMB_2901 : 5
# MATH10082 number_of_class: 2
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 8
# MATH10100 number_of_class: 2
# MH_G.33 : 20
# MH_G.13 : 5
# MATH10082 number_of_class: 2
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 8
# MATH10100 number_of_class: 2
# MH_G.33 : 20
# JCMB_2901 : 5
# MATH10082 number_of_class: 2
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 8
# MATH10100 number_of_class: 2
# MH_G.33 : 20
# MH_G.13 : 5
# MATH10082 number_of_class: 2
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 8
# MATH10100 number_of_class: 2
# MH_G.33 : 20
# 40GS_LG.09 : 5
# MATH10082 number_of_class: 2
# AT_M2 - Teaching Studio : 25
# MH_G.13 : 8
# MATH10100 number_of_class: 2
# AT_M2 - Teaching Studio : 25
# MATH10082 number_of_class: 1
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# done
# exchange:
# MH_G.31 : 22
# MATH11236 number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.31 : 39
# MATH11029+MATH11197 number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 2
# MATH11236 number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.31 : 39
# MATH11029+MATH11197 number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.31 : 2
# MATH11236 number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 20
# NUC_2.06 - Rowan : 19
# MATH11029+MATH11197 number_of_class: 3
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.31 : 2
# MATH11236 number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 20
# NUC_2.06 - Rowan : 19
# MATH11029+MATH11197 number_of_class: 3
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.31 : 2
# MATH11236 number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 20
# NUC_2.06 - Rowan : 19
# MATH11029+MATH11197 number_of_class: 3
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.31 : 2
# MATH11236 number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 20
# NUC_2.06 - Rowan : 19
# MATH11029+MATH11197 number_of_class: 3
# MH_G.31 : 22
# MATH11236 number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 20
# NUC_2.06 - Rowan : 19
# MATH11029+MATH11197 number_of_class: 3
# JCMB_3211 - Teaching Studio : 22
# MATH11236 number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 20
# NUC_2.06 - Rowan : 19
# MATH11029+MATH11197 number_of_class: 3
# NUC_2.06 - Rowan : 22
# MATH11236 number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 19
# MATH11029+MATH11197 number_of_class: 3
# MH_G.31 : 22
# MATH11236 number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 19
# MATH11029+MATH11197 number_of_class: 3
# 4 v.s. 3
# new exchange
# done
# exchange:
# AT_2.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 90
# 40GS_LG.07 - Teaching Studio : 20
# JBB_G.69 : 25
# SB_7.20 : 36
# MATH10017 + MATH10065 number_of_class: 6
# MH_G.10 : 20
# MH_G.32 : 28
# MH_G.12 : 2
# MATH10024 + MATH10079 number_of_class: 3
# AT_2.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 90
# 40GS_LG.07 - Teaching Studio : 20
# JBB_G.69 : 25
# MH_G.12 : 20
# MH_G.04 : 16
# MATH10017 + MATH10065 number_of_class: 7
# MH_G.10 : 20
# MH_G.32 : 28
# SB_7.20 : 2
# MATH10024 + MATH10079 number_of_class: 3
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 90
# 40GS_LG.07 - Teaching Studio : 20
# JBB_G.69 : 25
# MH_G.12 : 20
# MH_G.04 : 8
# MATH10017 + MATH10065 number_of_class: 7
# MH_G.10 : 20
# AT_2.12 : 20
# SB_7.20 : 10
# MATH10024 + MATH10079 number_of_class: 3
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# 40GS_LG.09 : 90
# 40GS_LG.07 - Teaching Studio : 20
# JBB_G.69 : 25
# MH_G.12 : 20
# MH_G.04 : 8
# MATH10017 + MATH10065 number_of_class: 7
# MH_G.10 : 20
# AT_2.12 : 20
# MH_1.19 : 10
# MATH10024 + MATH10079 number_of_class: 3
# MH_G.32 : 28
# MH_1.19 : 68
# 40GS_LG.09 : 90
# 40GS_LG.07 - Teaching Studio : 20
# JBB_G.69 : 10
# MATH10017 + MATH10065 number_of_class: 5
# MH_G.10 : 20
# AT_2.12 : 20
# AT_M2 - Teaching Studio : 10
# MATH10024 + MATH10079 number_of_class: 3
# MH_G.32 : 28
# MH_1.19 : 68
# 40GS_LG.09 : 90
# 40GS_LG.07 - Teaching Studio : 20
# JBB_G.69 : 10
# MATH10017 + MATH10065 number_of_class: 5
# MH_G.10 : 20
# AT_2.12 : 20
# JBB_G.69 : 10
# MATH10024 + MATH10079 number_of_class: 3
# MH_G.32 : 28
# MH_1.19 : 68
# 40GS_LG.09 : 90
# 40GS_LG.07 - Teaching Studio : 20
# JBB_G.69 : 10
# MATH10017 + MATH10065 number_of_class: 5
# MH_G.10 : 20
# JBB_G.69 : 25
# JBB_G.69 : 5
# MATH10024 + MATH10079 number_of_class: 3
# MH_G.32 : 28
# MH_1.19 : 68
# 40GS_LG.09 : 90
# 40GS_LG.07 - Teaching Studio : 20
# JBB_G.69 : 10
# MATH10017 + MATH10065 number_of_class: 5
# MH_G.10 : 20
# JBB_G.69 : 25
# JBB_G.69 : 5
# MATH10024 + MATH10079 number_of_class: 3
# MH_G.32 : 28
# MH_1.19 : 68
# 40GS_LG.09 : 90
# 40GS_LG.07 - Teaching Studio : 20
# JBB_G.69 : 10
# MATH10017 + MATH10065 number_of_class: 5
# MH_G.10 : 20
# JBB_G.69 : 25
# JBB_G.69 : 5
# MATH10024 + MATH10079 number_of_class: 3
# MH_G.32 : 28
# MH_1.19 : 68
# 40GS_LG.09 : 90
# MH_G.10 : 20
# JBB_G.69 : 10
# MATH10017 + MATH10065 number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# JBB_G.69 : 25
# JBB_G.69 : 5
# MATH10024 + MATH10079 number_of_class: 3
# 9 v.s. 8
# new exchange
# done
# exchange:
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# AT_2.12 : 20
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_1.19 : 43
# MATH08063 number_of_class: 15
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# AT_2.12 : 20
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_1.19 : 43
# MATH08063 number_of_class: 15
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# AT_2.12 : 20
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_1.19 : 43
# MATH08063 number_of_class: 15
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# AT_2.12 : 20
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_1.19 : 43
# MATH08063 number_of_class: 15
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# AT_2.12 : 20
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_1.19 : 43
# MATH08063 number_of_class: 15
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# AT_2.12 : 20
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.34 : 24
# 40GS_LG.11 : 19
# MATH08063 number_of_class: 16
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# MH_1.19 : 68
# ROB_Hugh Robson Building Computer Lab - 129 cap : 7
# MATH08063 number_of_class: 14
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.34 : 24
# 40GS_LG.11 : 14
# MATH08063 number_of_class: 16
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.34 : 24
# 40GS_LG.11 : 14
# MATH08063 number_of_class: 16
# 40GS_LG.11 : 57
# MATH08062 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# MH_G.12 : 20
# MH_G.30 : 20
# JCMB_3217 - Teaching Studio : 84
# JCMB_3217 - Teaching Studio : 84
# MH_G.10 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 20
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.34 : 24
# 40GS_LG.11 : 14
# MATH08063 number_of_class: 16
# 16 v.s. 15
# new exchange
# done
# exchange:
# JCMB_3212 - Teaching Studio : 24
# SB_7.20 : 35
# MATH11029A number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.09 : 79
# MATH10007 number_of_class: 3
# JCMB_3212 - Teaching Studio : 24
# SB_7.20 : 35
# MATH11029A number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.09 : 79
# MATH10007 number_of_class: 3
# JCMB_3217 - Teaching Studio : 59
# MATH11029A number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.09 : 79
# MATH10007 number_of_class: 3
# JCMB_3217 - Teaching Studio : 59
# MATH11029A number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.33 : 20
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 35
# MATH10007 number_of_class: 5
# JCMB_3217 - Teaching Studio : 59
# MATH11029A number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.33 : 20
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 35
# MATH10007 number_of_class: 5
# JCMB_3217 - Teaching Studio : 59
# MATH11029A number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.33 : 20
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 35
# MATH10007 number_of_class: 5
# JCMB_3217 - Teaching Studio : 59
# MATH11029A number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.04 : 20
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 35
# MATH10007 number_of_class: 5
# MH_G.31 : 46
# SB_7.20 : 13
# MATH11029A number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.04 : 20
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 35
# MATH10007 number_of_class: 5
# MH_G.31 : 46
# SB_7.20 : 13
# MATH11029A number_of_class: 2
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 35
# MATH10007 number_of_class: 5
# 40GS_LG.11 : 59
# MATH11029A number_of_class: 1
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# 5 v.s. 4
# new exchange
# done
# exchange:
# 40GS_LG.11 : 13
# MATH11053 number_of_class: 1
# MH_G.12 : 20
# MH_1.19 : 34
# MATH10076 number_of_class: 2
# MH_G.12 : 13
# MATH11053 number_of_class: 1
# 40GS_LG.11 : 54
# MATH10076 number_of_class: 1
# JBB_G.69 : 13
# MATH11053 number_of_class: 1
# 40GS_LG.11 : 54
# MATH10076 number_of_class: 1
# 40GS_LG.09 : 13
# MATH11053 number_of_class: 1
# 40GS_LG.11 : 54
# MATH10076 number_of_class: 1
# JBB_G.69 : 13
# MATH11053 number_of_class: 1
# 40GS_LG.11 : 54
# MATH10076 number_of_class: 1
# JBB_G.69 : 13
# MATH11053 number_of_class: 1
# 40GS_LG.11 : 54
# MATH10076 number_of_class: 1
# JBB_G.69 : 13
# MATH11053 number_of_class: 1
# 40GS_LG.11 : 54
# MATH10076 number_of_class: 1
# 40GS_LG.11 : 13
# MATH11053 number_of_class: 1
# JBB_G.69 : 25
# MH_1.19 : 29
# MATH10076 number_of_class: 2
# 40GS_7.01 : 12
# MH_G.05 : 1
# MATH11053 number_of_class: 2
# JBB_G.69 : 25
# MH_1.19 : 29
# MATH10076 number_of_class: 2
# JBB_G.69 : 13
# MATH11053 number_of_class: 1
# 40GS_7.01 : 12
# MH_1.19 : 42
# MATH10076 number_of_class: 2
# done
# exchange:
# MH_G.30 : 20
# 40GS_7.01 : 12
# MH_G.12 : 18
# MATH11226 + MATH10053 number_of_class: 3
# MH_G.05 : 24
# NUC_2.06 - Rowan : 5
# MATH11179 number_of_class: 2
# MH_G.30 : 20
# NUC_2.06 - Rowan : 30
# MATH11226 + MATH10053 number_of_class: 2
# MH_G.05 : 24
# NUC_2.06 - Rowan : 5
# MATH11179 number_of_class: 2
# MH_G.30 : 20
# 40GS_7.01 : 12
# MH_G.12 : 18
# MATH11226 + MATH10053 number_of_class: 3
# MH_G.05 : 24
# NUC_2.06 - Rowan : 5
# MATH11179 number_of_class: 2
# NUC_2.06 - Rowan : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.05 : 24
# NUC_2.06 - Rowan : 5
# MATH11179 number_of_class: 2
# NUC_2.06 - Rowan : 50
# MATH11226 + MATH10053 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# NUC_2.06 - Rowan : 17
# MATH11179 number_of_class: 2
# NUC_2.06 - Rowan : 50
# MATH11226 + MATH10053 number_of_class: 1
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.12 : 17
# MATH11179 number_of_class: 2
# NUC_2.06 - Rowan : 50
# MATH11226 + MATH10053 number_of_class: 1
# NUC_2.06 - Rowan : 29
# MATH11179 number_of_class: 1
# NUC_2.06 - Rowan : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.05 : 24
# MH_G.12 : 5
# MATH11179 number_of_class: 2
# MH_G.12 : 20
# 40GS_7.01 : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# NUC_2.06 - Rowan : 6
# MATH11226 + MATH10053 number_of_class: 4
# MH_G.05 : 24
# NUC_2.06 - Rowan : 5
# MATH11179 number_of_class: 2
# NUC_2.06 - Rowan : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.05 : 24
# MH_G.12 : 5
# MATH11179 number_of_class: 2
# 5 v.s. 2
# new exchange
# done
# exchange:
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_1.19 : 68
# 40GS_LG.09 : 34
# MATH11176 number_of_class: 4
# AT_2.12 : 20
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 60
# 40GS_7.18 : 18
# JCMB_3211 - Teaching Studio : 24
# MH_G.33 : 10
# MATH11111 number_of_class: 7
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_1.19 : 68
# 40GS_LG.09 : 34
# MATH11176 number_of_class: 4
# 40GS_LG.09 : 90
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 42
# MATH11111 number_of_class: 4
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_1.19 : 68
# 40GS_LG.09 : 34
# MATH11176 number_of_class: 4
# 40GS_LG.09 : 90
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 42
# MATH11111 number_of_class: 4
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_1.19 : 68
# 40GS_LG.09 : 34
# MATH11176 number_of_class: 4
# 40GS_LG.09 : 90
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 42
# MATH11111 number_of_class: 4
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_1.19 : 68
# 40GS_LG.09 : 34
# MATH11176 number_of_class: 4
# 40GS_LG.09 : 90
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 42
# MATH11111 number_of_class: 4
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_1.19 : 68
# 40GS_LG.09 : 34
# MATH11176 number_of_class: 4
# 40GS_LG.09 : 90
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 42
# MATH11111 number_of_class: 4
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_1.19 : 68
# 40GS_LG.09 : 34
# MATH11176 number_of_class: 4
# 40GS_LG.09 : 90
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 42
# MATH11111 number_of_class: 4
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_1.19 : 68
# 40GS_LG.09 : 34
# MATH11176 number_of_class: 4
# 40GS_LG.09 : 90
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 42
# MATH11111 number_of_class: 4
# 40GS_7.18 : 18
# MH_G.33 : 20
# MH_1.19 : 68
# 40GS_LG.09 : 34
# MATH11176 number_of_class: 4
# 40GS_LG.09 : 90
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 42
# MATH11111 number_of_class: 4
# 40GS_7.18 : 18
# 40GS_LG.09 : 90
# MH_1.19 : 32
# MATH11176 number_of_class: 3
# MH_G.33 : 20
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.11 : 60
# 40GS_7.18 : 18
# JCMB_3212 - Teaching Studio : 24
# MH_G.33 : 10
# MATH11111 number_of_class: 7
# 11 v.s. 8
# new exchange
# done
# exchange:
# MH_G.10 : 20
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# 40GS_7.18 : 18
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# AT_M2 - Teaching Studio : 2
# MATH10066A number_of_class: 10
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# SB_7.15 : 20
# MATH08057 number_of_class: 19
# MH_G.10 : 20
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# 40GS_7.18 : 18
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# AT_M2 - Teaching Studio : 2
# MATH10066A number_of_class: 10
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# SB_7.15 : 20
# MATH08057 number_of_class: 19
# MH_G.10 : 20
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# 40GS_7.18 : 18
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# AT_M2 - Teaching Studio : 2
# MATH10066A number_of_class: 10
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# SB_7.15 : 20
# MATH08057 number_of_class: 19
# MH_G.10 : 20
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# 40GS_7.18 : 18
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# AT_M2 - Teaching Studio : 2
# MATH10066A number_of_class: 10
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# SB_7.15 : 20
# MATH08057 number_of_class: 19
# MH_G.10 : 20
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# 40GS_7.18 : 18
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# AT_M2 - Teaching Studio : 2
# MATH10066A number_of_class: 10
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# SB_7.15 : 20
# MATH08057 number_of_class: 19
# SB_7.15 : 50
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# 40GS_7.18 : 18
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 32
# MATH10066A number_of_class: 9
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# SB_7.15 : 20
# MATH08057 number_of_class: 19
# SB_7.15 : 50
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# 40GS_7.18 : 18
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 32
# MATH10066A number_of_class: 9
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# SB_7.15 : 20
# MATH08057 number_of_class: 19
# SB_7.15 : 50
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# 40GS_7.18 : 18
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 32
# MATH10066A number_of_class: 9
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# SB_7.15 : 20
# MATH08057 number_of_class: 19
# SB_7.15 : 50
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# 40GS_7.18 : 18
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 32
# MATH10066A number_of_class: 9
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# MH_G.10 : 20
# AT_M2 - Teaching Studio : 25
# SB_7.15 : 20
# MATH08057 number_of_class: 19
# SB_7.15 : 50
# MH_G.32 : 28
# NUC_2.06 - Rowan : 60
# 40GS_7.18 : 18
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.10 : 20
# MH_G.04 : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# AT_M2 - Teaching Studio : 12
# MATH10066A number_of_class: 10
# MH_G.34 : 24
# 40GS_LG.11 : 60
# MH_G.12 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_LG.11 : 60
# SB_7.15 : 50
# MH_G.30 : 20
# MH_G.30 : 20
# JCMB_3212 - Teaching Studio : 24
# JBB_G.69 : 25
# MH_G.31 : 46
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.30 : 20
# LLTC_2.14 - Teaching Studio : 36
# 40GS_LG.11 : 60
# AT_M2 - Teaching Studio : 5
# MATH08057 number_of_class: 18
# done
# exchange:
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# MH_G.05 : 24
# MH_G.32 : 5
# MATH10013 + MATH10074 number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.34 : 24
# 40GS_LG.11 : 7
# MATH08071 number_of_class: 4
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 5
# MATH10013 + MATH10074 number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.34 : 24
# 40GS_LG.11 : 7
# MATH08071 number_of_class: 4
# MH_G.32 : 28
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 1
# MATH10013 + MATH10074 number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.34 : 24
# 40GS_LG.11 : 7
# MATH08071 number_of_class: 4
# MH_G.32 : 28
# 40GS_LG.11 : 60
# MH_G.12 : 9
# MATH10013 + MATH10074 number_of_class: 3
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# MH_G.34 : 24
# JCMB_3212 - Teaching Studio : 7
# MATH08071 number_of_class: 4
# MH_G.32 : 28
# 40GS_LG.11 : 60
# MH_G.12 : 9
# MATH10013 + MATH10074 number_of_class: 3
# JCMB_3212 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.34 : 24
# JCMB_3212 - Teaching Studio : 3
# MATH08071 number_of_class: 4
# MH_G.32 : 28
# 40GS_LG.11 : 60
# MH_G.12 : 9
# MATH10013 + MATH10074 number_of_class: 3
# JCMB_3212 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.34 : 24
# MH_G.05 : 3
# MATH08071 number_of_class: 4
# MH_G.32 : 28
# 40GS_LG.11 : 60
# MH_G.12 : 9
# MATH10013 + MATH10074 number_of_class: 3
# JCMB_3212 - Teaching Studio : 24
# JCMB_3212 - Teaching Studio : 24
# MH_G.34 : 23
# MATH08071 number_of_class: 3
# MH_G.32 : 28
# 40GS_LG.11 : 60
# MH_G.12 : 9
# MATH10013 + MATH10074 number_of_class: 3
# JCMB_3212 - Teaching Studio : 24
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.05 : 3
# MATH08071 number_of_class: 4
# MH_G.32 : 28
# 40GS_LG.11 : 60
# MH_G.12 : 9
# MATH10013 + MATH10074 number_of_class: 3
# JCMB_3212 - Teaching Studio : 24
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.05 : 3
# MATH08071 number_of_class: 4
# MH_G.32 : 28
# 40GS_LG.11 : 60
# SB_7.15 : 9
# MATH10013 + MATH10074 number_of_class: 3
# JCMB_3212 - Teaching Studio : 24
# JCMB_3212 - Teaching Studio : 24
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.05 : 3
# MATH08071 number_of_class: 4
# 8 v.s. 6
# new exchange
# done
# exchange:
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# 40GS_LG.11 : 60
# JCMB_3211 - Teaching Studio : 10
# MATH10065 number_of_class: 6
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# 40GS_LG.11 : 60
# JCMB_3211 - Teaching Studio : 10
# MATH10065 number_of_class: 6
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# 40GS_LG.11 : 60
# JCMB_3211 - Teaching Studio : 10
# MATH10065 number_of_class: 6
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# 40GS_LG.11 : 60
# JCMB_3211 - Teaching Studio : 10
# MATH10065 number_of_class: 6
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# 40GS_LG.11 : 60
# JCMB_3211 - Teaching Studio : 10
# MATH10065 number_of_class: 6
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# MH_G.32 : 28
# JCMB_3211 - Teaching Studio : 24
# 40GS_LG.07 - Teaching Studio : 18
# MATH10065 number_of_class: 7
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# MH_G.32 : 28
# JCMB_3211 - Teaching Studio : 24
# 40GS_LG.07 - Teaching Studio : 18
# MATH10065 number_of_class: 7
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# 40GS_LG.11 : 60
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# MH_G.32 : 28
# JCMB_3211 - Teaching Studio : 2
# MATH10065 number_of_class: 6
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# 40GS_LG.11 : 60
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# MH_G.32 : 28
# JCMB_3211 - Teaching Studio : 2
# MATH10065 number_of_class: 6
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# 40GS_LG.11 : 60
# 40GS_LG.11 : 60
# MH_G.31 : 46
# MH_G.12 : 20
# MH_G.32 : 28
# JCMB_3211 - Teaching Studio : 2
# MATH10065 number_of_class: 6
# SB_7.15 : 50
# JCMB_3211 - Teaching Studio : 8
# MATH10028 number_of_class: 2
# done
# exchange:
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.13 : 19
# JBB_G.69 : 25
# MH_G.31 : 46
# MH_G.04 : 20
# MATH11111 + MATH11187 number_of_class: 7
# SB_7.20 : 58
# MH_G.32 : 28
# JCMB_3211 - Teaching Studio : 2
# MATH11230 + MATH11153 number_of_class: 3
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.13 : 19
# JBB_G.69 : 25
# MH_G.31 : 46
# MH_G.04 : 20
# MATH11111 + MATH11187 number_of_class: 7
# SB_7.20 : 58
# MH_G.32 : 28
# JCMB_3211 - Teaching Studio : 2
# MATH11230 + MATH11153 number_of_class: 3
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.13 : 19
# JBB_G.69 : 25
# MH_G.31 : 46
# MH_G.04 : 20
# MATH11111 + MATH11187 number_of_class: 7
# SB_7.20 : 58
# MH_G.32 : 28
# JCMB_3211 - Teaching Studio : 2
# MATH11230 + MATH11153 number_of_class: 3
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.13 : 19
# JBB_G.69 : 25
# MH_G.31 : 46
# MH_G.04 : 20
# MATH11111 + MATH11187 number_of_class: 7
# SB_7.20 : 58
# MH_G.32 : 28
# JCMB_3211 - Teaching Studio : 2
# MATH11230 + MATH11153 number_of_class: 3
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.13 : 19
# JBB_G.69 : 25
# JCMB_3211 - Teaching Studio : 24
# MH_G.04 : 20
# 40GS_7.18 : 18
# MH_G.33 : 4
# MATH11111 + MATH11187 number_of_class: 9
# SB_7.20 : 58
# MH_G.32 : 28
# MH_G.31 : 2
# MATH11230 + MATH11153 number_of_class: 3
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.13 : 19
# JBB_G.69 : 25
# JCMB_3211 - Teaching Studio : 24
# MH_G.04 : 20
# NUC_2.06 - Rowan : 22
# MATH11111 + MATH11187 number_of_class: 8
# SB_7.20 : 58
# MH_G.32 : 28
# MH_G.31 : 2
# MATH11230 + MATH11153 number_of_class: 3
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# JBB_G.69 : 25
# JCMB_3211 - Teaching Studio : 24
# MH_G.04 : 1
# MATH11111 + MATH11187 number_of_class: 7
# SB_7.20 : 58
# MH_G.32 : 28
# MH_G.31 : 2
# MATH11230 + MATH11153 number_of_class: 3
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# JBB_G.69 : 25
# JCMB_3211 - Teaching Studio : 24
# MH_G.04 : 1
# MATH11111 + MATH11187 number_of_class: 7
# SB_7.20 : 58
# MH_G.32 : 28
# MH_G.10 : 2
# MATH11230 + MATH11153 number_of_class: 3
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# JBB_G.69 : 25
# JCMB_3211 - Teaching Studio : 24
# MH_G.04 : 1
# MATH11111 + MATH11187 number_of_class: 7
# SB_7.20 : 58
# MH_G.32 : 28
# NUC_2.06 - Rowan : 2
# MATH11230 + MATH11153 number_of_class: 3
# MH_G.34 : 24
# MH_G.10 : 20
# 40GS_LG.07 - Teaching Studio : 20
# 40GS_LG.11 : 60
# JBB_G.69 : 25
# NUC_2.06 - Rowan : 25
# MATH11111 + MATH11187 number_of_class: 6
# SB_7.20 : 58
# MH_G.32 : 28
# JCMB_3211 - Teaching Studio : 2
# MATH11230 + MATH11153 number_of_class: 3
# 11 v.s. 9
# new exchange
# done
# exchange:
# NUC_2.06 - Rowan : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.04 : 20
# MH_G.34 : 24
# SB_7.15 : 50
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# JCMB_3211 - Teaching Studio : 2
# MATH08066 + MATH10100 number_of_class: 14
# NUC_2.06 - Rowan : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.04 : 20
# MH_G.34 : 24
# SB_7.15 : 50
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# JCMB_3211 - Teaching Studio : 2
# MATH08066 + MATH10100 number_of_class: 14
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 4
# MATH11226 + MATH10053 number_of_class: 2
# MH_G.04 : 20
# MH_G.34 : 24
# SB_7.15 : 50
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# JCMB_3211 - Teaching Studio : 2
# MATH08066 + MATH10100 number_of_class: 14
# SB_7.15 : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.04 : 20
# MH_G.34 : 24
# MH_G.31 : 46
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# JCMB_3211 - Teaching Studio : 6
# MATH08066 + MATH10100 number_of_class: 14
# SB_7.15 : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.04 : 20
# MH_G.34 : 24
# MH_G.31 : 46
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# JCMB_3211 - Teaching Studio : 6
# MATH08066 + MATH10100 number_of_class: 14
# SB_7.15 : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.04 : 20
# MH_G.34 : 24
# MH_G.31 : 46
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# JCMB_3211 - Teaching Studio : 6
# MATH08066 + MATH10100 number_of_class: 14
# SB_7.15 : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.04 : 20
# MH_G.34 : 24
# MH_G.31 : 46
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# JCMB_3211 - Teaching Studio : 6
# MATH08066 + MATH10100 number_of_class: 14
# SB_7.15 : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.04 : 20
# MH_G.13 : 19
# MH_G.31 : 46
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# JCMB_3211 - Teaching Studio : 11
# MATH08066 + MATH10100 number_of_class: 14
# SB_7.15 : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.04 : 20
# MH_G.13 : 19
# MH_G.31 : 46
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# JCMB_3211 - Teaching Studio : 11
# MATH08066 + MATH10100 number_of_class: 14
# SB_7.15 : 50
# MATH11226 + MATH10053 number_of_class: 1
# MH_G.04 : 20
# MH_G.13 : 19
# MH_G.31 : 46
# LLTC_2.14 - Teaching Studio : 36
# JCMB_3217 - Teaching Studio : 84
# SB_7.15 : 50
# MH_G.31 : 46
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.10 : 20
# MH_G.33 : 20
# MH_G.33 : 20
# SB_7.15 : 50
# MH_G.05 : 24
# MH_G.34 : 11
# MATH08066 + MATH10100 number_of_class: 14
# done
# exchange:
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 19
# MATH11029+MATH11197 number_of_class: 3
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# 40GS_LG.07 - Teaching Studio : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.33 : 20
# MH_G.13 : 13
# MATH10100 number_of_class: 2
# done
# exchange:
# SB_7.20 : 58
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 5
# MATH11153 number_of_class: 3
# MH_G.13 : 19
# 40GS_7.01 : 12
# 40GS_7.18 : 18
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 73
# MATH08077A number_of_class: 5
# SB_7.20 : 58
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 5
# MATH11153 number_of_class: 3
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.12 : 20
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 71
# MATH08077A number_of_class: 5
# SB_7.20 : 58
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 5
# MATH11153 number_of_class: 3
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.12 : 20
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 71
# MATH08077A number_of_class: 5
# SB_7.20 : 58
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 5
# MATH11153 number_of_class: 3
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.12 : 20
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 71
# MATH08077A number_of_class: 5
# SB_7.20 : 58
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 5
# MATH11153 number_of_class: 3
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.12 : 20
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 71
# MATH08077A number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_7.18 : 18
# MH_G.32 : 13
# MATH11153 number_of_class: 5
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.12 : 20
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 71
# MATH08077A number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_7.18 : 18
# MH_G.32 : 13
# MATH11153 number_of_class: 5
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.32 : 28
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 63
# MATH08077A number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_7.18 : 18
# MH_G.32 : 13
# MATH11153 number_of_class: 5
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.32 : 28
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 63
# MATH08077A number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_7.18 : 18
# AT_2.12 : 13
# MATH11153 number_of_class: 5
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.32 : 28
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 63
# MATH08077A number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# AT_M2 - Teaching Studio : 25
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_7.18 : 18
# AT_2.12 : 13
# MATH11153 number_of_class: 5
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.32 : 28
# 40GS_LG.09 : 90
# JCMB_3217 - Teaching Studio : 31
# MATH08077A number_of_class: 5
# done
# exchange:
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# JBB_G.69 : 25
# MH_G.13 : 19
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.10 : 20
# 40GS_7.01 : 10
# MATH10068+MATH08068+MATH10079 number_of_class: 11
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# 40GS_LG.09 : 90
# MH_G.13 : 4
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# 40GS_LG.09 : 90
# MH_G.13 : 4
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# 40GS_LG.09 : 90
# MH_G.13 : 4
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# 40GS_LG.09 : 90
# MH_G.13 : 4
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# 40GS_LG.09 : 90
# MH_G.13 : 4
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# 40GS_LG.09 : 90
# MH_G.13 : 4
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# 40GS_LG.09 : 90
# MH_G.13 : 4
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# 40GS_LG.09 : 90
# MH_G.13 : 4
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# MH_G.34 : 24
# JCMB_2901 : 14
# AT_2.12 : 20
# JCMB_3217 - Teaching Studio : 84
# AT_2.12 : 20
# 40GS_7.18 : 18
# 40GS_LG.09 : 90
# MH_G.13 : 4
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# 14 v.s. 13
# new exchange
# done
# exchange:
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.05 : 24
# 40GS_LG.07 - Teaching Studio : 5
# MATH11179 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.05 : 24
# 40GS_LG.07 - Teaching Studio : 5
# MATH11179 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.05 : 24
# 40GS_LG.07 - Teaching Studio : 5
# MATH11179 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.05 : 24
# 40GS_LG.07 - Teaching Studio : 5
# MATH11179 number_of_class: 2
# JCMB_2901 : 14
# MH_G.33 : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.05 : 24
# 40GS_LG.07 - Teaching Studio : 5
# MATH11179 number_of_class: 2
# JCMB_2901 : 14
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# NUC_2.06 - Rowan : 1
# MATH11029+MATH11197 number_of_class: 4
# MH_G.05 : 24
# MH_G.33 : 5
# MATH11179 number_of_class: 2
# MH_G.33 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 19
# MATH11029+MATH11197 number_of_class: 3
# MH_G.05 : 24
# JCMB_2901 : 5
# MATH11179 number_of_class: 2
# MH_G.33 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 19
# MATH11029+MATH11197 number_of_class: 3
# MH_G.05 : 24
# JCMB_2901 : 5
# MATH11179 number_of_class: 2
# MH_G.33 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 19
# MATH11029+MATH11197 number_of_class: 3
# MH_G.05 : 24
# JCMB_2901 : 5
# MATH11179 number_of_class: 2
# MH_G.33 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 19
# MATH11029+MATH11197 number_of_class: 3
# MH_G.05 : 24
# JCMB_2901 : 5
# MATH11179 number_of_class: 2
# done
# exchange:
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_1.19 : 68
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# 40GS_7.01 : 12
# MH_G.30 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_7.01 : 9
# MATH08066 number_of_class: 17
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.31 : 35
# MATH10007 number_of_class: 5
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_1.19 : 68
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# 40GS_7.01 : 12
# MH_G.12 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_7.01 : 9
# MATH08066 number_of_class: 17
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.04 : 20
# 40GS_LG.09 : 15
# MATH10007 number_of_class: 6
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_1.19 : 68
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# 40GS_7.01 : 12
# MH_G.12 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_7.01 : 9
# MATH08066 number_of_class: 17
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.04 : 20
# JCMB_3212 - Teaching Studio : 24
# MH_G.04 : 20
# 40GS_LG.09 : 15
# MATH10007 number_of_class: 6
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_1.19 : 68
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# 40GS_7.01 : 12
# MH_G.12 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_7.01 : 9
# MATH08066 number_of_class: 17
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.04 : 20
# 40GS_7.01 : 12
# MH_G.04 : 20
# 40GS_LG.09 : 27
# MATH10007 number_of_class: 6
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_1.19 : 68
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 9
# MATH08066 number_of_class: 16
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.04 : 20
# 40GS_7.01 : 12
# MH_G.04 : 20
# 40GS_LG.09 : 27
# MATH10007 number_of_class: 6
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_1.19 : 68
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 9
# MATH08066 number_of_class: 16
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.04 : 20
# 40GS_7.01 : 12
# MH_G.04 : 20
# 40GS_LG.09 : 27
# MATH10007 number_of_class: 6
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_1.19 : 68
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 9
# MATH08066 number_of_class: 16
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.04 : 20
# JCMB_2901 : 14
# MH_G.04 : 20
# 40GS_LG.09 : 25
# MATH10007 number_of_class: 6
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_1.19 : 68
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 9
# MATH08066 number_of_class: 16
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.04 : 20
# JCMB_2901 : 14
# MH_G.04 : 20
# 40GS_LG.09 : 25
# MATH10007 number_of_class: 6
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_1.19 : 68
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 9
# MATH08066 number_of_class: 16
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.04 : 20
# JCMB_2901 : 14
# MH_G.04 : 20
# 40GS_LG.09 : 25
# MATH10007 number_of_class: 6
# 40GS_LG.07 - Teaching Studio : 20
# AT_2.12 : 20
# 40GS_LG.11 : 60
# MH_G.13 : 19
# MH_G.04 : 20
# JBB_G.69 : 25
# MH_G.05 : 24
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# AT_2.12 : 20
# MH_G.05 : 24
# 40GS_7.18 : 18
# SB_7.20 : 58
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# 40GS_7.01 : 12
# JCMB_3212 - Teaching Studio : 24
# LLTC_2.14 - Teaching Studio : 10
# MATH08066 number_of_class: 19
# done
# exchange:
# MH_G.33 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_2901 : 14
# ...
# SB_7.20 : 25
# MATH10082 number_of_class: 1
# 40GS_LG.11 : 60
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# SB_7.20 : 31
# MATH11236 + MATH11177 number_of_class: 4
# SB_7.20 : 25
# MATH10082 number_of_class: 1
# 40GS_LG.11 : 60
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# SB_7.20 : 31
# MATH11236 + MATH11177 number_of_class: 4
# SB_7.20 : 25
# MATH10082 number_of_class: 1
# 40GS_LG.11 : 60
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.12 : 20
# JCMB_3211 - Teaching Studio : 11
# MATH11236 + MATH11177 number_of_class: 5
# SB_7.20 : 25
# MATH10082 number_of_class: 1
# 40GS_LG.11 : 60
# 40GS_LG.07 - Teaching Studio : 20
# SB_7.15 : 50
# MH_G.12 : 20
# JCMB_3211 - Teaching Studio : 11
# MATH11236 + MATH11177 number_of_class: 5
# 6 v.s. 5
# new exchange
# done
# exchange:
# 40GS_LG.11 : 22
# MATH11236 number_of_class: 1
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.13 : 19
# JCMB_3217 - Teaching Studio : 62
# MATH10098 + MATH10028 number_of_class: 5
# 40GS_LG.11 : 22
# MATH11236 number_of_class: 1
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.13 : 19
# JCMB_3217 - Teaching Studio : 62
# MATH10098 + MATH10028 number_of_class: 5
# MH_G.13 : 19
# MH_G.33 : 3
# MATH11236 number_of_class: 2
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# AT_2.12 : 20
# 40GS_LG.11 : 60
# JCMB_3217 - Teaching Studio : 21
# MATH10098 + MATH10028 number_of_class: 5
# 40GS_LG.11 : 22
# MATH11236 number_of_class: 1
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.13 : 19
# JCMB_3217 - Teaching Studio : 62
# MATH10098 + MATH10028 number_of_class: 5
# 40GS_LG.11 : 22
# MATH11236 number_of_class: 1
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.13 : 19
# JCMB_3217 - Teaching Studio : 62
# MATH10098 + MATH10028 number_of_class: 5
# MH_1.19 : 22
# MATH11236 number_of_class: 1
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.13 : 19
# JCMB_3217 - Teaching Studio : 62
# MATH10098 + MATH10028 number_of_class: 5
# MH_1.19 : 22
# MATH11236 number_of_class: 1
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.13 : 19
# JCMB_3217 - Teaching Studio : 62
# MATH10098 + MATH10028 number_of_class: 5
# MH_G.12 : 20
# SB_7.15 : 2
# MATH11236 number_of_class: 2
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.13 : 19
# JCMB_3217 - Teaching Studio : 62
# MATH10098 + MATH10028 number_of_class: 5
# MH_G.33 : 20
# SB_7.15 : 2
# MATH11236 number_of_class: 2
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.13 : 19
# JCMB_3217 - Teaching Studio : 62
# MATH10098 + MATH10028 number_of_class: 5
# MH_G.33 : 20
# JCMB_3217 - Teaching Studio : 2
# MATH11236 number_of_class: 2
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# AT_2.12 : 20
# MH_G.13 : 19
# JCMB_3217 - Teaching Studio : 62
# MATH10098 + MATH10028 number_of_class: 5
# done
# exchange:
# MH_1.19 : 68
# 40GS_LG.11 : 60
# MH_G.04 : 20
# MH_G.30 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# MH_G.33 : 20
# LLTC_2.14 - Teaching Studio : 16
# MATH10095 number_of_class: 9
# SB_7.20 : 13
# MATH11053 number_of_class: 1
# MH_1.19 : 68
# 40GS_LG.11 : 60
# MH_G.04 : 20
# MH_G.30 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# MH_G.33 : 20
# LLTC_2.14 - Teaching Studio : 16
# MATH10095 number_of_class: 9
# MH_G.13 : 13
# MATH11053 number_of_class: 1
# MH_1.19 : 68
# 40GS_LG.11 : 60
# MH_G.04 : 20
# MH_G.30 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# MH_G.33 : 20
# MH_G.05 : 16
# MATH10095 number_of_class: 9
# MH_G.13 : 13
# MATH11053 number_of_class: 1
# MH_1.19 : 68
# 40GS_LG.11 : 60
# MH_G.04 : 20
# MH_G.30 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# LLTC_2.14 - Teaching Studio : 36
# MATH10095 number_of_class: 8
# MH_G.13 : 13
# MATH11053 number_of_class: 1
# MH_1.19 : 68
# 40GS_LG.11 : 60
# MH_G.04 : 20
# MH_G.30 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# LLTC_2.14 - Teaching Studio : 36
# MATH10095 number_of_class: 8
# SB_7.15 : 13
# MATH11053 number_of_class: 1
# MH_1.19 : 68
# 40GS_LG.11 : 60
# MH_G.33 : 20
# MH_G.30 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# LLTC_2.14 - Teaching Studio : 36
# MATH10095 number_of_class: 8
# SB_7.15 : 13
# MATH11053 number_of_class: 1
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.33 : 20
# MH_G.30 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# LLTC_2.14 - Teaching Studio : 36
# MH_G.05 : 24
# MH_G.13 : 19
# JCMB_3211 - Teaching Studio : 5
# MATH10095 number_of_class: 11
# SB_7.15 : 13
# MATH11053 number_of_class: 1
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.33 : 20
# MH_G.30 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# LLTC_2.14 - Teaching Studio : 36
# MH_G.05 : 24
# MH_G.13 : 19
# JCMB_3211 - Teaching Studio : 5
# MATH10095 number_of_class: 11
# SB_7.15 : 13
# MATH11053 number_of_class: 1
# MH_G.04 : 20
# 40GS_LG.11 : 60
# MH_G.33 : 20
# MH_G.30 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# LLTC_2.14 - Teaching Studio : 36
# MH_G.05 : 24
# MH_G.13 : 19
# JCMB_3211 - Teaching Studio : 5
# MATH10095 number_of_class: 11
# SB_7.15 : 13
# MATH11053 number_of_class: 1
# MH_G.04 : 20
# 40GS_LG.11 : 60
# JCMB_3212 - Teaching Studio : 24
# MH_G.30 : 20
# 40GS_LG.07 - Teaching Studio : 20
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# LLTC_2.14 - Teaching Studio : 36
# MH_G.05 : 24
# MH_G.13 : 19
# JCMB_3211 - Teaching Studio : 1
# MATH10095 number_of_class: 11
# SB_7.15 : 13
# MATH11053 number_of_class: 1
# done
# exchange:
# MH_G.10 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# MH_G.30 : 20
# MH_G.32 : 28
# MH_G.31 : 46
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.12 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# LLTC_2.14 - Teaching Studio : 36
# MH_G.13 : 19
# 40GS_7.18 : 18
# 40GS_7.01 : 12
# JBB_G.69 : 25
# NUC_2.06 - Rowan : 42
# MATH08074 + MATH10095 number_of_class: 17
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# SB_7.20 : 58
# 40GS_LG.09 : 90
# JCMB_2901 : 14
# 40GS_7.18 : 18
# MH_G.31 : 22
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# MH_G.10 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# MH_G.30 : 20
# MH_G.32 : 28
# MH_G.31 : 46
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.12 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# LLTC_2.14 - Teaching Studio : 36
# MH_G.13 : 19
# 40GS_7.18 : 18
# 40GS_7.01 : 12
# JBB_G.69 : 25
# NUC_2.06 - Rowan : 42
# MATH08074 + MATH10095 number_of_class: 17
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# SB_7.20 : 58
# 40GS_LG.09 : 90
# JCMB_2901 : 14
# 40GS_7.18 : 18
# MH_G.31 : 22
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# MH_G.10 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# MH_G.30 : 20
# MH_G.32 : 28
# MH_G.31 : 46
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.12 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# LLTC_2.14 - Teaching Studio : 36
# MH_G.13 : 19
# 40GS_7.18 : 18
# 40GS_7.01 : 12
# JBB_G.69 : 25
# NUC_2.06 - Rowan : 42
# MATH08074 + MATH10095 number_of_class: 17
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# SB_7.20 : 58
# 40GS_LG.09 : 90
# JCMB_2901 : 14
# 40GS_7.18 : 18
# MH_G.31 : 22
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# MH_G.10 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# MH_G.30 : 20
# MH_G.32 : 28
# MH_G.31 : 46
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.12 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# LLTC_2.14 - Teaching Studio : 36
# MH_G.13 : 19
# 40GS_7.18 : 18
# 40GS_7.01 : 12
# JBB_G.69 : 25
# NUC_2.06 - Rowan : 42
# MATH08074 + MATH10095 number_of_class: 17
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# SB_7.20 : 58
# 40GS_LG.09 : 90
# JCMB_2901 : 14
# 40GS_7.18 : 18
# MH_G.31 : 22
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# MH_G.10 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# MH_G.30 : 20
# MH_G.32 : 28
# MH_G.31 : 46
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# LLTC_2.14 - Teaching Studio : 36
# MH_G.13 : 19
# 40GS_7.18 : 18
# 40GS_7.01 : 12
# JBB_G.69 : 25
# NUC_2.06 - Rowan : 38
# MATH08074 + MATH10095 number_of_class: 17
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# SB_7.20 : 58
# 40GS_LG.09 : 90
# JCMB_2901 : 14
# 40GS_7.18 : 18
# MH_G.31 : 22
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# MH_G.10 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# NUC_2.06 - Rowan : 60
# MH_G.32 : 28
# MH_G.31 : 46
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# LLTC_2.14 - Teaching Studio : 36
# MH_G.13 : 19
# 40GS_7.18 : 18
# 40GS_7.01 : 12
# JBB_G.69 : 23
# MATH08074 + MATH10095 number_of_class: 16
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# SB_7.20 : 58
# 40GS_LG.09 : 90
# JCMB_2901 : 14
# 40GS_7.18 : 18
# MH_G.31 : 22
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# MH_G.10 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# NUC_2.06 - Rowan : 60
# MH_G.32 : 28
# MH_G.31 : 46
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# LLTC_2.14 - Teaching Studio : 36
# MH_G.13 : 19
# 40GS_7.18 : 18
# 40GS_7.01 : 12
# JBB_G.69 : 23
# MATH08074 + MATH10095 number_of_class: 16
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# SB_7.20 : 58
# 40GS_LG.09 : 90
# JCMB_2901 : 14
# 40GS_7.18 : 18
# MH_G.31 : 22
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# MH_G.10 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# NUC_2.06 - Rowan : 60
# MH_G.32 : 28
# MH_G.31 : 46
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.04 : 20
# MH_G.13 : 19
# 40GS_7.18 : 18
# 40GS_7.01 : 12
# JBB_G.69 : 25
# NUC_2.06 - Rowan : 14
# MATH08074 + MATH10095 number_of_class: 17
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# SB_7.20 : 58
# 40GS_LG.09 : 90
# JCMB_2901 : 14
# 40GS_7.18 : 18
# MH_G.31 : 22
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# MH_G.10 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# NUC_2.06 - Rowan : 60
# MH_G.32 : 28
# MH_G.31 : 46
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.04 : 20
# MH_G.13 : 19
# 40GS_7.18 : 18
# 40GS_7.01 : 12
# JBB_G.69 : 25
# NUC_2.06 - Rowan : 14
# MATH08074 + MATH10095 number_of_class: 17
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# SB_7.20 : 58
# 40GS_LG.09 : 90
# JCMB_2901 : 14
# 40GS_7.18 : 18
# MH_G.31 : 22
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# MH_G.10 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.32 : 28
# AT_M2 - Teaching Studio : 25
# NUC_2.06 - Rowan : 60
# MH_G.32 : 28
# MH_G.31 : 46
# JCMB_3212 - Teaching Studio : 24
# MH_G.12 : 20
# MH_G.04 : 20
# JCMB_3211 - Teaching Studio : 24
# MH_G.04 : 20
# MH_G.13 : 19
# 40GS_7.18 : 18
# 40GS_7.01 : 12
# JBB_G.69 : 25
# NUC_2.06 - Rowan : 14
# MATH08074 + MATH10095 number_of_class: 17
# LLTC_2.14 - Teaching Studio : 36
# ROB_Hugh Robson Building Computer Lab - 129 cap : 12
# MH_G.05 : 24
# SB_7.20 : 58
# 40GS_LG.09 : 90
# JCMB_2901 : 14
# 40GS_7.18 : 18
# MH_G.31 : 22
# MATH10068+MATH08068+MATH10079 number_of_class: 8
# done
# exchange:
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# MH_G.04 : 20
# MH_G.12 : 20
# MH_G.10 : 20
# NUC_2.06 - Rowan : 40
# MATH11187 number_of_class: 6
# MH_G.33 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_7.01 : 9
# MATH11235 + MATH10076 number_of_class: 3
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# MH_G.04 : 20
# MH_G.12 : 20
# MH_G.10 : 20
# NUC_2.06 - Rowan : 40
# MATH11187 number_of_class: 6
# MH_G.33 : 20
# AT_M2 - Teaching Studio : 25
# 40GS_7.01 : 9
# MATH11235 + MATH10076 number_of_class: 3
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# MH_G.04 : 20
# MH_G.12 : 20
# MH_G.10 : 20
# NUC_2.06 - Rowan : 40
# MATH11187 number_of_class: 6
# MH_G.33 : 20
# MH_G.13 : 19
# 40GS_7.01 : 12
# 40GS_LG.07 - Teaching Studio : 3
# MATH11235 + MATH10076 number_of_class: 4
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.12 : 20
# MH_G.10 : 20
# NUC_2.06 - Rowan : 40
# MATH11187 number_of_class: 6
# MH_G.33 : 20
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.04 : 3
# MATH11235 + MATH10076 number_of_class: 4
# JCMB_3211 - Teaching Studio : 24
# JCMB_2901 : 14
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.12 : 20
# MH_G.10 : 20
# NUC_2.06 - Rowan : 40
# MATH11187 number_of_class: 6
# MH_G.33 : 20
# MH_G.13 : 19
# 40GS_7.01 : 12
# AT_M2 - Teaching Studio : 3
# MATH11235 + MATH10076 number_of_class: 4
# JCMB_3211 - Teaching Studio : 24
# MH_G.13 : 19
# 40GS_LG.07 - Teaching Studio : 20
# MH_G.12 : 20
# MH_G.10 : 20
# NUC_2.06 - Rowan : 35
# MATH11187 number_of_class: 6
# MH_G.33 : 20
# JCMB_2901 : 14
# 40GS_7.01 : 12
# AT_M2 - Teaching Studio : 8
# MATH11235 + MATH10076 number_of_class: 4
# JCMB_3211 - Teaching Studio : 24
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.12 : 20
# MH_G.10 : 20
# NUC_2.06 - Rowan : 43
# MATH11187 number_of_class: 6
# MH_G.33 : 20
# JCMB_2901 : 14
# 40GS_LG.07 - Teaching Studio : 20
# MATH11235 + MATH10076 number_of_class: 3
# JCMB_3211 - Teaching Studio : 24
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.33 : 20
# MH_G.10 : 20
# NUC_2.06 - Rowan : 43
# MATH11187 number_of_class: 6
# MH_G.12 : 20
# JCMB_2901 : 14
# 40GS_LG.07 - Teaching Studio : 20
# MATH11235 + MATH10076 number_of_class: 3
# JCMB_3211 - Teaching Studio : 24
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.33 : 20
# MH_G.10 : 20
# NUC_2.06 - Rowan : 43
# MATH11187 number_of_class: 6
# MH_G.04 : 20
# JCMB_2901 : 14
# 40GS_LG.07 - Teaching Studio : 20
# MATH11235 + MATH10076 number_of_class: 3
# JCMB_3211 - Teaching Studio : 24
# MH_G.13 : 19
# 40GS_7.01 : 12
# MH_G.33 : 20
# MH_G.10 : 20
# NUC_2.06 - Rowan : 43
# MATH11187 number_of_class: 6
# MH_G.04 : 20
# JCMB_2901 : 14
# 40GS_LG.07 - Teaching Studio : 20
# MATH11235 + MATH10076 number_of_class: 3
# done
# exchange:
# SB_7.15 : 50
# MH_G.34 : 24
# MH_G.31 : 46
# MH_G.10 : 20
# 40GS_LG.11 : 21
# MATH11177 number_of_class: 5
# SB_7.20 : 58
# JCMB_3212 - Teaching Studio : 24
# JCMB_3217 - Teaching Studio : 84
# 40GS_7.18 : 8
# MATH11111 number_of_class: 4
# SB_7.15 : 50
# MH_G.34 : 24
# 40GS_7.01 : 12
# MH_G.10 : 20
# 40GS_LG.11 : 55
# MATH11177 number_of_class: 5
# SB_7.20 : 58
# JCMB_3212 - Teaching Studio : 24
# JCMB_3217 - Teaching Studio : 84
# 40GS_7.18 : 8
# MATH11111 number_of_class: 4
# SB_7.15 : 50
# MH_G.34 : 24
# 40GS_7.01 : 12
# MH_G.10 : 20
# 40GS_LG.11 : 55
# MATH11177 number_of_class: 5
# SB_7.20 : 58
# JCMB_3212 - Teaching Studio : 24
# JCMB_3217 - Teaching Studio : 84
# MH_G.05 : 8
# MATH11111 number_of_class: 4
# SB_7.15 : 50
# MH_G.34 : 24
# 40GS_7.01 : 12
# MH_G.10 : 20
# 40GS_LG.11 : 55
# MATH11177 number_of_class: 5
# SB_7.20 : 58
# JCMB_3212 - Teaching Studio : 24
# JCMB_3217 - Teaching Studio : 84
# MH_G.05 : 8
# MATH11111 number_of_class: 4
# SB_7.15 : 50
# MH_G.34 : 24
# 40GS_7.01 : 12
# MH_G.10 : 20
# 40GS_LG.11 : 55
# MATH11177 number_of_class: 5
# SB_7.20 : 58
# JCMB_3212 - Teaching Studio : 24
# 40GS_7.18 : 18
# MH_G.05 : 24
# MH_1.19 : 50
# MATH11111 number_of_class: 5
# SB_7.15 : 50
# MH_G.34 : 24
# 40GS_7.01 : 12
# MH_G.05 : 24
# 40GS_LG.11 : 51
# MATH11177 number_of_class: 5
# SB_7.20 : 58
# JCMB_3212 - Teaching Studio : 24
# 40GS_7.18 : 18
# MH_G.05 : 24
# MH_1.19 : 50
# MATH11111 number_of_class: 5
# SB_7.15 : 50
# MH_G.34 : 24
# 40GS_7.01 : 12
# MH_G.05 : 24
# 40GS_LG.11 : 51
# MATH11177 number_of_class: 5
# SB_7.20 : 58
# JCMB_3212 - Teaching Studio : 24
# 40GS_7.18 : 18
# MH_G.05 : 24
# MH_1.19 : 50
# MATH11111 number_of_class: 5
# SB_7.15 : 50
# MH_G.05 : 24
# 40GS_7.01 : 12
# MH_G.05 : 24
# 40GS_LG.11 : 51
# MATH11177 number_of_class: 5
# SB_7.20 : 58
# JCMB_3212 - Teaching Studio : 24
# 40GS_7.18 : 18
# MH_G.05 : 24
# MH_1.19 : 50
# MATH11111 number_of_class: 5
# SB_7.15 : 50
# MH_G.05 : 24
# 40GS_7.01 : 12
# MH_G.05 : 24
# 40GS_LG.11 : 51
# MATH11177 number_of_class: 5
# SB_7.20 : 58
# JCMB_3217 - Teaching Studio : 84
# 40GS_7.18 : 18
# MH_G.05 : 14
# MATH11111 number_of_class: 4
# SB_7.15 : 50
# MH_G.05 : 24
# 40GS_7.01 : 12
# MH_G.05 : 24
# 40GS_LG.11 : 51
# MATH11177 number_of_class: 5
# SB_7.20 : 58
# JCMB_3212 - Teaching Studio : 24
# 40GS_7.18 : 18
# MH_G.05 : 24
# MH_1.19 : 50
# MATH11111 number_of_class: 5
# done
# Total decrease in class sessions: 103

# %%
print("total_class:",total_classes)#total_class
sum(total_classes)#sum
# Out:
# total_class: [1, 9, 2, 3, 16, 2, 6, 1, 1, 3, 7, 7, 2, 1, 1, 3, 2, 1, 1, 3, 9, 1, 4, 4, 1, 4, 2, 1, 2, 1, 1, 4, 1, 14, 1, 9, 6, 3, 2, 5, 1, 1, 1, 8, 4, 2, 2, 4, 1, 3, 1, 1, 13, 3, 13, 11, 1, 7, 1, 4, 1, 8, 1, 2, 14, 4, 5, 1]
# 265

# %%
timetable
# Out:
# {'MATH08062': [(12, 1), (27, 2), (7, 0), (22, 4), (25, 2)],
#  'MATH10066': [(21, 4),
#   (3, 0),
#   (27, 1),
#   (23, 0),
#   (20, 1),
#   (14, 3),
#   (23, 2),
#   (19, 2),
#   (23, 3),
#   (9, 0),
#   (16, 1),
#   (1, 1),
#   (3, 4),
#   (0, 4),
#   (0, 1),
#   (15, 1),
#   (8, 4),
#   (18, 1),
#   (2, 3),
#   (22, 1),
#   (25, 4),
#   (5, 2),
#   (19, 4),
#   (13, 1),
#   (21, 4),
#   (24, 4)],
#  'MATH11231': [(22, 3), (1, 4), (23, 4)],
#  'MATH08077': [(4, 1),
#   (4, 4),
#   (0, 0),
#   (11, 1),
#   (13, 2),
#   (4, 3),
#   (11, 3),
#   (6, 1),
#   (2, 3),
#   (5, 0),
#   (11, 2),
#   (25, 3),
#   (17, 3),
#   (17, 4),
#   (10, 2)],
#  'MATH08057': [(15, 1),
#   (27, 3),
#   (10, 0),
#   (19, 4),
#   (12, 4),
#   (17, 3),
#   (0, 3),
#   (11, 0),
#   (15, 0),
#   (6, 4),
#   (7, 2),
#   (17, 1),
#   (27, 4),
#   (20, 4),
#   (11, 1),
#   (15, 4),
#   (22, 0),
#   (11, 3),
#   (17, 4),
#   (9, 3),
#   (26, 1),
#   (13, 4),
#   (16, 2),
#   (16, 3),
#   (13, 4),
#   (24, 0),
#   (22, 1),
#   (26, 0),
#   (4, 1),
#   (13, 2),
#   (7, 4),
#   (27, 1),
#   (9, 3),
#   (5, 1),
#   (5, 1),
#   (1, 0),
#   (7, 2),
#   (24, 2),
#   (18, 0),
#   (14, 4),
#   (15, 3),
#   (22, 2),
#   (6, 2),
#   (11, 3),
#   (19, 0),
#   (24, 4),
#   (17, 0),
#   (6, 3),
#   (17, 2)],
#  'MATH10098': [(11, 2),
#   (24, 3),
#   (9, 1),
#   (21, 4),
#   (2, 2),
#   (26, 1),
#   (7, 3),
#   (6, 4),
#   (15, 2),
#   (11, 0),
#   (14, 1),
#   (1, 3),
#   (0, 2)],
#  'MATH11199': [(26, 2),
#   (3, 0),
#   (14, 1),
#   (24, 3),
#   (2, 2),
#   (26, 3),
#   (27, 3),
#   (17, 0),
#   (21, 0),
#   (17, 1),
#   (4, 2),
#   (16, 4),
#   (13, 4),
#   (12, 3),
#   (7, 4),
#   (27, 0),
#   (5, 3),
#   (22, 2),
#   (8, 1)],
#  'MATH11029': [(2, 0), (21, 1), (5, 1), (13, 1), (1, 1)],
#  'MATH10099': [(17, 2), (12, 3), (22, 1), (24, 3)],
#  'MATH11029+MATH11197': [(10, 2), (25, 0), (5, 4), (8, 4), (9, 2)],
#  'MATH10098+MATH10066': [(1, 2),
#   (10, 4),
#   (9, 4),
#   (13, 2),
#   (18, 1),
#   (20, 4),
#   (0, 3),
#   (26, 0),
#   (11, 0),
#   (1, 2),
#   (23, 0),
#   (10, 4),
#   (18, 4),
#   (21, 3),
#   (22, 4),
#   (24, 0),
#   (26, 4),
#   (3, 4),
#   (15, 1),
#   (19, 2),
#   (15, 3),
#   (5, 4),
#   (12, 2),
#   (4, 0),
#   (2, 0)],
#  'MATH10068+MATH08068+MATH10079': [(24, 2),
#   (25, 4),
#   (7, 3),
#   (18, 1),
#   (21, 1),
#   (1, 2),
#   (26, 1),
#   (12, 0),
#   (24, 2),
#   (22, 0),
#   (5, 0),
#   (26, 3),
#   (13, 0),
#   (19, 0),
#   (12, 3),
#   (1, 0),
#   (0, 0),
#   (11, 4),
#   (11, 1),
#   (20, 2),
#   (9, 2),
#   (24, 2),
#   (20, 3)],
#  'MATH08071': [(12, 0), (22, 1), (10, 2), (15, 1), (9, 4), (9, 4)],
#  'MATH11226': [(10, 4), (13, 0), (11, 3), (21, 1)],
#  'MATH11236': [(14, 2), (4, 4)],
#  'MATH11177': [(17, 1),
#   (7, 0),
#   (27, 2),
#   (7, 4),
#   (22, 3),
#   (21, 0),
#   (12, 2),
#   (14, 2),
#   (19, 1),
#   (4, 0),
#   (11, 3),
#   (18, 2),
#   (12, 2),
#   (26, 1)],
#  'MATH10072': [(5, 0),
#   (0, 0),
#   (27, 2),
#   (8, 2),
#   (19, 0),
#   (2, 1),
#   (18, 1),
#   (0, 1)],
#  'MATH10017': [(16, 1), (1, 4), (25, 2)],
#  'MATH11235': [(13, 3), (1, 1), (1, 0)],
#  'MATH11153': [(22, 0),
#   (8, 4),
#   (7, 1),
#   (18, 3),
#   (6, 4),
#   (12, 2),
#   (20, 4),
#   (27, 4)],
#  'MATH08074': [(5, 3),
#   (25, 2),
#   (5, 3),
#   (2, 1),
#   (27, 0),
#   (8, 0),
#   (23, 1),
#   (5, 3),
#   (9, 1),
#   (14, 1),
#   (26, 0),
#   (25, 4),
#   (19, 1),
#   (14, 2),
#   (23, 1),
#   (5, 3),
#   (21, 2),
#   (6, 3),
#   (0, 4),
#   (0, 2),
#   (1, 3),
#   (20, 0),
#   (20, 1),
#   (5, 0),
#   (3, 2),
#   (10, 2),
#   (24, 1),
#   (18, 4),
#   (23, 0),
#   (24, 1),
#   (26, 2),
#   (13, 0),
#   (0, 1),
#   (20, 3),
#   (15, 0),
#   (23, 4)],
#  'MATH10047': [(26, 4), (18, 2), (25, 0)],
#  'MATH10065': [(7, 1),
#   (20, 1),
#   (12, 4),
#   (13, 0),
#   (20, 0),
#   (8, 2),
#   (12, 1),
#   (4, 0),
#   (16, 4),
#   (21, 3),
#   (13, 4),
#   (22, 0),
#   (11, 4),
#   (3, 3),
#   (23, 0),
#   (27, 3),
#   (25, 1),
#   (20, 4)],
#  'MATH11111': [(18, 3),
#   (3, 2),
#   (26, 3),
#   (7, 4),
#   (5, 2),
#   (23, 4),
#   (8, 0),
#   (8, 3),
#   (27, 3),
#   (13, 4),
#   (18, 3),
#   (15, 3),
#   (8, 2),
#   (15, 3),
#   (21, 0)],
#  'MATH10076': [(3, 0), (25, 2), (0, 1), (0, 3), (13, 3)],
#  'MATH11187': [(2, 1),
#   (10, 1),
#   (27, 3),
#   (14, 0),
#   (8, 1),
#   (16, 3),
#   (12, 2),
#   (9, 1),
#   (4, 3),
#   (3, 3),
#   (19, 3),
#   (19, 1)],
#  'MATH10074': [(16, 2),
#   (10, 1),
#   (19, 3),
#   (25, 0),
#   (8, 4),
#   (2, 3),
#   (2, 2),
#   (17, 2),
#   (17, 4)],
#  'MATH11053': [(17, 0), (14, 0)],
#  'MATH10100': [(16, 0), (4, 2), (15, 2)],
#  'MATH10082': [(18, 0), (10, 0), (1, 4)],
#  'MATH10013': [(9, 2), (15, 0), (16, 4), (15, 1), (26, 4)],
#  'MATH08072': [(19, 2),
#   (11, 0),
#   (27, 2),
#   (3, 2),
#   (23, 4),
#   (12, 0),
#   (15, 0),
#   (17, 2),
#   (15, 4),
#   (5, 3),
#   (8, 0),
#   (3, 2)],
#  'MATH11007': [(19, 3), (27, 3), (18, 2), (12, 1), (6, 1), (5, 3), (26, 4)],
#  'MATH08066': [(9, 1),
#   (15, 0),
#   (24, 4),
#   (15, 0),
#   (13, 3),
#   (27, 4),
#   (25, 0),
#   (24, 3),
#   (23, 2),
#   (7, 0),
#   (4, 3),
#   (11, 2),
#   (6, 3),
#   (15, 1),
#   (1, 3),
#   (27, 1),
#   (13, 1),
#   (3, 3),
#   (13, 0),
#   (2, 0),
#   (3, 1),
#   (16, 3),
#   (4, 4),
#   (20, 0),
#   (6, 2),
#   (14, 1),
#   (21, 0),
#   (14, 4),
#   (11, 0),
#   (14, 4),
#   (24, 2),
#   (3, 4),
#   (14, 4),
#   (9, 0),
#   (25, 4),
#   (15, 4),
#   (27, 0),
#   (11, 0),
#   (9, 0)],
#  'MATH10024': [(16, 3)],
#  'MATH08063': [(4, 3),
#   (4, 1),
#   (5, 4),
#   (4, 3),
#   (20, 2),
#   (7, 0),
#   (17, 3),
#   (26, 0),
#   (9, 2),
#   (19, 3),
#   (8, 3),
#   (24, 0),
#   (6, 4),
#   (7, 2),
#   (18, 2),
#   (16, 0),
#   (23, 2),
#   (20, 0),
#   (8, 1),
#   (7, 4),
#   (19, 0),
#   (7, 3),
#   (21, 3),
#   (4, 2),
#   (23, 0),
#   (0, 2),
#   (23, 4),
#   (19, 3),
#   (20, 4),
#   (8, 1),
#   (0, 1),
#   (14, 1),
#   (20, 4),
#   (11, 2),
#   (19, 3),
#   (15, 2),
#   (26, 0),
#   (25, 1)],
#  'MATH10095': [(6, 1),
#   (22, 3),
#   (3, 3),
#   (11, 4),
#   (20, 0),
#   (2, 1),
#   (1, 1),
#   (24, 4),
#   (7, 3),
#   (10, 1),
#   (2, 2),
#   (23, 1),
#   (2, 3),
#   (6, 3),
#   (7, 3),
#   (21, 0),
#   (5, 4),
#   (22, 3),
#   (25, 4),
#   (18, 3),
#   (19, 4),
#   (10, 0)],
#  'MATH11176': [(27, 1),
#   (10, 2),
#   (14, 0),
#   (7, 1),
#   (14, 4),
#   (0, 2),
#   (22, 2),
#   (17, 1),
#   (14, 4),
#   (27, 4),
#   (5, 0),
#   (9, 2)],
#  'MATH11154': [(10, 0), (15, 2), (10, 3), (0, 0), (25, 2), (18, 3), (4, 0)],
#  'MATH10007': [(14, 3),
#   (27, 0),
#   (1, 0),
#   (9, 2),
#   (16, 3),
#   (7, 1),
#   (25, 1),
#   (23, 1),
#   (10, 2),
#   (6, 2),
#   (9, 0),
#   (11, 4),
#   (18, 0)],
#  'MATH10028': [(27, 3), (4, 4), (9, 1), (22, 3), (18, 2)],
#  'MATH11144': [(27, 1)],
#  'MATH11179': [(16, 2), (8, 3), (11, 1)],
#  'MATH10066A': [(14, 4),
#   (25, 3),
#   (25, 3),
#   (25, 0),
#   (2, 1),
#   (27, 2),
#   (6, 0),
#   (12, 0),
#   (3, 3),
#   (26, 0),
#   (16, 4),
#   (12, 4),
#   (3, 2),
#   (12, 0),
#   (19, 1),
#   (16, 3),
#   (24, 0),
#   (16, 2),
#   (19, 0),
#   (5, 2),
#   (5, 4),
#   (16, 1),
#   (6, 0),
#   (2, 1),
#   (24, 1),
#   (12, 4)],
#  'MATH11236 + MATH11177': [(22, 0),
#   (20, 2),
#   (17, 3),
#   (9, 1),
#   (2, 2),
#   (23, 4),
#   (21, 1),
#   (18, 2),
#   (2, 4),
#   (12, 3),
#   (5, 3),
#   (5, 1),
#   (16, 3),
#   (3, 4)],
#  'MATH11230 + MATH11153': [(2, 0),
#   (18, 3),
#   (2, 0),
#   (16, 1),
#   (26, 1),
#   (1, 1),
#   (9, 4),
#   (27, 0)],
#  'MATH10072 + MATH10047': [(13, 0),
#   (25, 0),
#   (14, 3),
#   (18, 3),
#   (0, 4),
#   (0, 3),
#   (24, 1),
#   (6, 4)],
#  'MATH10017 + MATH10065': [(8, 1),
#   (1, 0),
#   (25, 0),
#   (10, 3),
#   (26, 4),
#   (0, 1),
#   (21, 2),
#   (20, 2),
#   (22, 2),
#   (7, 2),
#   (0, 2),
#   (5, 2),
#   (3, 1),
#   (4, 3),
#   (21, 0),
#   (16, 2),
#   (8, 0),
#   (18, 4)],
#  'MATH11235 + MATH10076': [(6, 2), (1, 3), (20, 2), (19, 4), (8, 0)],
#  'MATH11111 + MATH11187': [(19, 1),
#   (22, 0),
#   (14, 0),
#   (10, 2),
#   (20, 0),
#   (5, 2),
#   (9, 1),
#   (19, 4),
#   (11, 4),
#   (16, 0),
#   (2, 2),
#   (26, 3),
#   (20, 3),
#   (5, 1),
#   (20, 3)],
#  'MATH11226 + MATH10053': [(11, 1), (21, 0), (22, 4), (14, 4), (19, 1)],
#  'MATH10082 + MATH11053': [(4, 0), (12, 1), (20, 3)],
#  'MATH08066 + MATH10100': [(8, 3),
#   (8, 1),
#   (9, 0),
#   (23, 3),
#   (17, 3),
#   (4, 2),
#   (27, 1),
#   (1, 3),
#   (17, 0),
#   (27, 4),
#   (12, 3),
#   (20, 3),
#   (4, 1),
#   (22, 2),
#   (3, 4),
#   (4, 4),
#   (26, 2),
#   (14, 3),
#   (20, 0),
#   (24, 0),
#   (20, 2),
#   (10, 1),
#   (14, 0),
#   (1, 2),
#   (25, 3),
#   (1, 0),
#   (15, 2),
#   (25, 4),
#   (24, 1),
#   (21, 2),
#   (4, 2),
#   (8, 2),
#   (17, 3),
#   (23, 3),
#   (25, 2),
#   (11, 3),
#   (0, 4),
#   (6, 0),
#   (16, 0)],
#  'MATH10013 + MATH10074': [(24, 1),
#   (25, 1),
#   (27, 0),
#   (9, 0),
#   (20, 1),
#   (17, 1),
#   (12, 0),
#   (21, 2),
#   (27, 2)],
#  'MATH08074 + MATH10095': [(8, 1),
#   (2, 4),
#   (13, 2),
#   (19, 0),
#   (16, 4),
#   (13, 1),
#   (12, 4),
#   (3, 0),
#   (9, 0),
#   (6, 0),
#   (2, 1),
#   (6, 3),
#   (10, 1),
#   (26, 4),
#   (27, 1),
#   (0, 2),
#   (16, 2),
#   (11, 2),
#   (0, 0),
#   (1, 4),
#   (3, 2),
#   (3, 1),
#   (21, 3),
#   (6, 1),
#   (21, 4),
#   (13, 3),
#   (19, 2),
#   (7, 1),
#   (0, 4),
#   (18, 3),
#   (10, 0),
#   (22, 4),
#   (7, 3),
#   (18, 1),
#   (23, 2),
#   (23, 2)],
#  'MATH08068 + MATH08074': [(25, 4),
#   (17, 0),
#   (6, 3),
#   (20, 0),
#   (18, 2),
#   (16, 3),
#   (7, 1),
#   (6, 0),
#   (7, 0),
#   (14, 2),
#   (20, 1),
#   (3, 3),
#   (0, 2),
#   (14, 0),
#   (14, 3),
#   (13, 3),
#   (13, 2),
#   (10, 0),
#   (27, 0),
#   (22, 3),
#   (4, 3),
#   (22, 4),
#   (6, 1),
#   (17, 0),
#   (21, 0),
#   (1, 1),
#   (20, 3),
#   (25, 1),
#   (14, 2),
#   (23, 3),
#   (23, 3),
#   (1, 4),
#   (10, 4),
#   (21, 2),
#   (4, 0),
#   (14, 0)],
#  'MATH11144 + MATH11179': [(6, 0), (14, 3), (21, 1)],
#  'MATH07003 + MATH11154': [(6, 3),
#   (19, 0),
#   (8, 3),
#   (7, 2),
#   (5, 1),
#   (7, 3),
#   (3, 0),
#   (11, 2),
#   (4, 2),
#   (24, 4),
#   (23, 3),
#   (20, 2),
#   (5, 0),
#   (8, 4),
#   (8, 0),
#   (12, 3),
#   (13, 3),
#   (19, 4),
#   (0, 0),
#   (10, 4),
#   (14, 0)],
#  'MATH10010 + MATH10053': [(4, 2), (15, 0), (2, 1), (19, 2), (13, 1)],
#  'MATH10098 + MATH10028': [(6, 1),
#   (2, 3),
#   (23, 4),
#   (10, 0),
#   (4, 0),
#   (21, 1),
#   (27, 4),
#   (14, 2),
#   (17, 3),
#   (22, 2),
#   (5, 0),
#   (5, 2),
#   (9, 2)],
#  'MATH10024 + MATH10079': [(15, 2), (23, 3), (12, 4), (14, 2), (14, 0)],
#  'MATH11231A': [(15, 2), (7, 4), (22, 0)],
#  'MATH08077A': [(9, 3),
#   (0, 2),
#   (15, 4),
#   (24, 1),
#   (2, 2),
#   (0, 3),
#   (14, 1),
#   (23, 1),
#   (11, 1),
#   (26, 3),
#   (2, 4),
#   (13, 1),
#   (20, 3),
#   (25, 3),
#   (12, 2)],
#  'MATH08057A': [(6, 1),
#   (7, 0),
#   (1, 1),
#   (16, 0),
#   (16, 2),
#   (10, 1),
#   (13, 3),
#   (16, 0),
#   (4, 4),
#   (18, 0),
#   (17, 1),
#   (16, 2),
#   (8, 2),
#   (3, 4),
#   (18, 3),
#   (9, 3),
#   (27, 0),
#   (4, 1),
#   (19, 4),
#   (22, 4),
#   (14, 1),
#   (18, 0),
#   (18, 1),
#   (4, 0),
#   (8, 4),
#   (26, 2),
#   (12, 0),
#   (2, 4),
#   (18, 0),
#   (6, 0),
#   (21, 1),
#   (0, 4),
#   (6, 2),
#   (25, 1),
#   (21, 2),
#   (23, 2),
#   (9, 4),
#   (6, 0),
#   (12, 1),
#   (26, 4),
#   (23, 3),
#   (16, 0),
#   (8, 1),
#   (26, 2),
#   (3, 4),
#   (10, 3),
#   (20, 1),
#   (26, 1),
#   (3, 2)],
#  'MATH10098A': [(13, 1),
#   (7, 0),
#   (19, 3),
#   (6, 1),
#   (17, 0),
#   (2, 3),
#   (9, 3),
#   (25, 0),
#   (22, 3),
#   (8, 4),
#   (19, 2),
#   (22, 3),
#   (8, 0)],
#  'MATH11199A': [(12, 1),
#   (19, 1),
#   (5, 2),
#   (23, 2),
#   (6, 4),
#   (3, 1),
#   (15, 4),
#   (3, 1),
#   (7, 1),
#   (1, 3),
#   (21, 2),
#   (4, 1),
#   (8, 0),
#   (22, 4),
#   (0, 0),
#   (2, 0),
#   (17, 4),
#   (13, 3),
#   (14, 2)],
#  'MATH11029A': [(26, 2), (7, 0), (15, 3), (10, 1), (23, 4)]}

# %%
# Create a list of all possible room and weekday combinations.
room_timetable = [(room, weekday) for room in range(rooms_num) for weekday in range(weekdays_num)]

# Initialize a dictionary to store course arrangements for each room and weekday.
room_timetable_dict = {key: [] for key in room_timetable}

# Populate the dictionary with course data from a pre-existing timetable.
for course in pre_timetable:
    arrangement_list = pre_timetable[course]
    for room_date in arrangement_list:
        # Each course is paired with its duration and stored under the corresponding room and date.
        course_time = (course, hours_per_course[course])
        room_timetable_dict[room_date].append(course_time)

# Iterate over each room and weekday combination to display the scheduled courses.
for rt in room_timetable:
    print(rooms[rt[0]], ":")
    # Initialize a counter to calculate start times based on course durations.
    k = 0
    for one_class in room_timetable_dict[rt]:
        # Format the course code and the specific day.
        first_part = "  - Course Code: " + one_class[0] + ", " + "Day " + str(rt[1] + 1) + ", "
        # Calculate start and end times based on course duration, starting at 9 AM.
        second_part = [9 + k, 9 + k + one_class[1]]
        for j in range(2):
            # Convert 24-hour time format to 12-hour format with AM/PM.
            if second_part[j] < 12:
                second_part[j] = str(second_part[j]) + "AM"
            elif second_part[j] == 12:
                second_part[j] = "12PM"
            else:
                second_part[j] = str(second_part[j] % 12) + "PM"
        # Append the duration of the course in hours.
        third_part = "(" + str(one_class[1]) + "h)"
        # Increment the start time by the duration of the current course for the next course.
        k += one_class[1]
        # Print the complete timetable entry for each course.
        print(first_part + second_part[0] + "-" + second_part[1] + third_part)
# Out:
# JBB_G.69 :
#   - Course Code: MATH08077, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH10072, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH11154, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH11199A, Day 1, 5PM-6PM(1h)
# JBB_G.69 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10072, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH08074, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10076, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 2, 3PM-4PM(1h)
# JBB_G.69 :
#   - Course Code: MATH10098, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH11176, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH08077A, Day 3, 5PM-6PM(1h)
# JBB_G.69 :
#   - Course Code: MATH08057, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH10076, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08077A, Day 4, 3PM-4PM(1h)
# JBB_G.69 :
#   - Course Code: MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 5, 3PM-4PM(1h)
# JCMB_2901 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH11235, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10007, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 4PM-5PM(1h)
# JCMB_2901 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11029, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH11235, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10095, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 2, 5PM-6PM(1h)
# JCMB_2901 :
#   - Course Code: MATH10098+MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 1PM-3PM(2h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 3PM-4PM(1h)
# JCMB_2901 :
#   - Course Code: MATH10098, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH11235 + MATH10076, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH11199A, Day 4, 3PM-4PM(1h)
# JCMB_2901 :
#   - Course Code: MATH11231, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10017, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10082, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 2PM-3PM(1h)
# JCMB_3211 - Teaching Studio :
#   - Course Code: MATH11029, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08066, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 1, 4PM-5PM(1h)
# JCMB_3211 - Teaching Studio :
#   - Course Code: MATH10072, Day 2, 9AM-10AM(1h)
#   - Course Code: MATH08074, Day 2, 10AM-11AM(1h)
#   - Course Code: MATH11187, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10066A, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH10010 + MATH10053, Day 2, 4PM-5PM(1h)
# JCMB_3211 - Teaching Studio :
#   - Course Code: MATH10098, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH10074, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10095, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH08077A, Day 3, 5PM-6PM(1h)
# JCMB_3211 - Teaching Studio :
#   - Course Code: MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08077, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH10074, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10095, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10098A, Day 4, 4PM-5PM(1h)
# JCMB_3211 - Teaching Studio :
#   - Course Code: MATH11236 + MATH11177, Day 5, 9AM-10AM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 10AM-11AM(1h)
#   - Course Code: MATH08077A, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08057A, Day 5, 12PM-1PM(1h)
# JCMB_3212 - Teaching Studio :
#   - Course Code: MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH10076, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 1, 3PM-4PM(1h)
# JCMB_3212 - Teaching Studio :
#   - Course Code: MATH08066, Day 2, 9AM-10AM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 2, 10AM-11AM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH11199A, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH11199A, Day 2, 1PM-2PM(1h)
# JCMB_3212 - Teaching Studio :
#   - Course Code: MATH08074, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH11111, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH08072, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08072, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 3, 3PM-4PM(1h)
# JCMB_3212 - Teaching Studio :
#   - Course Code: MATH10065, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH11187, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH08066, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 2PM-3PM(1h)
# JCMB_3212 - Teaching Studio :
#   - Course Code: MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH08066, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 5, 5PM-6PM(1h)
# JCMB_3217 - Teaching Studio :
#   - Course Code: MATH10098+MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH10065, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH11154, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10082 + MATH11053, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 1, 5PM-6PM(1h)
# JCMB_3217 - Teaching Studio :
#   - Course Code: MATH08077, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH08063, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 2, 4PM-5PM(1h)
# JCMB_3217 - Teaching Studio :
#   - Course Code: MATH11199, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10100, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH10010 + MATH10053, Day 3, 4PM-5PM(1h)
# JCMB_3217 - Teaching Studio :
#   - Course Code: MATH08077, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11187, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 4PM-5PM(1h)
# JCMB_3217 - Teaching Studio :
#   - Course Code: MATH08077, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH11236, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH10028, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 5, 3PM-4PM(1h)
# MH_1.19 :
#   - Course Code: MATH08077, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH10072, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08074, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH11176, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 1, 5PM-6PM(1h)
# MH_1.19 :
#   - Course Code: MATH08057, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH11029, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH11236 + MATH11177, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 2, 5PM-6PM(1h)
# MH_1.19 :
#   - Course Code: MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11111, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10066A, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 3, 4PM-5PM(1h)
# MH_1.19 :
#   - Course Code: MATH11199, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08074, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08074, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08074, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08072, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH11007, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 4, 5PM-6PM(1h)
# MH_1.19 :
#   - Course Code: MATH11029+MATH11197, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH08063, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10095, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH10066A, Day 5, 3PM-4PM(1h)
# MH_G.04 :
#   - Course Code: MATH10066A, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH10066A, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH11144 + MATH11179, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 1, 4PM-5PM(1h)
# MH_G.04 :
#   - Course Code: MATH08077, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11007, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 2, 5PM-6PM(1h)
# MH_G.04 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10007, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH11235 + MATH10076, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 3, 2PM-3PM(1h)
# MH_G.04 :
#   - Course Code: MATH08057, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH10095, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 4, 4PM-5PM(1h)
# MH_G.04 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10098, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH11153, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 5, 4PM-5PM(1h)
# MH_G.05 :
#   - Course Code: MATH08062, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH10098A, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH11029A, Day 1, 5PM-6PM(1h)
# MH_G.05 :
#   - Course Code: MATH11153, Day 2, 9AM-10AM(1h)
#   - Course Code: MATH10065, Day 2, 10AM-11AM(1h)
#   - Course Code: MATH11176, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10007, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11199A, Day 2, 3PM-4PM(1h)
# MH_G.05 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH08063, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 3, 3PM-4PM(1h)
# MH_G.05 :
#   - Course Code: MATH10098, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH08063, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10095, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10095, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 4, 5PM-6PM(1h)
# MH_G.05 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH11177, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11111, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08063, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH11231A, Day 5, 4PM-5PM(1h)
# MH_G.10 :
#   - Course Code: MATH08074, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH11111, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH08072, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH11235 + MATH10076, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10098A, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 1, 4PM-5PM(1h)
# MH_G.10 :
#   - Course Code: MATH11199, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11187, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 2, 5PM-6PM(1h)
# MH_G.10 :
#   - Course Code: MATH10072, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH10065, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH11111, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08057A, Day 3, 1PM-2PM(1h)
# MH_G.10 :
#   - Course Code: MATH11111, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH08063, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH11179, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 4, 1PM-2PM(1h)
# MH_G.10 :
#   - Course Code: MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH11029+MATH11197, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH11153, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10074, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 5, 5PM-6PM(1h)
# MH_G.12 :
#   - Course Code: MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10007, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 4PM-5PM(1h)
# MH_G.12 :
#   - Course Code: MATH10098, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH11187, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08066, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10028, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 2, 4PM-5PM(1h)
# MH_G.12 :
#   - Course Code: MATH11029+MATH11197, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH10013, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH11176, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH10007, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 3, 5PM-6PM(1h)
# MH_G.12 :
#   - Course Code: MATH08057, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH08077A, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10098A, Day 4, 3PM-4PM(1h)
# MH_G.12 :
#   - Course Code: MATH10098+MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08071, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08071, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 5, 2PM-3PM(1h)
# MH_G.13 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10082, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH11154, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 1, 4PM-5PM(1h)
# MH_G.13 :
#   - Course Code: MATH11187, Day 2, 9AM-10AM(1h)
#   - Course Code: MATH10074, Day 2, 10AM-11AM(1h)
#   - Course Code: MATH10095, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11029A, Day 2, 3PM-4PM(1h)
# MH_G.13 :
#   - Course Code: MATH08077, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11029+MATH11197, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH08071, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08074, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH11176, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH10007, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 3, 5PM-6PM(1h)
# MH_G.13 :
#   - Course Code: MATH11154, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH08057A, Day 4, 11AM-12PM(1h)
# MH_G.13 :
#   - Course Code: MATH10098+MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH11226, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 5, 3PM-4PM(1h)
# MH_G.30 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10098, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH10098+MATH10066, Day 1, 1PM-3PM(2h)
#   - Course Code: MATH08072, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08066, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH08066, Day 1, 5PM-6PM(1h)
# MH_G.30 :
#   - Course Code: MATH08077, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH11179, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH11226 + MATH10053, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08077A, Day 2, 5PM-6PM(1h)
# MH_G.30 :
#   - Course Code: MATH08077, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10098, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH08066, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 3, 4PM-5PM(1h)
# MH_G.30 :
#   - Course Code: MATH08077, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH08057, Day 4, 1PM-3PM(2h)
#   - Course Code: MATH11226, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH11177, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 5PM-6PM(1h)
# MH_G.30 :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10065, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH10007, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 5, 2PM-3PM(1h)
# MH_G.31 :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH08071, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08072, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10066A, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 1, 4PM-5PM(1h)
# MH_G.31 :
#   - Course Code: MATH08062, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10065, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH11007, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10082 + MATH11053, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11199A, Day 2, 3PM-4PM(1h)
# MH_G.31 :
#   - Course Code: MATH10098+MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH11177, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH11153, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH11187, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08077A, Day 3, 3PM-4PM(1h)
# MH_G.31 :
#   - Course Code: MATH11199, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10099, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 4, 1PM-3PM(2h)
#   - Course Code: MATH11236 + MATH11177, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 4, 5PM-6PM(1h)
# MH_G.31 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10065, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10066A, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH10024 + MATH10079, Day 5, 3PM-4PM(1h)
# MH_G.32 :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11226, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08074, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10065, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08066, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 1, 3PM-4PM(1h)
# MH_G.32 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11029, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH08066, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10010 + MATH10053, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08077A, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 2, 5PM-6PM(1h)
# MH_G.32 :
#   - Course Code: MATH08077, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH10098+MATH10066, Day 3, 1PM-3PM(2h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 4PM-5PM(1h)
# MH_G.32 :
#   - Course Code: MATH11235, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH10076, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH08066, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 4, 4PM-5PM(1h)
# MH_G.32 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH11199, Day 5, 1PM-3PM(2h)
#   - Course Code: MATH10065, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH11111, Day 5, 4PM-5PM(1h)
# MH_G.33 :
#   - Course Code: MATH11187, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH11053, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH11176, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH10024 + MATH10079, Day 1, 5PM-6PM(1h)
# MH_G.33 :
#   - Course Code: MATH10098, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08066, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08063, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08077A, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 2, 5PM-6PM(1h)
# MH_G.33 :
#   - Course Code: MATH11236, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH11177, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH08074, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH10024 + MATH10079, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 3, 4PM-5PM(1h)
# MH_G.33 :
#   - Course Code: MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10007, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH11144 + MATH11179, Day 4, 3PM-4PM(1h)
# MH_G.33 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08066, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11176, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH11176, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH10066A, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH11226 + MATH10053, Day 5, 5PM-6PM(1h)
# MH_G.34 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH10013, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08072, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08066, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08066, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH10010 + MATH10053, Day 1, 4PM-5PM(1h)
# MH_G.34 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10098+MATH10066, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH08071, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH10013, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08066, Day 2, 5PM-6PM(1h)
# MH_G.34 :
#   - Course Code: MATH10098, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10100, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH11154, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH10024 + MATH10079, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11231A, Day 3, 4PM-5PM(1h)
# MH_G.34 :
#   - Course Code: MATH08057, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH11111, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11111, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH11029A, Day 4, 3PM-4PM(1h)
# MH_G.34 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08072, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08077A, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11199A, Day 5, 2PM-3PM(1h)
# NUC_2.06 - Rowan :
#   - Course Code: MATH10100, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH08063, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08057A, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 1, 3PM-4PM(1h)
# NUC_2.06 - Rowan :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10017, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10066A, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 2, 1PM-2PM(1h)
# NUC_2.06 - Rowan :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10074, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH11179, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 3, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 3, 5PM-6PM(1h)
# NUC_2.06 - Rowan :
#   - Course Code: MATH08057, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11187, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH10024, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10007, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10066A, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 5PM-6PM(1h)
# NUC_2.06 - Rowan :
#   - Course Code: MATH11199, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10065, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10013, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH10066A, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 2PM-3PM(1h)
# SB_7.15 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH11053, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 1, 5PM-6PM(1h)
# SB_7.15 :
#   - Course Code: MATH08057, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH11177, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH11176, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 2, 4PM-5PM(1h)
# SB_7.15 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10099, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH10074, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08072, Day 3, 2PM-3PM(1h)
# SB_7.15 :
#   - Course Code: MATH08077, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH08063, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 4, 5PM-6PM(1h)
# SB_7.15 :
#   - Course Code: MATH08077, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH10074, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11199A, Day 5, 2PM-3PM(1h)
# SB_7.20 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10082, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH10007, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08057A, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 1, 3PM-4PM(1h)
# SB_7.20 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH10072, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 2, 5PM-6PM(1h)
# SB_7.20 :
#   - Course Code: MATH11177, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH10047, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH11007, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH10028, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 3PM-4PM(1h)
# SB_7.20 :
#   - Course Code: MATH11153, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH11111, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH11111, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH11154, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 4, 5PM-6PM(1h)
# SB_7.20 :
#   - Course Code: MATH10098+MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 5, 12PM-1PM(1h)
# AT_M2 - Teaching Studio :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH10072, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10066A, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 1, 5PM-6PM(1h)
# AT_M2 - Teaching Studio :
#   - Course Code: MATH11177, Day 2, 9AM-10AM(1h)
#   - Course Code: MATH08074, Day 2, 10AM-11AM(1h)
#   - Course Code: MATH11187, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10066A, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH11226 + MATH10053, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11199A, Day 2, 3PM-4PM(1h)
# AT_M2 - Teaching Studio :
#   - Course Code: MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH08072, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH10010 + MATH10053, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH10098A, Day 3, 4PM-5PM(1h)
# AT_M2 - Teaching Studio :
#   - Course Code: MATH11187, Day 4, 9AM-10AM(1h)
#   - Course Code: MATH10074, Day 4, 10AM-11AM(1h)
#   - Course Code: MATH11007, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08063, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH10098A, Day 4, 3PM-4PM(1h)
# AT_M2 - Teaching Studio :
#   - Course Code: MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH10095, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH11235 + MATH10076, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 5, 5PM-6PM(1h)
# 40GS_LG.07 - Teaching Studio :
#   - Course Code: MATH08074, Day 1, 9AM-10AM(1h)
#   - Course Code: MATH10065, Day 1, 10AM-11AM(1h)
#   - Course Code: MATH08066, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10095, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 4PM-5PM(1h)
# 40GS_LG.07 - Teaching Studio :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10065, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 2, 3PM-4PM(1h)
# 40GS_LG.07 - Teaching Studio :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH08063, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH11235 + MATH10076, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 3, 4PM-5PM(1h)
# 40GS_LG.07 - Teaching Studio :
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10082 + MATH11053, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08077A, Day 4, 5PM-6PM(1h)
# 40GS_LG.07 - Teaching Studio :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH11153, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10065, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08063, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08063, Day 5, 4PM-5PM(1h)
# 40GS_LG.09 :
#   - Course Code: MATH11199, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH11111, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08066, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10095, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH11226 + MATH10053, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 5PM-6PM(1h)
# 40GS_LG.09 :
#   - Course Code: MATH11029, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH11226, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11144 + MATH11179, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 2, 5PM-6PM(1h)
# 40GS_LG.09 :
#   - Course Code: MATH08074, Day 3, 9AM-10AM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 3, 10AM-11AM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH11199A, Day 3, 3PM-4PM(1h)
# 40GS_LG.09 :
#   - Course Code: MATH10098+MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10065, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 4, 1PM-2PM(1h)
# 40GS_LG.09 :
#   - Course Code: MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10066, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH10098, Day 5, 1PM-3PM(2h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 3PM-4PM(1h)
# 40GS_LG.11 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH11153, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10065, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH11231A, Day 1, 5PM-6PM(1h)
# 40GS_LG.11 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10099, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH08071, Day 2, 3PM-4PM(1h)
# 40GS_LG.11 :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH11176, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 3, 4PM-5PM(1h)
# 40GS_LG.11 :
#   - Course Code: MATH11231, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH10095, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH10095, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH10028, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10098A, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 4, 5PM-6PM(1h)
# 40GS_LG.11 :
#   - Course Code: MATH08062, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH11226 + MATH10053, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH11199A, Day 5, 5PM-6PM(1h)
# AT_2.12 :
#   - Course Code: MATH10066, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10065, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08063, Day 1, 3PM-4PM(1h)
# AT_2.12 :
#   - Course Code: MATH08074, Day 2, 9AM-10AM(1h)
#   - Course Code: MATH08074, Day 2, 10AM-11AM(1h)
#   - Course Code: MATH10095, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10007, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08077A, Day 2, 1PM-2PM(1h)
# AT_2.12 :
#   - Course Code: MATH10066, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH08066, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08063, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08057A, Day 3, 3PM-4PM(1h)
#   - Course Code: MATH11199A, Day 3, 4PM-5PM(1h)
# AT_2.12 :
#   - Course Code: MATH10066, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH10024 + MATH10079, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 4, 5PM-6PM(1h)
# AT_2.12 :
#   - Course Code: MATH11231, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH11111, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH08072, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH11236 + MATH11177, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH11029A, Day 5, 5PM-6PM(1h)
# LLTC_2.14 - Teaching Studio :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08063, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10066A, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 1, 3PM-4PM(1h)
# LLTC_2.14 - Teaching Studio :
#   - Course Code: MATH08074, Day 2, 9AM-10AM(1h)
#   - Course Code: MATH08074, Day 2, 10AM-11AM(1h)
#   - Course Code: MATH10066A, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH08077A, Day 2, 3PM-4PM(1h)
# LLTC_2.14 - Teaching Studio :
#   - Course Code: MATH08057, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 11AM-1PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 1PM-3PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 3, 3PM-5PM(2h)
#   - Course Code: MATH08066, Day 3, 5PM-6PM(1h)
# LLTC_2.14 - Teaching Studio :
#   - Course Code: MATH10098, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH10099, Day 4, 1PM-3PM(2h)
#   - Course Code: MATH08066, Day 4, 3PM-4PM(1h)
# LLTC_2.14 - Teaching Studio :
#   - Course Code: MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH08066, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10095, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH07003 + MATH11154, Day 5, 3PM-4PM(1h)
# ROB_Hugh Robson Building Computer Lab - 129 cap :
#   - Course Code: MATH11029+MATH11197, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10047, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH10074, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH08066, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH10066A, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10072 + MATH10047, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH10098A, Day 1, 5PM-6PM(1h)
# ROB_Hugh Robson Building Computer Lab - 129 cap :
#   - Course Code: MATH10065, Day 2, 9AM-10AM(1h)
#   - Course Code: MATH08063, Day 2, 10AM-11AM(1h)
#   - Course Code: MATH10007, Day 2, 11AM-12PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 2, 12PM-1PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 2, 2PM-3PM(1h)
# ROB_Hugh Robson Building Computer Lab - 129 cap :
#   - Course Code: MATH08062, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH10017, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08074, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH10076, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH11154, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 3PM-4PM(1h)
# ROB_Hugh Robson Building Computer Lab - 129 cap :
#   - Course Code: MATH08077, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10066A, Day 4, 11AM-12PM(1h)
#   - Course Code: MATH10066A, Day 4, 12PM-1PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH08077A, Day 4, 2PM-3PM(1h)
# ROB_Hugh Robson Building Computer Lab - 129 cap :
#   - Course Code: MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 5, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08066, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH10095, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 5, 4PM-5PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 5, 5PM-6PM(1h)
# 40GS_7.18 :
#   - Course Code: MATH08057, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH10098+MATH10066, Day 1, 11AM-1PM(2h)
#   - Course Code: MATH08074, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH08063, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH08063, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH10066A, Day 1, 4PM-5PM(1h)
# 40GS_7.18 :
#   - Course Code: MATH08057, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH10098, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 2, 1PM-3PM(2h)
#   - Course Code: MATH11177, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 2, 5PM-6PM(1h)
# 40GS_7.18 :
#   - Course Code: MATH11199, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08057A, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH08057A, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH11029A, Day 3, 3PM-4PM(1h)
# 40GS_7.18 :
#   - Course Code: MATH11199, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH10068+MATH08068+MATH10079, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH11111, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11111 + MATH11187, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH08077A, Day 4, 3PM-4PM(1h)
# 40GS_7.18 :
#   - Course Code: MATH10098+MATH10066, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH10047, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH10013, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH11007, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH10017 + MATH10065, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 5, 3PM-4PM(1h)
#   - Course Code: MATH08057A, Day 5, 4PM-5PM(1h)
# 40GS_7.01 :
#   - Course Code: MATH11199, Day 1, 9AM-11AM(2h)
#   - Course Code: MATH08074, Day 1, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 1, 12PM-1PM(1h)
#   - Course Code: MATH10007, Day 1, 1PM-2PM(1h)
#   - Course Code: MATH11230 + MATH11153, Day 1, 2PM-3PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 1, 3PM-4PM(1h)
#   - Course Code: MATH08068 + MATH08074, Day 1, 4PM-5PM(1h)
#   - Course Code: MATH08057A, Day 1, 5PM-6PM(1h)
# 40GS_7.01 :
#   - Course Code: MATH10066, Day 2, 9AM-11AM(2h)
#   - Course Code: MATH08057, Day 2, 11AM-1PM(2h)
#   - Course Code: MATH08066, Day 2, 1PM-2PM(1h)
#   - Course Code: MATH11176, Day 2, 2PM-3PM(1h)
#   - Course Code: MATH11144, Day 2, 3PM-4PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 2, 4PM-5PM(1h)
#   - Course Code: MATH08074 + MATH10095, Day 2, 5PM-6PM(1h)
# 40GS_7.01 :
#   - Course Code: MATH08062, Day 3, 9AM-11AM(2h)
#   - Course Code: MATH11177, Day 3, 11AM-12PM(1h)
#   - Course Code: MATH10072, Day 3, 12PM-1PM(1h)
#   - Course Code: MATH08072, Day 3, 1PM-2PM(1h)
#   - Course Code: MATH10066A, Day 3, 2PM-3PM(1h)
#   - Course Code: MATH10013 + MATH10074, Day 3, 3PM-4PM(1h)
# 40GS_7.01 :
#   - Course Code: MATH08057, Day 4, 9AM-11AM(2h)
#   - Course Code: MATH11199, Day 4, 11AM-1PM(2h)
#   - Course Code: MATH10065, Day 4, 1PM-2PM(1h)
#   - Course Code: MATH11111, Day 4, 2PM-3PM(1h)
#   - Course Code: MATH11187, Day 4, 3PM-4PM(1h)
#   - Course Code: MATH11007, Day 4, 4PM-5PM(1h)
#   - Course Code: MATH10028, Day 4, 5PM-6PM(1h)
# 40GS_7.01 :
#   - Course Code: MATH08057, Day 5, 9AM-11AM(2h)
#   - Course Code: MATH11153, Day 5, 11AM-12PM(1h)
#   - Course Code: MATH08066, Day 5, 12PM-1PM(1h)
#   - Course Code: MATH11176, Day 5, 1PM-2PM(1h)
#   - Course Code: MATH08066 + MATH10100, Day 5, 2PM-3PM(1h)
#   - Course Code: MATH10098 + MATH10028, Day 5, 3PM-4PM(1h)
