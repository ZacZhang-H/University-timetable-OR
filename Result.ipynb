# %%
import main

# %%
# %run main
# Out:
# -------SEM1 Lecture-----
# Step 1: Generating Initial Timetable using Random Generation
#
# 40GS_Lecture Theatre B:
#   - Course Code: MATH11053A, Monday, 9 AM-10 AM
#   - Course Code: MATH10013A, Tuesday, 10 AM-11 AM
#   - Course Code: MATH10095, Wednesday, 9 AM-10 AM
#   - Course Code: MATH10076, Friday, 5 PM-6 PM
#
# 40GS_Lecture Theatre C:
#   - Course Code: MATH10068, Monday, 1 PM-2 PM
#   - Course Code: MATH08077, Wednesday, 2 PM-3 PM
#   - Course Code: MATH11235A, Wednesday, 4 PM-5 PM
#   - Course Code: MATH11154, Thursday, 1 PM-3 PM
#   - Course Code: MATH11236, Friday, 5 PM-6 PM
#
# ASH_Lecture Theatre 1:
#   - Course Code: MATH10066, Monday, 10 AM-11 AM
#   - Course Code: MATH10066A, Tuesday, 1 PM-2 PM
#   - Course Code: MATH10065, Wednesday, 9 AM-11 AM
#   - Course Code: MATH10013, Friday, 1 PM-2 PM
#   - Course Code: MATH11199, Friday, 3 PM-4 PM
#
# ASH_Lecture Theatre 3:
#   - Course Code: MATH10010 + MATH11088, Tuesday, 11 AM-1 PM
#
# AT_Lecture Theatre 2:
# ...
